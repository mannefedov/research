# %%
import tarfile, lzma
import pandas as pd
import nltk.data
import warnings
import nltk.tokenize
from nltk.grammar import DependencyGrammar
from nltk.parse import (
    DependencyGraph,
    ProjectiveDependencyParser,
    NonprojectiveDependencyParser,
)
from zss import simple_distance, Node
# import spacy
from collections import defaultdict, Counter
import numpy as np
import warnings
from sklearn.metrics.pairwise import cosine_similarity
warnings.filterwarnings('ignore')

# %%
arch =  tarfile.open('Russian-annotated-conll17.tar')

# %%
def iterate_archive(arch):
    for file in arch:
        if 'wiki' not in file.name:
            continue
        if not file.isfile():
            continue
        file = arch.extractfile(file)
        try:
            reader = lzma.open(file)
        except:
            continue
        par = []
        sent = None
        tree = []
        first = reader.readline().decode('utf8')
        
        if first == '# newpar\n':
            pars = True
        else:
            pars = False
            sent = first
        
        
        for line in reader:
            text = line.decode('utf8')
            if text == '# newpar\n':
                if pars:
                    if sent and tree:
                        par.append((sent, ''.join(tree)))
                
                    yield par
                else:
                    yield [(sent, ''.join(tree))]
                    pars = True
                
                par = []
                sent, tree = None, []
            
            elif text == '\n':
                if pars and sent and tree:
                    par.append((sent, ''.join(tree)))
                
                elif not pars and sent and tree:
                    yield [(sent, ''.join(tree))]
                
                sent, tree = None, []
            
            elif text.startswith('#'):
                if sent:
                    print(sent, tree, text)
                    print('Error, line with # in the wrong place!')
                    raise KeyError
                sent = text
            
            else:
                tree.append(text)

def get_subtree(nodes, node):
    if not nodes[node]['deps']:
        return [node]
    else:
        
        
        return [node] + [get_subtree(nodes, dep) for rel in nodes[node]['deps'] if rel != 'punct'
                         for dep in nodes[node]['deps'][rel]]
# flatten = lambda l: [item for sublist in l for item in sublist]
def flatten(l):
    flat = []
    for el in l:
        if not isinstance(el, list):
            flat.append(el)
        else:
            flat += flatten(el)
    return flat

def get_predicate(d):
    subj = []
    main_subj = None
    obj = []
    main_obj = None
    verbs = []
    nodes = d.nodes
    for node in nodes:
        if nodes[node]['ctag'] == 'VERB':
            verb = [node]
            if 'aux' in nodes[node]['deps']:
                verb += flatten([get_subtree(nodes, n) for n in nodes[node]['deps']['aux']])
            elif 'aux:pass' in nodes[node]['deps']:
                verb += flatten([get_subtree(nodes, n) for n in nodes[node]['deps']['aux:pass']])
            
            verbs.append(verb)
    
    if not verbs:
#         print('BAD!')
        return None
    
    predicates = []
    for verb in verbs:
        if ('obj' in nodes[verb[0]]['deps'] or 'obl' in nodes[verb[0]]['deps']) \
            and ('nsubj' in nodes[verb[0]]['deps'] or 'nsubj:pass' in nodes[verb[0]]['deps']):
            
            main_subj = nodes[verb[0]]['deps'].get('nsubj', None) or nodes[verb[0]]['deps']['nsubj:pass']
            main_subj = main_subj[0]
            main_objs = nodes[verb[0]]['deps'].get('obj', []) + nodes[verb[0]]['deps'].get('obl', [])
    
            subj = sorted(flatten(get_subtree(nodes, main_subj)))
            objs = [sorted(flatten(get_subtree(nodes, main_obj))) for main_obj in main_objs]
    
            subj_words = [nodes[node]['word']+'_'+nodes[node]['ctag'] \
                          if node > 1 else '<start>_'+nodes[node]['word']+'_'+nodes[node]['ctag'] \
                          for node in subj]
            obj_words = []
            for obj in objs:
                ow = []
                for node in obj:
                    ow.append(nodes[node]['word']+'_'+nodes[node]['ctag'])
                obj_words.append(ow)
            
            verb_words = [nodes[node]['word']+'_'+nodes[node]['ctag'] for node in sorted(verb)]
            pred = []
            pred.append(' '.join(subj_words))
            pred.append(' '.join(verb_words))
            for ow in sorted(obj_words, key=lambda x: x[0]):
                pred.append(' '.join(ow))
            
            predicates.append(pred)
    
    return predicates

def get_predicate_pattern(d):
    subj = []
    main_subj = None
    obj = []
    main_obj = None
    verbs = []
    nodes = d.nodes
    for node in nodes:
        if nodes[node]['ctag'] == 'VERB':
            verb = [node]
            if 'aux' in nodes[node]['deps']:
                verb += flatten([get_subtree(nodes, n) for n in nodes[node]['deps']['aux']])
            elif 'aux:pass' in nodes[node]['deps']:
                verb += flatten([get_subtree(nodes, n) for n in nodes[node]['deps']['aux:pass']])
            
            verbs.append(verb)
    
    if not verbs:
#         print('BAD!')
        return None
    
    predicates = []
    for verb in verbs:
        if ('obj' in nodes[verb[0]]['deps'] or 'obl' in nodes[verb[0]]['deps']) \
            and ('nsubj' in nodes[verb[0]]['deps'] or 'nsubj:pass' in nodes[verb[0]]['deps']):
            
            main_subj = nodes[verb[0]]['deps'].get('nsubj', None) or nodes[verb[0]]['deps']['nsubj:pass']
            main_subj = main_subj[0]
            main_objs = nodes[verb[0]]['deps'].get('obj', []) + nodes[verb[0]]['deps'].get('obl', [])
    
            subj = sorted(flatten(get_subtree(nodes, main_subj)))
            objs = [sorted(flatten(get_subtree(nodes, main_obj))) for main_obj in main_objs]
    
            subj_words = [nodes[node]['word']+'_'+nodes[node]['ctag'] \
                          if node > 1 else '<start>_'+nodes[node]['word']+'_'+nodes[node]['ctag'] \
                          for node in subj]
            obj_words = []
            obj_i = []
            for obj in objs:
                ow = []
                for node in obj:
                    ow.append(nodes[node]['word']+'_'+nodes[node]['ctag']+'_'+nodes[node]['rel'])
                    obj_i.append(node)
                obj_words.append(ow)
                    
            
            obj_i = sorted(obj_i)
            pattern_i = []
            if subj[0] > obj_i[0]:
                pattern_i += list(range(subj[-1]+1, obj_i[0]))
            else:
                pattern_i += list(range(subj[-1]+1, obj_i[0]))
            if not pattern_i:
                continue
            verb_words = []
            for node in pattern_i:
                w = nodes[node]['word'] + '_'+nodes[node]['ctag']+'_'+nodes[node]['rel']
                if node in verb:
                    w += '_CORE'
                verb_words.append(w)
            
            pred = []
            pred.append(' '.join(subj_words))
            pred.append(' '.join(verb_words))
            for ow in sorted(obj_words, key=lambda x: x[0]):
                pred.append(' '.join(ow))
            
            predicates.append(pred)
    
    return predicates

# %%
[] + list(range(1, 3))
# Out:
# [1, 2]

# %%
a = [f for f in arch]

# %%
b = a[1]

# %%
j
# Out:
# 283966

# %%
i = iterate_archive(arch)

# %%
fs = open('sentences_100k_wiki.txt', 'w')
# ftr = open('trees_50000.txt', 'w')

for j, t in enumerate(i):
    
    if j > 300000:
        break
    for s in t:
        
        sent, tree = s
        if not sent or len(sent) > 1000:
            continue
        
        fs.write(sent.replace('# text = ', ''))
#         ftr.write(tree + '\n')
fs.close()
# ftr.close()

# %%
next(i)[0][0].replace('# text = ', '')
# Out:
# 'Есть ли там ресторан или кафе?\n'

# %%
next(i)
# Out:
# [('# text = Автошкола “ВИРАЖ” работает на основании таких нормативных документов, как: лицензия Министерства образования Украины (Серия АЕ No 527752 от 15.12.2014 г.) и сертификат Министерства внутренних дел (Серия ДДАІ No 003029 от 03.07.2015 г.).\n',
#   '1\tАвтошкола\tАвтошкол\tNOUN\t_\tAnimacy=Inan|Case=Nom|Gender=Fem|Number=Sing\t3\tnsubj\t_\t_\n2\t“ВИРАЖ”\t“ВИРАЖ”\tPROPN\t_\tAnimacy=Anim|Case=Nom|Gender=Masc|Number=Sing\t1\tappos\t_\t_\n3\tработает\tработать\tVERB\t_\tAspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act\t0\troot\t_\t_\n4\tна\tна\tADP\t_\t_\t5\tcase\t_\t_\n5\tосновании\tоснование\tNOUN\t_\tAnimacy=Inan|Case=Loc|Gender=Neut|Number=Sing\t3\tobl\t_\t_\n6\tтаких\tтакой\tDET\t_\tCase=Gen|Number=Plur\t8\tamod\t_\t_\n7\tнормативных\tнормативный\tADJ\t_\tCase=Gen|Degree=Pos|Number=Plur\t8\tamod\t_\t_\n8\tдокументов\tдокумент\tNOUN\t_\tAnimacy=Inan|Case=Gen|Gender=Masc|Number=Plur\t5\tnmod\t_\tSpaceAfter=No\n9\t,\t,\tPUNCT\t_\t_\t8\tpunct\t_\t_\n10\tкак\tкак\tSCONJ\t_\t_\t3\tcc\t_\tSpaceAfter=No\n11\t:\t:\tPUNCT\t_\t_\t10\tpunct\t_\t_\n12\tлицензия\tлицензия\tNOUN\t_\tAnimacy=Inan|Case=Nom|Gender=Fem|Number=Sing\t10\tparataxis\t_\t_\n13\tМинистерства\tминистерство\tPROPN\t_\tAnimacy=Inan|Case=Gen|Gender=Neut|Number=Sing\t12\tnmod\t_\t_\n14\tобразования\tобразование\tNOUN\t_\tAnimacy=Inan|Case=Gen|Gender=Neut|Number=Sing\t13\tnmod\t_\t_\n15\tУкраины\tукраина\tPROPN\t_\tAnimacy=Inan|Case=Gen|Gender=Fem|Number=Sing\t13\tnmod\t_\t_\n16\t(\t(\tPUNCT\t_\t_\t17\tpunct\t_\tSpaceAfter=No\n17\tСерия\tсерия\tPROPN\t_\tAnimacy=Anim|Case=Nom|Gender=Masc|Number=Sing\t12\tappos\t_\t_\n18\tАЕ\tай\tPROPN\t_\tAnimacy=Anim|Case=Nom|Gender=Masc|Number=Sing\t17\tflat:name\t_\t_\n19\tNo\tNo\tPROPN\t_\tForeign=Yes\t18\tflat:foreign\t_\t_\n20\t527752\t527752\tNUM\t_\t_\t19\tnummod\t_\t_\n21\tот\tот\tADP\t_\t_\t23\tcase\t_\t_\n22\t15.12.2014\t15.12.2014\tNUM\t_\t_\t23\tnummod\t_\t_\n23\tг.\tгод\tNOUN\t_\tAnimacy=Inan|Case=Gen|Gender=Masc|Number=Sing\t20\tnmod\t_\tSpaceAfter=No\n24\t)\t)\tPUNCT\t_\t_\t23\tpunct\t_\t_\n25\tи\tи\tCCONJ\t_\t_\t26\tcc\t_\t_\n26\tсертификат\tсертификат\tNOUN\t_\tAnimacy=Anim|Case=Nom|Gender=Masc|Number=Sing\t12\tconj\t_\t_\n27\tМинистерства\tминистерство\tPROPN\t_\tAnimacy=Inan|Case=Gen|Gender=Neut|Number=Sing\t26\tnmod\t_\t_\n28\tвнутренних\tвнутренний\tADJ\t_\tCase=Gen|Degree=Pos|Number=Plur\t29\tamod\t_\t_\n29\tдел\tдело\tNOUN\t_\tAnimacy=Inan|Case=Gen|Gender=Neut|Number=Plur\t27\tnmod\t_\t_\n30\t(\t(\tPUNCT\t_\t_\t31\tpunct\t_\tSpaceAfter=No\n31\tСерия\tсерия\tPROPN\t_\tAnimacy=Anim|Case=Nom|Gender=Masc|Number=Sing\t27\tappos\t_\t_\n32\tДДАІ\tДДАІ\tPROPN\t_\tAnimacy=Anim|Case=Nom|Gender=Masc|Number=Sing\t31\tflat:name\t_\t_\n33\tNo\tNo\tPROPN\t_\tForeign=Yes\t32\tflat:foreign\t_\t_\n34\t003029\t003029\tNUM\t_\t_\t33\tnummod\t_\t_\n35\tот\tот\tADP\t_\t_\t37\tcase\t_\t_\n36\t03.07.2015\t03.07.2015\tNUM\t_\t_\t37\tnummod\t_\t_\n37\tг.\tгод\tNOUN\t_\tAnimacy=Inan|Case=Gen|Gender=Masc|Number=Sing\t31\tnmod\t_\tSpaceAfter=No\n38\t)\t)\tPUNCT\t_\t_\t37\tpunct\t_\tSpaceAfter=No\n39\t.\t.\tPUNCT\t_\t_\t37\tpunct\t_\t_\n')]

# %%
f = open('predicates_pos.txt', 'w')
for par in iterate_archive(arch):
    for sent, tree in par:
        try:
            d = DependencyGraph(tree.split('\n', maxsplit=1)[1])
        except:
            continue
        pr = get_predicate(d)
        if not pr:continue
        for p in pr:
            f.write('\t'.join(p) + '\n')
            
f.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-355-95f6a996ccba> in <module>()
#       1 f = open('predicates_pos.txt', 'w')
# ----> 2 for par in iterate_archive(arch):
#       3     for sent, tree in par:
#       4         try:
#       5             d = DependencyGraph(tree.split('\n', maxsplit=1)[1])
#
# <ipython-input-354-6d2e76efd33d> in iterate_archive(arch)
#      20
#      21
# ---> 22         for line in reader:
#      23             text = line.decode('utf8')
#      24             if text == '# newpar\n':
#
# /usr/lib/python3.5/lzma.py in readline(self, size)
#     218         """
#     219         self._check_can_read()
# --> 220         return self._buffer.readline(size)
#     221
#     222     def write(self, data):
#
# /usr/lib/python3.5/_compression.py in readinto(self, b)
#      66     def readinto(self, b):
#      67         with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68             data = self.read(len(byte_view))
#      69             byte_view[:len(data)] = data
#      70         return len(data)
#
# /usr/lib/python3.5/_compression.py in read(self, size)
#     101                 else:
#     102                     rawblock = b""
# --> 103                 data = self._decompressor.decompress(rawblock, size)
#     104             if data:
#     105                 break
#
# KeyboardInterrupt:

# %%
f = open('predicates_pattern.txt', 'w')
for par in iterate_archive(arch):
    for sent, tree in par:
        try:
            d = DependencyGraph(tree.split('\n', maxsplit=1)[1])
        except:
            continue
        pr = get_predicate_pattern(d)
        if not pr:continue
        for p in pr:
            f.write('\t'.join(p) + '\n')
            
f.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-448-464d769822a8> in <module>()
#       1 f = open('predicates_pattern.txt', 'w')
# ----> 2 for par in iterate_archive(arch):
#       3     for sent, tree in par:
#       4         try:
#       5             d = DependencyGraph(tree.split('\n', maxsplit=1)[1])
#
# <ipython-input-408-2af76875c8a8> in iterate_archive(arch)
#      35                 sent, tree = None, []
#      36
# ---> 37             elif text == '\n':
#      38                 if pars and sent and tree:
#      39                     par.append((sent, ''.join(tree)))
#
# KeyboardInterrupt:

# %%
f.close()

# %%
f.close()

# %% [markdown]
# ## Близость предикатов по embeddingам

# %%
import sentencepiece as spm
sp = spm.SentencePieceProcessor()
sp.Load("ru.wiki.bpe.op200000.model")
# sp.EncodeAsPieces("This is a test")
# Out:
# True

# %%
sp.EncodeAsPieces("применяется")
# Out:
# ['▁применяется']

# %%
from gensim.models import KeyedVectors
model = KeyedVectors.load_word2vec_format("ru.wiki.bpe.op200000.d300.w2v.bin", binary=True)

# %%
np.concatenate([np.mean(model[sp.EncodeAsPieces("применяется на практике")], axis=0), 
          np.mean(model[sp.EncodeAsPieces("применяется на практике")], axis=0)]).shape
# Out:
# (600,)

# %%
sp.EncodeAsPieces(p.lower())
# Out:
# ['▁', 'ב', 'пере', 'ходит']

# %%
a = np.zeros((100,))

# %%
model.

# %%
predicates = open('predicates.txt').read().splitlines()
X = np.zeros((len(predicates), 300))
# X_subj = np.zeros((len(predicates), 300))
for i, pred in enumerate(predicates):
    pl = pred.split('\t')
    
    if len(pl) > 5:
        continue
    
    nsubj, p, *objs = pl
    
#     pieces = [x for x in sp.EncodeAsPieces(p.lower()) if x in model]
#     if not pieces:
#         continue
#     vecs = model[pieces]
#     vec = np.mean(vecs, axis=0)
#     X[i] = vec
    nsubj_pieces = [x for x in sp.EncodeAsPieces(nsubj.lower()) if x in model]
    nsubj_vec = np.mean(model[nsubj_pieces], axis=0) if nsubj_pieces else np.zeros((300,))
    
#     p_pieces = [x for x in sp.EncodeAsPieces(p.lower()) if x in model]
#     p_vec = np.mean(model[p_pieces], axis=0) if p_pieces else np.zeros((300,))
    
#     objs_pieces = [[x for x in sp.EncodeAsPieces(obj.lower()) if x in model] for obj in objs]
#     obj_vec = [np.mean(model[piece], axis=0) if piece else np.zeros((300,)) for piece in objs_pieces] 
    
#     vec = [nsubj_vec, p_vec] + obj_vec + [np.zeros((300,)) for i in range(3 - len(objs))]
    
#     vec = np.concatenate(p_vec)
    
    X[i] = nsubj_vec

# %%
model[[x for x in sp.EncodeAsPieces(nsubj.lower()) if x in model]].shape
# Out:
# (1, 300)

# %%
X.shape
# Out:
# (144660, 300)

# %%
[x for x in sp.EncodeAsPieces(nsubj.lower()) if x in model]
# Out:
# []

# %%
from sklearn.cluster import MiniBatchKMeans

# %%
km = MiniBatchKMeans(10000, n_init=1, batch_size=20000, verbose=True, init_size=30000,  max_no_improvement=150)

# %%
km_s = MiniBatchKMeans(10000, n_init=1, batch_size=20000, verbose=True)

# %%
# km_s.fit(X)

# %%
km.fit(X)
# Out:
# Init 1/1 with method: k-means++
# Inertia for init 1/1: 75306.466880
# Minibatch iteration 1/800: mean batch inertia: 3.778345, ewa inertia: 3.778345
# Minibatch iteration 2/800: mean batch inertia: 3.602757, ewa inertia: 3.729794
# Minibatch iteration 3/800: mean batch inertia: 3.440036, ewa inertia: 3.649673
# Minibatch iteration 4/800: mean batch inertia: 3.434478, ewa inertia: 3.590170
# Minibatch iteration 5/800: mean batch inertia: 3.275418, ewa inertia: 3.503138
# Minibatch iteration 6/800: mean batch inertia: 3.297392, ewa inertia: 3.446248
# Minibatch iteration 7/800: mean batch inertia: 3.276970, ewa inertia: 3.399441
# Minibatch iteration 8/800: mean batch inertia: 3.197869, ewa inertia: 3.343705
# Minibatch iteration 9/800: mean batch inertia: 3.219714, ewa inertia: 3.309420
# [MiniBatchKMeans] Reassigning 9752 cluster centers.
# Minibatch iteration 10/800: mean batch inertia: 3.159101, ewa inertia: 3.267856
# Minibatch iteration 11/800: mean batch inertia: 5.277688, ewa inertia: 3.823592
# Minibatch iteration 12/800: mean batch inertia: 5.312823, ewa inertia: 4.235377
# Minibatch iteration 13/800: mean batch inertia: 5.250779, ewa inertia: 4.516144
# Minibatch iteration 14/800: mean batch inertia: 5.228920, ewa inertia: 4.713233
# Minibatch iteration 15/800: mean batch inertia: 5.085948, ewa inertia: 4.816292
# Minibatch iteration 16/800: mean batch inertia: 5.108515, ewa inertia: 4.897094
# Minibatch iteration 17/800: mean batch inertia: 5.012892, ewa inertia: 4.929113
# Minibatch iteration 18/800: mean batch inertia: 5.076547, ewa inertia: 4.969880
# Minibatch iteration 19/800: mean batch inertia: 5.064460, ewa inertia: 4.996032
# Minibatch iteration 20/800: mean batch inertia: 4.964192, ewa inertia: 4.987228
# Minibatch iteration 21/800: mean batch inertia: 5.040479, ewa inertia: 5.001952
# Minibatch iteration 22/800: mean batch inertia: 5.048684, ewa inertia: 5.014874
# Minibatch iteration 23/800: mean batch inertia: 4.901624, ewa inertia: 4.983560
# Minibatch iteration 24/800: mean batch inertia: 4.884530, ewa inertia: 4.956177
# Minibatch iteration 25/800: mean batch inertia: 4.950999, ewa inertia: 4.954745
# Minibatch iteration 26/800: mean batch inertia: 4.928438, ewa inertia: 4.947471
# Minibatch iteration 27/800: mean batch inertia: 4.857266, ewa inertia: 4.922529
# Minibatch iteration 28/800: mean batch inertia: 4.812012, ewa inertia: 4.891970
# Minibatch iteration 29/800: mean batch inertia: 4.846872, ewa inertia: 4.879500
# Minibatch iteration 30/800: mean batch inertia: 4.782628, ewa inertia: 4.852714
# Minibatch iteration 31/800: mean batch inertia: 4.790199, ewa inertia: 4.835428
# Minibatch iteration 32/800: mean batch inertia: 4.706116, ewa inertia: 4.799672
# Minibatch iteration 33/800: mean batch inertia: 4.737759, ewa inertia: 4.782552
# Minibatch iteration 34/800: mean batch inertia: 4.737305, ewa inertia: 4.770041
# Minibatch iteration 35/800: mean batch inertia: 4.758754, ewa inertia: 4.766920
# Minibatch iteration 36/800: mean batch inertia: 4.725421, ewa inertia: 4.755445
# Minibatch iteration 37/800: mean batch inertia: 4.665651, ewa inertia: 4.730616
# Minibatch iteration 38/800: mean batch inertia: 4.718309, ewa inertia: 4.727213
# Minibatch iteration 39/800: mean batch inertia: 4.672784, ewa inertia: 4.712163
# Minibatch iteration 40/800: mean batch inertia: 4.760948, ewa inertia: 4.725653
# Minibatch iteration 41/800: mean batch inertia: 4.557539, ewa inertia: 4.679168
# Minibatch iteration 42/800: mean batch inertia: 4.653217, ewa inertia: 4.671992
# Minibatch iteration 43/800: mean batch inertia: 4.701352, ewa inertia: 4.680110
# Minibatch iteration 44/800: mean batch inertia: 4.627718, ewa inertia: 4.665623
# Minibatch iteration 45/800: mean batch inertia: 4.648874, ewa inertia: 4.660992
# Minibatch iteration 46/800: mean batch inertia: 4.617308, ewa inertia: 4.648913
# Minibatch iteration 47/800: mean batch inertia: 4.676750, ewa inertia: 4.656610
# Minibatch iteration 48/800: mean batch inertia: 4.607174, ewa inertia: 4.642941
# Minibatch iteration 49/800: mean batch inertia: 4.488179, ewa inertia: 4.600148
# Minibatch iteration 50/800: mean batch inertia: 4.561473, ewa inertia: 4.589454
# Minibatch iteration 51/800: mean batch inertia: 4.556636, ewa inertia: 4.580380
# Minibatch iteration 52/800: mean batch inertia: 4.519866, ewa inertia: 4.563647
# Minibatch iteration 53/800: mean batch inertia: 4.494391, ewa inertia: 4.544497
# Minibatch iteration 54/800: mean batch inertia: 4.552726, ewa inertia: 4.546773
# Minibatch iteration 55/800: mean batch inertia: 4.459606, ewa inertia: 4.522670
# Minibatch iteration 56/800: mean batch inertia: 4.490816, ewa inertia: 4.513862
# Minibatch iteration 57/800: mean batch inertia: 4.463538, ewa inertia: 4.499947
# Minibatch iteration 58/800: mean batch inertia: 4.563755, ewa inertia: 4.517591
# Minibatch iteration 59/800: mean batch inertia: 4.476309, ewa inertia: 4.506176
# Minibatch iteration 60/800: mean batch inertia: 4.411834, ewa inertia: 4.480090
# Minibatch iteration 61/800: mean batch inertia: 4.454626, ewa inertia: 4.473049
# Minibatch iteration 62/800: mean batch inertia: 4.430434, ewa inertia: 4.461265
# Minibatch iteration 63/800: mean batch inertia: 4.408687, ewa inertia: 4.446727
# Minibatch iteration 64/800: mean batch inertia: 4.462068, ewa inertia: 4.450969
# Minibatch iteration 65/800: mean batch inertia: 4.424833, ewa inertia: 4.443742
# Minibatch iteration 66/800: mean batch inertia: 4.391856, ewa inertia: 4.429395
# Minibatch iteration 67/800: mean batch inertia: 4.453501, ewa inertia: 4.436061
# Minibatch iteration 68/800: mean batch inertia: 4.410835, ewa inertia: 4.429086
# Minibatch iteration 69/800: mean batch inertia: 4.442831, ewa inertia: 4.432886
# Minibatch iteration 70/800: mean batch inertia: 4.415376, ewa inertia: 4.428045
# Minibatch iteration 71/800: mean batch inertia: 4.434636, ewa inertia: 4.429867
# Minibatch iteration 72/800: mean batch inertia: 4.369203, ewa inertia: 4.413093
# Minibatch iteration 73/800: mean batch inertia: 4.405166, ewa inertia: 4.410901
# Minibatch iteration 74/800: mean batch inertia: 4.344622, ewa inertia: 4.392574
# Minibatch iteration 75/800: mean batch inertia: 4.440845, ewa inertia: 4.405921
# Minibatch iteration 76/800: mean batch inertia: 4.466647, ewa inertia: 4.422713
# Minibatch iteration 77/800: mean batch inertia: 4.284783, ewa inertia: 4.384574
# Minibatch iteration 78/800: mean batch inertia: 4.372468, ewa inertia: 4.381226
# Minibatch iteration 79/800: mean batch inertia: 4.380918, ewa inertia: 4.381141
# Minibatch iteration 80/800: mean batch inertia: 4.392983, ewa inertia: 4.384415
# Minibatch iteration 81/800: mean batch inertia: 4.313257, ewa inertia: 4.364740
# Minibatch iteration 82/800: mean batch inertia: 4.368185, ewa inertia: 4.365692
# Minibatch iteration 83/800: mean batch inertia: 4.297929, ewa inertia: 4.346955
# Minibatch iteration 84/800: mean batch inertia: 4.354056, ewa inertia: 4.348918
# Minibatch iteration 85/800: mean batch inertia: 4.281629, ewa inertia: 4.330312
# Minibatch iteration 86/800: mean batch inertia: 4.383793, ewa inertia: 4.345100
# Minibatch iteration 87/800: mean batch inertia: 4.315843, ewa inertia: 4.337010
# Minibatch iteration 88/800: mean batch inertia: 4.325362, ewa inertia: 4.333790
# Minibatch iteration 89/800: mean batch inertia: 4.268082, ewa inertia: 4.315621
# Minibatch iteration 90/800: mean batch inertia: 4.297697, ewa inertia: 4.310665
# Minibatch iteration 91/800: mean batch inertia: 4.231990, ewa inertia: 4.288910
# Minibatch iteration 92/800: mean batch inertia: 4.349605, ewa inertia: 4.305693
# Minibatch iteration 93/800: mean batch inertia: 4.280075, ewa inertia: 4.298609
# Minibatch iteration 94/800: mean batch inertia: 4.329845, ewa inertia: 4.307246
# Minibatch iteration 95/800: mean batch inertia: 4.325120, ewa inertia: 4.312189
# Minibatch iteration 96/800: mean batch inertia: 4.283941, ewa inertia: 4.304378
# Minibatch iteration 97/800: mean batch inertia: 4.218236, ewa inertia: 4.280559
# Minibatch iteration 98/800: mean batch inertia: 4.190353, ewa inertia: 4.255616
# Minibatch iteration 99/800: mean batch inertia: 4.251293, ewa inertia: 4.254421
# Minibatch iteration 100/800: mean batch inertia: 4.299384, ewa inertia: 4.266854
# Minibatch iteration 101/800: mean batch inertia: 4.291330, ewa inertia: 4.273622
# Minibatch iteration 102/800: mean batch inertia: 4.250618, ewa inertia: 4.267261
# Minibatch iteration 103/800: mean batch inertia: 4.296551, ewa inertia: 4.275360
# Minibatch iteration 104/800: mean batch inertia: 4.272898, ewa inertia: 4.274679
# Minibatch iteration 105/800: mean batch inertia: 4.218040, ewa inertia: 4.259018
# Minibatch iteration 106/800: mean batch inertia: 4.193293, ewa inertia: 4.240844
# Minibatch iteration 107/800: mean batch inertia: 4.271274, ewa inertia: 4.249258
# Minibatch iteration 108/800: mean batch inertia: 4.246664, ewa inertia: 4.248541
# Minibatch iteration 109/800: mean batch inertia: 4.186650, ewa inertia: 4.231428
# Minibatch iteration 110/800: mean batch inertia: 4.212890, ewa inertia: 4.226302
# Minibatch iteration 111/800: mean batch inertia: 4.202998, ewa inertia: 4.219858
# Minibatch iteration 112/800: mean batch inertia: 4.217906, ewa inertia: 4.219318
# Minibatch iteration 113/800: mean batch inertia: 4.276763, ewa inertia: 4.235202
# Minibatch iteration 114/800: mean batch inertia: 4.218946, ewa inertia: 4.230707
# Minibatch iteration 115/800: mean batch inertia: 4.103949, ewa inertia: 4.195658
# Minibatch iteration 116/800: mean batch inertia: 4.146698, ewa inertia: 4.182120
# Minibatch iteration 117/800: mean batch inertia: 4.152787, ewa inertia: 4.174009
# Minibatch iteration 118/800: mean batch inertia: 4.212402, ewa inertia: 4.184625
# Minibatch iteration 119/800: mean batch inertia: 4.183640, ewa inertia: 4.184353
# Minibatch iteration 120/800: mean batch inertia: 4.115570, ewa inertia: 4.165334
# Minibatch iteration 121/800: mean batch inertia: 4.174067, ewa inertia: 4.167749
# Minibatch iteration 122/800: mean batch inertia: 4.120652, ewa inertia: 4.154726
# Minibatch iteration 123/800: mean batch inertia: 4.185936, ewa inertia: 4.163356
# Minibatch iteration 124/800: mean batch inertia: 4.183207, ewa inertia: 4.168845
# Minibatch iteration 125/800: mean batch inertia: 4.115240, ewa inertia: 4.154023
# Minibatch iteration 126/800: mean batch inertia: 4.138815, ewa inertia: 4.149817
# Minibatch iteration 127/800: mean batch inertia: 4.130218, ewa inertia: 4.144398
# Minibatch iteration 128/800: mean batch inertia: 4.174212, ewa inertia: 4.152642
# Minibatch iteration 129/800: mean batch inertia: 4.151324, ewa inertia: 4.152278
# Minibatch iteration 130/800: mean batch inertia: 4.163810, ewa inertia: 4.155466
# Minibatch iteration 131/800: mean batch inertia: 4.135618, ewa inertia: 4.149978
# Minibatch iteration 132/800: mean batch inertia: 4.238828, ewa inertia: 4.174546
# Minibatch iteration 133/800: mean batch inertia: 4.121832, ewa inertia: 4.159970
# Minibatch iteration 134/800: mean batch inertia: 4.171901, ewa inertia: 4.163269
# Minibatch iteration 135/800: mean batch inertia: 4.171493, ewa inertia: 4.165543
# Minibatch iteration 136/800: mean batch inertia: 4.164113, ewa inertia: 4.165148
# Minibatch iteration 137/800: mean batch inertia: 4.172024, ewa inertia: 4.167049
# Minibatch iteration 138/800: mean batch inertia: 4.090103, ewa inertia: 4.145773
# Minibatch iteration 139/800: mean batch inertia: 4.078126, ewa inertia: 4.127068
# Minibatch iteration 140/800: mean batch inertia: 4.146645, ewa inertia: 4.132481
# Minibatch iteration 141/800: mean batch inertia: 4.169715, ewa inertia: 4.142777
# Minibatch iteration 142/800: mean batch inertia: 4.163151, ewa inertia: 4.148410
# Minibatch iteration 143/800: mean batch inertia: 4.109986, ewa inertia: 4.137786
# Minibatch iteration 144/800: mean batch inertia: 4.148928, ewa inertia: 4.140867
# Minibatch iteration 145/800: mean batch inertia: 4.093086, ewa inertia: 4.127655
# Minibatch iteration 146/800: mean batch inertia: 4.092548, ewa inertia: 4.117948
# Minibatch iteration 147/800: mean batch inertia: 4.138240, ewa inertia: 4.123558
# Minibatch iteration 148/800: mean batch inertia: 4.167481, ewa inertia: 4.135704
# [MiniBatchKMeans] Reassigning 9739 cluster centers.
# Minibatch iteration 149/800: mean batch inertia: 4.136857, ewa inertia: 4.136022
# Minibatch iteration 150/800: mean batch inertia: 5.155666, ewa inertia: 4.417963
# Minibatch iteration 151/800: mean batch inertia: 5.331568, ewa inertia: 4.670582
# Minibatch iteration 152/800: mean batch inertia: 5.220332, ewa inertia: 4.822593
# Minibatch iteration 153/800: mean batch inertia: 5.251402, ewa inertia: 4.941162
# Minibatch iteration 154/800: mean batch inertia: 5.220210, ewa inertia: 5.018321
# Minibatch iteration 155/800: mean batch inertia: 5.200951, ewa inertia: 5.068820
# Minibatch iteration 156/800: mean batch inertia: 5.257662, ewa inertia: 5.121036
# Minibatch iteration 157/800: mean batch inertia: 5.241017, ewa inertia: 5.154212
# Minibatch iteration 158/800: mean batch inertia: 5.235875, ewa inertia: 5.176793
# Minibatch iteration 159/800: mean batch inertia: 5.294982, ewa inertia: 5.209473
# Minibatch iteration 160/800: mean batch inertia: 5.231865, ewa inertia: 5.215665
# Converged (lack of improvement in inertia) at iteration 160/800
# Computing label assignment and total inertia
# MiniBatchKMeans(batch_size=20000, compute_labels=True, init='k-means++',
#         init_size=30000, max_iter=100, max_no_improvement=150,
#         n_clusters=10000, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=True)

# %%
km.
# Out:
# MiniBatchKMeans(batch_size=20000, compute_labels=True, init='k-means++',
#         init_size=30000, max_iter=100, max_no_improvement=10,
#         n_clusters=10000, n_init=1, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=True)

# %%
labels.shape
# Out:
# (20000,)

# %%
labels = km.labels_

# %%
labels_s = km_s.labels_

# %%
clusters = defaultdict(list)
for i in range(len(predicates)):
    clusters[labels[i]].append(predicates[i])

# %%
clusters = defaultdict(list)
for i in range(len(predicates)):
    clusters[labels_s[i]].append(predicates[i])

# %%
m = cosine_similarity(X[9].reshape(1, -1), X)

# %%
m.argsort()[0][::-1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-240-9b950f8e4fb2> in <module>()
# ----> 1 m.argsort()[100076][::-1]
#
# IndexError: index 100076 is out of bounds for axis 0 with size 1

# %%
predicates[100076]
# Out:
# 'Борис Львович Коваленко\tродился\tв с . Хотуничи Щорского района Черниговской области в семье железнодорожника .'

# %%
ml = Counter()
for p in predicates:
    ml.update([len(p.split('\t'))])

# %%
ml
# Out:
# Counter({3: 82381, 4: 35547, 5: 6518, 6: 862, 7: 112, 8: 14, 9: 4})

# %%
f = open('clusters_subj.txt', 'w')
for cl in clusters:
    f.write('### {} ###\n\n'.format(cl))
    pred_by_length = defaultdict(list)
    
#     for p in clusters[cl]:
#         if len(p.split('\t')) < 3:
#             continue
#         pred_by_length[len(p.split('\t')) - 2].append(p)
        
#     for l in pred_by_length:
#         f.write('\n\n@@@ {} @@@\n\n'.format(l))
#         for p in pred_by_length[l]:
    for p in clusters[cl]:
        f.write(p.split('\t')[0] + '\n')
    
    f.write('\n\n')
f.close()

# %%
def count_verb_rels(sents):
    verbs = defaultdict(set)
    for sent in sents:
        try:
            d = DependencyGraph(sent.split('\n', maxsplit=1)[1])
        except (KeyError, ValueError, AssertionError):
            continue
        nodes = [node for node in d.nodes if d.nodes[node]['ctag'] == 'VERB']
        
        for node in nodes:
            v = d.nodes[node]['word'].lower()
            subs = []
            for rel in d.nodes[node]['deps']:
#                 if rel not in ['obl', 'obj']:
#                     continue
                if rel not in ['aux', 'aux:pass']:
                    continue
                
                for s in d.nodes[node]['deps'][rel]:
                    sub = sorted(flatten(get_subtree(d.nodes, s)))
#                     subs = [(d.nodes[n]['rel'], d.nodes[n]['word']) for n in sub]
                    subs.append(' '.join([d.nodes[n]['word'] for n in sub]))
#                         sw = (d.nodes[s]['rel'], d.nodes[s]['word'].lower())
#                             verbs[v].update([sw])
            if subs:
                verbs[v].update(tuple(subs))
    return dict(verbs)

# %%
flatten(get_subtree(d.nodes, 2))
# Out:
# [2, 3, 4]

# %%
verbs = count_verb_rels(sents[:100000])

# %%
vs = list(verbs.keys())

# %%
vs[:10]
# Out:
# ['объединена',
#  'уступать',
#  'проводиться',
#  'скрыта',
#  'проголосовало',
#  'отпущен',
#  'посажены',
#  'потерян',
#  'переделаны',
#  'вынуждено']

# %%
set(verbs['объединена'])
# Out:
# {'была'}

# %%
[] + [1, 2,3]
# Out:
# [1, 2, 3]

# %%
import gensim

# %%
from gensim.corpora import WikiCorpus, MmCorpus
from gensim.utils import tokenize, lemmatize
import gensim

# %%
# wiki = WikiCorpus('ruwiki-latest-pages-articles.xml.bz2', lemmatize=True) # create word->word_id mapping, takes almost 8h
MmCorpus.serialize('wiki_ru_vocab.mm', wiki) # another 8h, creates a file in MatrixMarket format and mapping

# %%
f = open('wiki_texts.txt', 'w')
i = 0
for text in wiki.get_texts():
    f.write(' '.join([x.decode('utf8').rstrip('_') for x in text]) + '\n')
    i += 1
    if not i % 10000:
        print('Processed - ', i)
# Out:
# Processed -  10000
# Processed -  20000
# Processed -  30000
# Processed -  40000
# Processed -  50000
# Processed -  60000
# Processed -  70000
# Processed -  80000
# Processed -  90000
# Processed -  100000
# Processed -  110000
# Processed -  120000
# Processed -  130000
# Processed -  140000
# Processed -  150000
# Processed -  160000
# Processed -  170000
# Processed -  180000
# Processed -  190000
# Processed -  200000
# Processed -  210000
# Processed -  220000
# Processed -  230000
# Processed -  240000
# Processed -  250000
# Processed -  260000
# Processed -  270000
# Processed -  280000
# Processed -  290000
# Processed -  300000
# Processed -  310000
# Processed -  320000
# Processed -  330000
# Processed -  340000
# Processed -  350000
# Processed -  360000
# Processed -  370000
# Processed -  380000
# Processed -  390000
# Processed -  400000
# Processed -  410000
# Processed -  420000
# Processed -  430000
# Processed -  440000
# Processed -  450000
# Processed -  460000
# Processed -  470000
# Processed -  480000
# Processed -  490000
# Processed -  500000
# Processed -  510000
# Processed -  520000
# Processed -  530000
# Processed -  540000
# Processed -  550000
# Processed -  560000
# Processed -  570000
# Processed -  580000
# Processed -  590000
# Processed -  600000
# Processed -  610000
# Processed -  620000
# Processed -  630000
# Processed -  640000
# Processed -  650000
# Processed -  660000
# Processed -  670000
# Processed -  680000
# Processed -  690000
# Processed -  700000
# Processed -  710000
# Processed -  720000
# Processed -  730000
# Processed -  740000
# Processed -  750000
# Processed -  760000
# Processed -  770000
# Processed -  780000
# Processed -  790000
# Processed -  800000
# Processed -  810000
# Processed -  820000
# Processed -  830000
# Processed -  840000
# Processed -  850000
# Processed -  860000
# Processed -  870000
# Processed -  880000
# Processed -  890000
# Processed -  900000
# Processed -  910000
# Processed -  920000
# Processed -  930000
# Processed -  940000
# Processed -  950000
# Processed -  960000
# Processed -  970000
# Processed -  980000
# Processed -  990000
# Processed -  1000000
# Processed -  1010000
# Processed -  1020000
# Processed -  1030000
# Processed -  1040000
# Processed -  1050000
# Processed -  1060000
# Processed -  1070000
# Processed -  1080000
# Processed -  1090000
# Processed -  1100000
# Processed -  1110000
# Processed -  1120000
# Processed -  1130000
# Processed -  1140000
# Processed -  1150000
# Processed -  1160000
# Processed -  1170000
# Processed -  1180000

# %%
f.close()

# %%
i
# Out:
# 142535

# %%
docs = gensim.models.doc2vec.TaggedLineDocument('wiki_texts.txt')

# %%
doc2vec = gensim.models.Doc2Vec(docs, vector_size=200, min_count=5, workers=3)

# %%
# ?gensim.models.Doc2Vec

# %%
doc2vec.docvecs.most_similar([doc2vec.infer_vector(t[0].split())])
# Out:
# [(684460, 0.910470187664032),
#  (1182366, 0.9060593843460083),
#  (1091552, 0.9052213430404663),
#  (905271, 0.9049792885780334),
#  (1013732, 0.9021373391151428),
#  (1102873, 0.9021013975143433),
#  (1032700, 0.9013933539390564),
#  (1169996, 0.9012395143508911),
#  (864957, 0.9008297324180603),
#  (1142866, 0.9005771279335022)]

# %%
t = []

# %%
for i, text in enumerate(open('wiki_texts.txt')):
    if i == 684460:
        t.append(text)
        break

# %%
doc2vec.save('word2vec_200')

# %%
from nltk.corpus import stopwords
stops = set(stopwords.words('russian') + ['который', 'это', 'та', "которая", "всё", "многое", "которое"])

# %%
predicates = Counter()
examples = defaultdict(set)
for line in open('predicates_pattern.txt'):
    subj, predicate, *objs = line.split('\t')
    sws = [token.split('_')[0] for token in subj.split()]
    if not len(set([x.lower() for x in sws]) - stops):
        continue
    for obj in objs:
        tokens = obj.split()
        ws = [token.split('_')[0] for token in tokens]
        if not (set([x.lower() for x in ws]) - stops):
            continue
        rel = [token.split('_')[2] for token in tokens]
        pred_ws = [token.split('_')[0] for token in predicate.split()]
        if rel[0] in ['case', 'obl']:
            pred_ws.append(ws.pop(0))
            predicates.update([' '.join(pred_ws)])
        examples[' '.join(pred_ws)].add((' '.join(sws), ' '.join(ws)))

# %%
def examples_for_pred(pred):
    predicates = Counter()
    for line in open('predicates_pattern.txt'):
        subj, predicate, *objs = line.split('\t')
        p = ' '.join([token.split('_')[0] for token in predicate.split()])
        print(p)
        return False
        if pred == p:
            predicates.update([(' '.join([token.split('_')[0] for token in subj.split()]), 
                    ' '.join([token.split('_')[0] for token in objs[0].split()]))])
            
    return predicates.most_common()

# %%
examples['зависит от']
# Out:
# {('очень многое', 'людей от человеческого фактора'),
#  ('эпигенетическое наследование ребенка',
#   'объективных факторов стресса например количества дней проведенных без электричества'),
#  ('толщина ленточного фундамента', 'используемого материала'),
#  ('Решение', 'вероятности повторной госпитализации. &gt'),
#  ('качество его сборки', 'выбора производителя и страны где он изготовлен'),
#  ('биение сердца', 'количества кислорода в баллонах для дыхания'),
#  ('львиная доля успеха',
#   'верного расчета материалов и опыта не только строителей но и офисных менеджеров'),
#  ('твое настроение', 'скорости'),
#  ('цена которого', 'фронта предстоящих работ и применяемых средств'),
#  ('ввод текста', 'контекста'),
#  ('167 Наступление половой зрелости Наступление половой зрелости у крупного рогатого скота',
#   'скороспелости животных'),
#  ('уборка', 'наличия на двери соответствующей таблички'),
#  ('состав которого',
#   'концентрации кислоты например Fe + 4HNO3 = Fe( NO3)3 + NO + 2H2O.'),
#  ('ее написание', 'того в каких условиях вы работаете'),
#  ('80 процентов успеха',
#   'правильного сбалансированного питания и здорового образа жизни'),
#  ('померанского шпица', 'многих факторов влияющих на ее формирование'),
#  ('стоимость заказа',
#   'состава и типа коллагена удаленности вашего региона от Москвы'),
#  ('деление на возрастные категории', 'Положения о соревнованиях'),
#  ('применение этих методов и рекомендаций',
#   'сочетания конкретных обстоятельств условий'),
#  ('возможность нанесения', 'цвета футболки ТОЛЬКО белые футболки'),
#  ('работа офиса', 'многих составляющих'),
#  ('срок исполнения заказа', 'времени поступления заявки и объемов работ'),
#  ('доступность номеров', 'их наличия'),
#  ('30Все', 'того зачем вам назначили БАДы и что вы от них ждете'),
#  ('цена на которых', 'пола и чистоты родословной'),
#  ('женская красота',
#   'умения ее обладательницы одеваться краситься и следить за собой'),
#  ('ширина ремня и форма пряжки', 'выбранной одежды'),
#  ('стоимость заказа',
#   'следующих факторов размеров и количества изделий материала необходимости дополнительных услуг таких как разработка дизайна продукции изготовление крепежа и декоративных элементов монтаж и доставка а так же от срочности производства'),
#  ('очень многое', 'правильности проведения работ'),
#  ('стоимость страховки',
#   'марки модели года выпуска транспортного средства наличия на нем противоугонной системы возраста и стажа владения для физических лиц и в среднем составляет от 4,5 % до 10 % от страховой суммы стоимости транспортного средства'),
#  ('промежуток времени доставки',
#   'места вашего нахождения и от размера заказа'),
#  ('процесс',
#   'очень многих факторов размера дерева вида дерева желаний мастера и его возможностей'),
#  ('уровень', 'возраста'),
#  ('смысл которых', 'местного законодательства'),
#  ('их специализация', 'питания'),
#  ('разрешение RICH-детекторов',
#   'целого ряда причин среди которых общей является хроматическая дисперсия среды радиатора зависимость её показателя преломления от длины волны'),
#  ('строение продуктов', 'соотношения количеств TEMPO и субстрата'),
#  ('эффект', 'кратности приема'),
#  ('наше будущее', 'чтения и воображения'),
#  ('цена надгробного памятника', 'следующих факторов'),
#  ('тундр', 'дыхания почвы'),
#  ('Повышение ставок ФРС', 'данных 2 21'),
#  ('количество',
#   'нескольких параметров класс напряжения ЛЭП эксплуатационные условия конструкция опор тип изолятора'),
#  ('цена на который', 'функционала который требуется'),
#  ('шпинель', 'содержания примесей различных элементов'),
#  ('цена на ковролин', 'многих факторов'),
#  ('клеить виниловые обои', 'их основы'),
#  ('успешность биографического анализа',
#   'установки на контакт общение с людьми оказавшимися в поле зрения биографа'),
#  ('доход', 'психологии трейдера'),
#  ('количество', 'сложности текстов и наличия обнаруженных ошибок'),
#  ('количество порошка', 'того какой интенсивности цвет вы хотите получить'),
#  ('длина удилища', 'дальности заброса и от глубины реки'),
#  ('цена', 'производителя'),
#  ('цена', 'Лондонской биржи металлов'),
#  ('эффективность',
#   'степени соответствия планировки полос условиям местности и от характера самих полос их высоты продуваемости и т. п.'),
#  ('вопрос', 'множества факторов'),
#  ('написание', 'суффикса'),
#  ('режим по умолчанию', 'модели коммутатора'),
#  ('подбор ассортимента нашей продукции', 'актуальных тенденций на рынке'),
#  ('сила которого', 'того сколько отнялось красных сфер'),
#  ('стоимость', 'срочности визы'),
#  ('человек', 'природы'),
#  ('количество',
#   'количества ячеек легендарного качества имевшихся в лабиринте на момент установки обновления 6.0'),
#  ('график', 'объема работ в среднем пятидневка с 10 до 18 19'),
#  ('опросов', 'материала исследования'),
#  ('роение пчел', 'того когда происходит наступления весны раннее или позднее'),
#  ('которое', 'производителя и вложенных в производство средств'),
#  ('весь мир', 'ваших советов'),
#  ('весь исход игры', 'того на сколько уда'),
#  ('Окончательная комплектация',
#   'характеристик сырья требований к выходящей продукции и условий заказчика'),
#  ('которое',
#   'входного напряжения и скважности импульсов зависящей от частоты генератора и ёмкости конденсатора'),
#  ('качество сигнала', 'частоты расположения смартфона и наушников'),
#  ('цена которых', 'многих факторов'),
#  ('такая готовность купить данный продукт',
#   'того отдает ли потребитель предпочтение этому продукту когда он сравнивает его с другими имеющимися близкими заменителями продукта и относительными ценами на них'),
#  ('брак',
#   'двух телевизоров Янв 20 2016 Знакомство в интернете Авг 19 2014 Женщина стерва Дек 17 2015 Когда придётся расстаться с подгузниками'),
#  ('Реальная скорость', 'размера файла и возможностей системы'),
#  ('консультирование',
#   'точного диагноза определения типа наследования в каждой семье и результатов молекулярно генетического тестирования'),
#  ('D', 'C'),
#  ('ширина которой', 'используемых материалов'),
#  ('дата', 'предоставления их соответствующими службами подробнее'),
#  ('трубка диаметром 16 мм Длина', 'организации слива конденсата.'),
#  ('Церковь', 'спонсоров'),
#  ('сама возможность подключения к интернету на скорости 3G',
#   'очень многих факторов расстояние до базовой станции погоды занятости слотов активности абонентов'),
#  ('единовременный кредит или возобновляемая кредитная линия ставка',
#   'срока кредитования и категории кредитополучателя'),
#  ('судьба твоей дистанции',
#   'последнего гребка или даже от последнего касания бортика'),
#  ('стоимость мокрого фасада',
#   'вида и толщины утеплителя кривизны стен здания вида финишного декоративного покрытия'),
#  ('цена', 'используемых материалов'),
#  ('точный расход горючего',
#   'мощности и объема силового агрегата и характера выполняемых работ'),
#  ('работа пиролизного котла во многом',
#   'применяемой схемы подключения при монтаже'),
#  ('цена которой', 'используемых в производстве компонентов'),
#  ('радиочувствительность',
#   'радиочувствительности тканей которые этот орган образуют'),
#  ('приватный ключ d', 'исходного сообщения P.'),
#  ('Возможность установки дополнительных кроватей', 'выбранного типа номера'),
#  ('наличие', 'изготовителя платы'),
#  ('его эффективность во многом', 'подхода исполнителя'),
#  ('отдых', 'твоего настроения'),
#  ('адаптация',
#   'многих переменных индивидуальные особенности психологические защиты и копинг немаловажная роль в процессе психологической адаптации'),
#  ('жизнь друзей и судьба Англии', 'Аллана'),
#  ('оценка свойств',
#   '«системы ценностей» то есть от их роли во мнении заказчика'),
#  ('выбор которых',
#   'действий игрокаAction Action жанр компьютерных игр в которых успех игрока в большой степени зависит от его скорости реакции и способности быстро принимать тактические решения'),
#  ('каждая из перечисленных позиций во многом',
#   'случайных и в то же время объективных факторов'),
#  ('функционал', 'используемой программы'),
#  ('эффективность которых', 'качества получаемой ими информации'),
#  ('направление которой', 'взаимного расположения кристаллов'),
#  ('размер начислений', 'тарифа'),
#  ('площадь обработки', 'размера и облиственности растения'),
#  ('изобилие или разнообразие членов более высоких трофических уровней',
#   'доступности или качества ресурсов более низких уровней'),
#  ('качество жизни рыбаков и их семей',
#   'улова который также не всегда соответствует ожиданиям жителей'),
#  ('внешние займы или -Устойчивость экономики',
#   'степени её зависимости от внешних источников финансирования для поддержания текущего потребления'),
#  ('эффективность', 'многих факторов от бюджета от'),
#  ('полярность связи',
#   'нескольких факторов от размеров атомов и ионов соединяющихся молекул от числа и характера связи уже имевшихся у соединяющихся атомов до их данного взаимодействия от типа структуры и даже особенностей дефектов их кристаллических решёток'),
#  ('цена', 'ширины'),
#  ('твердость', 'твердого согласного [л'),
#  ('которое', 'количества нанесённых ударов'),
#  ('решение толпы',
#   'случайного или подстроенного большинства которое по неведению политических тайн произносит абсурдное решение кладущее зародыш анархии в управление'),
#  ('выбор', 'цели группировки и существа'),
#  ('здоровье и снижение веса', 'уровня клетчатки в вашем ежедневном рационе'),
#  ('формула получения этой стоимости', 'специфики продукта услуги'),
#  ('прохождение которых', 'выбора игрока'),
#  ('настоящее содержание', 'производителя'),
#  ('под ключ',
#   'типа дома технологий строительства климатических особенностей региона геолого геодезических условий глубины промерзания и расположения грунтовых вод расчетных нагрузок и множества других эксплуатационных факторов'),
#  ('21М', 'набора применяемых датчиков'),
#  ('уровень цен',
#   'экономической ситуации в стране и рынков недвижимости других городов'),
#  ('стоимость', 'объема повреждений'),
#  ('«Это', 'того с каким периодом сравнивать'),
#  ('расстояние между картой и считывателем',
#   'размера антенны и электроники устройства выбор которых осуществляется производителем с учетом области их применения'),
#  ('цена безлимитного мобильного интернета',
#   'скорости и технологии передачи данных'),
#  ('9Все', 'того какой пик выберет твой противник'),
#  ('качество выполнения черновой подготовки квартиры в новостройке',
#   'строительной компании которая строила дом'),
#  ('Украина', 'поставок российского природного газа'),
#  ('чья структура', 'этого принципа'),
#  ('ген рецептора RAR', 'ретиноевой кислоты для регуляции транскрипции'),
#  ('время', 'гравитации'),
#  ('которое', 'энергии зацепления'),
#  ('контраст',
#   'условий наблюдения изменения которых могут вызвать усиление или ослабление восприятия данного цвета'),
#  ('ширина подгибки', 'вида изделия и свойств материала'),
#  ('наше здоровье', 'многих факторов'),
#  ('его стоимость', 'требований которые наши гости предъявляют к букету'),
#  ('внешний вид', 'прямого их назначения и дизайнерского решения'),
#  ('настроение человека и его работоспособность в полной мере',
#   'освещенности комнаты'),
#  ('серебра', 'установленной оценочной стоимости в которой учитывается'),
#  ('процветание страны и всей нации',
#   'состояния здоровья каждой семьи в отдельности и каждого ее члена'),
#  ('флора влагалища женщин', 'следующих'),
#  ('синтаксис регулярных выражений', 'реализации'),
#  ('группа', 'осложнений'),
#  ('частота которых', 'степени чувствительности зубов'),
#  ('эффективность Вашей подготовки',
#   'того сможете ли Вы создать условия приближенные к реальному экзамену'),
#  ('выбор', 'множества факторов'),
#  ('терапия',
#   'основного заболевания и характера нарушений сердечной деятельности'),
#  ('выталкивающая сила', 'плотности жидкости в которую опускают тело'),
#  ('вот вознаграждение и его сумма', 'хозяина телефона и его совести'),
#  ('человек', 'власти'),
#  ('обязанность повиновения',
#   'исследования её исторического происхождения из договора'),
#  ('тактика акушера и инфекциониста', 'сочетания многих показателей'),
#  ('будет стоить облигация', 'того сколько будет стоять тело облигации'),
#  ('цена', 'своевременной оплаты и от наличия иных выгодных сделок'),
#  ('результативность предпринимаемых нами усилий', 'нашего влияния на людей'),
#  ('стоимость',
#   'качества шкур меха длины самого изделия состояния на момент оценки'),
#  ('уровень интеллекта', 'языка или цвета кожи'),
#  ('планировка', 'региона и достатка семьи'),
#  ('вопрос децентрализации', 'парламента'),
#  ('дальнейшая судьба героя', 'смс голосования'),
#  ('решение', 'конкретного чиновника который рассматривает документы tibalt'),
#  ('Расчетная стоимость',
#   'максимальной розничной цены которая представляет собой стоимость пачки сигарет и папирос превышать которую не разрешено ни магазинам ни предприятиям общепита'),
#  ('мой заработок',
#   'моих ответов вам УдалитьОтветитьАнонимный2 октября 2013 г. 17 51Здравствуйте'),
#  ('масса перемещаемого груза',
#   'длины стрелы и положения стрелы крана по отношению к направлению движения крана'),
#  ('кодирование', 'времени'),
#  ('успех',
#   'того насколько точно были выявлены показания и противопоказания к работе лазером'),
#  ('..оплата больничного', 'стажа'),
#  ('успех деловых переговоров', 'уважения к собеседнику 22Июля'),
#  ('адекватный рейт',
#   'многих факторов ваших скиллов уровня владения языком доступности возможности'),
#  ('спрос', 'уровня доходов'),
#  ('состав которой', 'источника и технологии получения'),
#  ('рабочий режим устройства число положений переключателя ручного корректора',
#   'модели автомобиля'),
#  ('00это', 'порядочности покупателей'),
#  ('выбор их',
#   'Вашего кошелька и практических знаний использования различных их типов для более комфортного и быстрого выполнения работ'),
#  ('метод обнаружения ошибок', 'конкретного'),
#  ('которое', 'массы всяких факторов'),
#  ('каждый',
#   'другого которые нанесут большой вред растениям поля леса луга и т. д Математическая олимпиада в начальной школе'),
#  ('конкретная реализация этих форматов',
#   'разработки соответствующих прикладных программ'),
#  ('размер',
#   'сложности сделки например наличия несовершеннолетних альтернативы большого количества собственников или прописанных в жилье наличия живых или ипотечных денег'),
#  ('выбор', 'предшествующей гласной'),
#  ('цена перевозки груза из Китая', 'того насколько грамотно составлен'),
#  ('скорость «эфирного ветра»', 'направления в пространстве'),
#  ('влажность воздуха',
#   'температурного режима и переноса адвекции влаги с океаническими массами воздуха'),
#  ('содержание которых',
#   'текущего дня «Интригующий понедельник» «Весёлый вторник» «Сенсационная среда» «Романтический четверг» и «Звёздная пятница»'),
#  ('2015“Все', 'везения”'),
#  ('их количественный и качественный состав',
#   'интенсивности фотосинтеза условий увлажнения питания и температуры'),
#  ('летняя выживаемость',
#   'локализации опухоли гистологии состояния общего здоровья и ряда других факторов'),
#  ('работа электродвигателей асинхронного типа', 'многих факторов'),
#  ('«Победа или разгром в битве на две трети',
#   'командира и только на треть от солдат»'),
#  ('истинность которого', 'значения переменных входящих в него'),
#  ('жизнь которого', '«дороги»'),
#  ('оплата больничного', 'страхового стажа работника 60 80 или 100 %'),
#  ('«Будущность дорогой нам Греции', 'этого боя'),
#  ('успех данной борьбы', 'действий каждого из нас'),
#  ('выбор', 'ваших личных предпочтений.'),
#  ('гардин', 'многих факторов'),
#  ('цена', 'загруженности дороги'),
#  ('применение мер таможенно тарифного и нетарифного регулирования',
#   'страны происхождения товаров'),
#  ('лечение этой болезни', 'формы экземы и причины её возникновения'),
#  ('разложение', 'дозы употребленной'),
#  ('длительность эффекта', 'особенностей зоны инъекции'),
#  ('развитие и старение организма', 'скорости процессов обмена'),
#  ('конечная сумма',
#   'объема диагностических исследований необходимости проведения лечебных процедур выбора способа оплодотворения и дополнительных услуг например выбор пола ребенка'),
#  ('Участие инвесторов в реконструкции МКАД', 'экономической ситуации'),
#  ('Kx', 'давления'),
#  ('премии', 'тарифов соответствующей страховой компании'),
#  ('человек', 'внешних оценок окружающих его людей'),
#  ('конкретика',
#   'возраста семейного положения и количества детей на момент получения израильского гражданства'),
#  ('звук', 'источника'),
#  ('только прибыльность', 'многих факторов'),
#  ('рост которого',
#   'количества корреспондентов с которыми у пользователя имелись трансакции'),
#  ('сирот «Будущее', 'тебя»'),
#  ('оценка фильма', 'возраста'),
#  ('цена скупки золота в ломбарде', 'его состояния'),
#  ('налоги будете платить',
#   'выбранной вами системы налогообложения и от наличия или отсутствия наемных работников'),
#  ('сумма кредита',
#   'среднемесячного дохода заемщика за последние шесть месяцев'),
#  ('таких штор', 'многих'),
#  ('определение геодезической линии', 'типа пространства'),
#  ('результат которого', 'многих факторов в том числе от доступности сайта'),
#  ('тип нашего перерождения',
#   'кармы от разных привычек которые мы создали компульсивным поведением'),
#  ('высота кирпичных столбов', 'высоты забора'),
#  ('цена вопроса', 'курса фунта'),
#  ('пол будущего ребенка', 'возраста матери'),
#  ('влияние ТН на детей', 'того как они применяются'),
#  ('их выбор', 'выбора вех развития'),
#  ('эффективность вычисления хламидии с помощью ПЦР', 'целого ряда условий'),
#  ('реализация которой', 'нашего'),
#  ('т.к. она', 'объёмов'),
#  ('скорость появления монстров',
#   'того включён ли «мирный» режим в общих настройках для всех сохранений'),
#  ('цена Биг-Бэги',
#   'многих параметров таких как степень загрязненности и технического состояния'),
#  ('стоимость которого',
#   'размера группы продолжительности рыбалки и необходимого количества летных часов вертолета'),
#  ('выбор которых', 'мощности потребления электроэнергии'),
#  ('разная', 'объема'),
#  ('ресурс системы', 'качества жидкости теплоносителя'),
#  ('прибыль', 'ваших продаж'),
#  ('увеличение или уменьшение мощности несущего винта', 'шага винта'),
#  ('атмосферное давление', 'многих факторов'),
#  ('способность пуль',
#   'характеристик брони т.е. есть разница между простым и бронебойным патроном'),
#  ('19Все', 'человека его стремлений'),
#  ('36Всё', 'условий стрельбы'),
#  ('конструкция которой', 'вида фундамента'),
#  ('помидор', 'многих факторов'),
#  ('тяжесть которой', 'патогенного возбудителя'),
#  ('объём фильтрации и размер захватываемых частиц', 'морфологии жабр'),
#  ('цена', 'качества и стоимости самих волос'),
#  ('разрешение политического кризиса в стране',
#   'премьер-министра Арсения Яценюка'),
#  ('ставка', 'суммы'),
#  ('очень многое', 'человека'),
#  ('размер скидки', 'суммы заказа'),
#  ('каско', 'авто от программы страхования'),
#  ('цена которого', 'применяемых технологий'),
#  ('сумма',
#   'конкретной проверке о размере оплаты сообщаем заранее во время телефонного инструктажа'),
#  ('качество которых',
#   'своевременной и качественной заправки печати новыми чернилами'),
#  ('развитие событий',
#   'переговорной части процессаСпортивный директор «Крыльев Советов» Зураб Циклаури о ситуации с полузащитником команды Йоаном Молло.27 мая 2016 16 22Ильгиз Фахриев'),
#  ('завершение которых',
#   'результата проводимого судебного разбирательства или принятия законопроекта'),
#  ('европейская экономика',
#   'потребительской уверенности которая то и дело подвергается шокам таким как кризис с мигрантами или пенсионный кризис в Греции'),
#  ('потребляемая память', 'кол-ва памяти на компе'),
#  ('уровень технологического развития и экономики', 'эволюционной фазы'),
#  ('плата от 65000 и выше', 'разряда'),
#  ('число очков', 'уровня башни Зал единения и 1 Купон на материал гильдии'),
#  ('как и совершённая работа количество переданной теплоты',
#   'конкретного процесса совершённого над телом'),
#  ('размер', 'а/к'),
#  ('оно', 'вашего упорства от вашей силы воли и от вашей собственной энергии'),
#  ('глубина аксессуара', 'его размера'),
#  ('объем анализа', 'рассматриваемой информации в среднем 5 8 страниц'),
#  ('степень развития у ребенка чувства доверия к другим людям и миру',
#   'качества получаемой им материнской заботы'),
#  ('остальное', 'площади приемной ее формы и дизайна'),
#  ('ротация пве фури воина',
#   'количества противников и степени генерации ярости'),
#  ('Использование Воздушной трапеции и водных видов спорта',
#   'погодных условий'),
#  ('удача на промысле', 'лешего'),
#  ('Частота', 'значения в TACCR0 и состояния пред-делителя IDx'),
#  ('успех любой организации', 'правильного выбора партнера'),
#  ('успех операции', 'коллективной работы'),
#  ('дата',
#   'наличия заказанных Товаров на складе Продавца и времени необходимого на обработку Заказа'),
#  ('применение', 'того какие страны сделают их обязательными'),
#  ('написание',
#   'лексического значения слова лексического значения Чередование гласных в корнях 8'),
#  ('стратегия', 'указаний политики'),
#  ('удаленная через удобный личный кабинет на сайтеГрафик работы свободный при условии выполнения работ в срокОплата по факту выполнения задания еженедельная Уровень зарплаты',
#   'количества выполненных заданий и вашей квалификации'),
#  ('количество', 'ширины зеркала и от числа крепежей на нем'),
#  ('стоимость', 'количества проверок автомобиля'),
#  ('цена на модели', 'множества факторов'),
#  ('и решение проблемы', 'сельского хозяйства'),
#  ('сумма', 'финансовых результатов холдинга по итогам этого года'),
#  ('общее решение', '6/г произвольных скалярных постоянных'),
#  ('стоимость растаможки авто', 'нескольких параметров'),
#  ('статус в котором', 'манеры поведения девушек'),
#  ('срок', 'характера приобретения участка'),
#  ('Минимум', 'способностей'),
#  ('сечение', 'этажности дома и других особенностей проекта'),
#  ('величина которой', 'раунда'),
#  ('несущая способность сваи', 'жесткости лопасти на ее прогиб'),
#  ('их расположение', 'коэффициентов k и b'),
#  ('результат', 'слаженности действий медицинских и социальных служб'),
#  ('оно', 'оборудования и технологий применяемых при изготовлении продукции'),
#  ('сумма переплаты', 'суммы кредита и срока кредитования'),
#  ('новое бронирование', 'доступности номеров'),
#  ('содержание силимарина',
#   'погоды и почвы в районе культивирования расторопши'),
#  ('цена', 'количества материалов которые используются'),
#  ('выбор которой', 'желания тренера и гимнастки'),
#  ('выбор которых',
#   'выделенного возбудителя и его чувствительности к антибиотикам.'),
#  ('Стоимость товара', 'объема Вашего заказа'),
#  ('целесообразность их применения', 'конкретной игровой ситуации'),
#  ('привлечение его к ответственности',
#   'того действовал ли член совета директоров при исполнении своих обязанностей разумно и добросовестно то есть проявил ли он заботливость и осмотрительность которые следует ожидать от хорошего руководителя и принял ли он все меры для надлежащего исполнения своих обязанностей'),
#  ('на счет широкого канал', 'аудитории которая будет смотреть видео'),
#  ('победа над взяточничеством', 'политической воли президента'),
#  ('как и все проводные машинки CM 2000', 'напряжения в сети'),
#  ('время работы', 'настроек разрешения съемки'),
#  ('интеллектуальное развитие ребенка', 'того насколько он развит физически'),
#  ('выбор', 'цены и доступности материалов'),
#  ('длительность', 'даты совершения покупки'),
#  ('цена', 'размера'),
#  ('течение и прогноз эндометрита', 'лечения'),
#  ('стоимость',
#   'количества запрошенных показателей по каждому материалу степени сложности'),
#  ('Количество штук', 'размера выбранной сковороды'),
#  ('скорость работы GPRS', 'следующих параметров'),
#  ('цена', 'квалификации мастера см. прейскурант «Запись»'),
#  ('срок',
#   'перепадов температуры ее средне-годичного значения и других факторов'),
#  ('качество которых',
#   'технических параметров самого металла и надежности сварного шва'),
#  ('ее сила',
#   'зрения слуха и концентрации внимания на повреждающий фактор т. е. эмоциональное состояние'),
#  ('оформить аптекарский огородДизайн ароматного садика',
#   'выделенной ему площади и вашей фантазии'),
#  ('гамильтониан этой системы', 'параметров'),
#  ('цвет глаз', 'макияжа и освещения'),
#  ('время',
#   'состояния и возраста батареи а также от потребляемой мощности включаемой аппаратуры 220 вольт'),
#  ('надежность АКПП', 'ее правильной эксплуатации'),
#  ('ставка',
#   'вида двигателя его мощности и возраста авто НДС 20 % от стоимости увеличенной на сумму пошлины и акциза'),
#  ('эволюция которой',
#   'приспособления данной культуры к определенным экологическим условиям'),
#  ('эффект Терафлекса', 'стадии гонартроза'),
#  ('отображение версии', 'экзешника'),
#  ('предпочтительная пища', 'сезона и географического района'),
#  ('которое', 'содержания в растворе белков'),
#  ('В12 и длительность пребывания каждой отдельно взятой молекулы В12 в организме',
#   'множества факторов'),
#  ('его внешний вид', 'раунда через который игрок попал на «Special Stage»'),
#  ('дата начала Лосар', 'часовых поясов'),
#  ('размер полового члена',
#   'размеров пористых тканей полностью заполненных кровью'),
#  ('выбор сорта которых', 'свойств ингредиентов входящих в состав порошка'),
#  ('цена которого', 'марки металла и разновидности сдаваемых изделий'),
#  ('стоимость', 'размера сложности стилистики использования'),
#  ('действие левотироксина',
#   'его дозировки так в малых дозах он способен оказывать анаболическое действие в средних влияет преимущественно на клетки и ткани'),
#  ('конструкция',
#   'допустимой мощности двигателя и его типа для каждого вида лодок'),
#  ('стоимость приобретения',
#   'удаленности населенного пункта размера партии товара его модели и др'),
#  ('все могущество', 'итогов торгов нефтью в Лондоне'),
#  ('проблема адаптации внутреннего биологического будильника человека',
#   'многих психологических и поведенческих особенностей'),
#  ('коэффициент усиления по напряжению',
#   'соотношения сопротивлений резисторов'),
#  ('человеческое здоровье', 'качества потребляемой воды'),
#  ('решение которых',
#   'другого структурного подразделения компании либо сотрудника'),
#  ('прогноз заболевания и исход', 'выраженности анатомических изменений'),
#  ('её название', 'модели'),
#  ('сила навыка',
#   'интервала между реакцией и её подкреплением а также от интервала между условным раздражителем и реакцией'),
#  ('тактика', 'размеров опухоли'),
#  ('профилактика холеры',
#   'доступа к безопасной воде и надлежащей санитарии для предотвращения контакта с инфекцией и прерывания ее передачи'),
#  ('состояние', 'физических условий в которых'),
#  ('законность которого', 'Национального собрания'),
#  ('решение политического кризиса на Украине',
#   'ЯценюкаТема Вопрос об отставке правительства Украины 150 12 0010.03.201643749018 © РИА Новости'),
#  ('стоимость',
#   'выбранного вами препарата способа его введения и длительности срока кодирования'),
#  ('размер сделок', 'некоторых других условий'),
#  ('не только первенство', 'соборности'),
#  ('состав которых', 'характера боевой деятельности обеспечиваемых кораблей'),
#  ('содержание дряни',
#   'компонентов способа приготовления и радиуса кривизны рук'),
#  ('стоимость штукатурных работ',
#   'высоты рабочей поверхности свыше 3.2 м коэффициэнт 1,15'),
#  ('состав воды', 'отложений минеральных солей на дне русла'),
#  ('масса', 'скорости'),
#  ('размер шапок', 'сезона на планете'),
#  ('цена', 'страны проведения той или иной гонки выбора места на стадионе'),
#  ('эффективность', 'климатических условий'),
#  ('ввод лицензии Порядок ручного ввода лицензии КриптоПро',
#   'установленной версии криптопровайдера'),
#  ('ответить многое', 'того насколько интенсивно поливаете.'),
#  ('решение', 'представителя ОБСЕ в контактной группе Мартина Сайдика'),
#  ('цена на неё', 'выбранного вами материала и необходимого вами количества'),
#  ('величина Ant', 'числа разбиений дуги на участки и от выбора точек деления'),
#  ('логика процедуры выборки данных', 'физической организации этих данных'),
#  ('прежде всего срок службы ковра',
#   'его качества которое в свою очередь определяется следующими основными критериями технология изготовления плотность материал метод окраски и особенности красящих веществ'),
#  ('заработок несовершеннолетнего', 'региона и режима'),
#  ('цена', 'таких факторов'),
#  ('эффективность жироулавливающего фильтра', 'его чистоты'),
#  ('их достичь',
#   'методов которые вы будете применять личного таланта и упорной работы'),
#  ('количество и диаметр проволок', 'марки производимого провода ПВС'),
#  ('часть потребительских свойств окон', 'правильно выполненного монтажа'),
#  ('решение задачи', 'типа орбиты по которой движется тело'),
#  ('выбор регионального центра', 'места жительства участника'),
#  ('выход связи «Tele2» в Московском регионе',
#   'выдачи лицензии Министерством связи'),
#  ('оценка', 'оценки компонента получившего наихудшие результаты'),
#  ('температура в квартире', 'ряда факторов'),
#  ('локализация которой',
#   'того какой именно межпозвоночный диск максимально поврежден'),
#  ('впечатление об аромате', 'личных предпочтений'),
#  ('Достижение целей устойчивого развития', 'успешной борьбы с голодом'),
#  ('ход которой', 'действий стрелка'),
#  ('нормальное атмосферное давление', 'разных факторов'),
#  ('метрика', 'гласных'),
#  ('раб. дней 580 грн )за 1 документ Стоимость всего заказа',
#   'выбранной пересылки Пересылка заказным письмом Укрпочтой 70 грн около 14 раб дней'),
#  ('погиб крутизна ложи', 'расстояния между ключицей и глазом стрелка'),
#  ('степень предсказуемости образования формы множественного числа и ее семантики',
#   'лексико грамматического разряда в который входит данное имя существительное'),
#  ('устойчивость власти и самого государства',
#   'одного важнейшего фактора доверия людей к органам власти'),
#  ('армия',
#   'народа там рано или поздно оказывается что правительство зависит от армииСамое популярное0 Разоблачение от историка'),
#  ('разница', 'вида топлива применяемого в качестве источника энергии'),
#  ('объем анализа', 'рассматриваемой информации в среднем 1 2 страницы'),
#  ('объём', 'выбранного тарифного плана'),
#  ('использование домашней птицы', 'вида возраста и упитанности'),
#  ('успех этого процесса',
#   'совершенствования законодательной базы и государственных инвестиций'),
#  ('секс', 'женщины'),
#  ('их действие', 'окружающей обстановки и настроения'),
#  ('время', 'размера свеклы'),
#  ('выполнение тамэсивари', 'следующих факторов'),
#  ('отдача', 'соотношения калибра и массы ружья'),
#  ('сумма ваших средств в белорусских рублях',
#   'изменения его курса установленного Нацбанком'),
#  ('выраженность которых',
#   'концентрации магния в крови снижение артериального давления тошнота рвота угнетение центральной нервной системы снижение рефлексов изменения на электрокардиограмме угнетение дыхания кома остановка сердца и паралич дыхания анурический синдром'),
#  ('выбор', 'ваших потребностей'),
#  ('время', 'трафика'),
#  ('сила гравитации', 'плотности и давления материи во Вселенной'),
#  ('стоимость доставки',
#   'габаритов и веса товара адреса доставки и выбранного Вами способа доставки'),
#  ('твое настроение', 'настроения другого человека'),
#  ('качество которого', 'отношения'),
#  ('потенциал развития ее', 'уровня вашей преданности идее'),
#  ('влияние тестостерона на метаболические процессы',
#   'его выработки а также от стимуляции или подавления функции специфического клеточного рецептора следовательно усиление метаболического воздействия гормона'),
#  ('Вермокс для детей', 'вида заболевания'),
#  ('длительность лечения', 'характера и тяжести заболевания'),
#  ('которое', 'решения Форекс как сегодня'),
#  ('вес торта', 'количества ярусов в нем'),
#  ('цена которого', 'марки производителя и эксклюзивности дизайна'),
#  ('поведение тела', 'глубины'),
#  ('его значение', 'того что происходило и что происходит в вашей жизни.'),
#  ('количество', 'параметров выпускных отверстий устанавливаемых заказчиком'),
#  ('цена', 'характеристик'),
#  ('широта', 'площади торгового центра'),
#  ('цена на обслуживание',
#   'сложности работ и стоимости необходимых для замены запчастей'),
#  ('ослабление',
#   'множества факторов среди которых диссоциативная анонимность невидимость асинхронность солипсическая интроекция диссоциативное воображение минимизация власти а также личные качества пользователя'),
#  ('только одно температура нагрева', 'нагревателя'),
#  ('комфортность ее в большинстве случаев',
#   'того какие тона или оттенки ее характеризуют'),
#  ('которое',
#   'размера формы и оптических характеристик пылинкиKorsun Pavlo P. Kulyk Irina V Ivanova Oleksandra V Afanasiev Viktor L Kugel Francois Rinner Claudine Ivashchenko Yuriy M. Dust tail of the active distant Comet C 2003 WT42 LINEAR studied with photometric and spectroscopic observations Icarus'),
#  ('положение пациента', 'места постановки горчичников'),
#  ('сумма', 'доходов Нобелевского фонда в текущем году'),
#  ('поведение её зятя', 'греха'),
#  ('красивый внешний вид', 'внутреннего здоровья'),
#  ('выбор модуля экзамена IELTS', 'целей преследуемых при сдаче теста'),
#  ('1 раб день 290 грн. 2 3 раб дня 250 грн.6 7 раб дней 190 грн. Стоимость всего заказа',
#   'выбранной Вами пересылки и адреса доставки'),
#  ('стоимость', 'условий жилья месторасположении'),
#  ('здоровье', 'состояния головного мозга'),
#  ('её «наполняемость»', 'разработчиков'),
#  ('расположение', 'операционной системы'),
#  ('контракт Слуцкого', 'игры сборной на ЕвроПрезидент РФС'),
#  ('рост вашего государства на прямую', 'того насколько сильна ваша армия'),
#  ('выбор которой', 'ваших пожеланий и предпочтений'),
#  ('площадь сечения заземляющего проводника', 'задач выполняемых заземлителем'),
#  ('длительность доставки', 'региона России в котором проживает наш клиент'),
#  ('цена на которую', 'толщины металла и других показателей'),
#  ('их количество', 'величины контейнера'),
#  ('потребления ОЗУ', 'типа системы'),
#  ('эффективность добычи',
#   'множества факторов в каждом регионе газосланцевая добыча будет развиваться с разной скоростью показывая значительную зависимость от рынка'),
#  ('получение справки об отсутствии судимости в большинстве случаев',
#   'правильно заполненных документов которые подаются в органы внутренних дел'),
#  ('птенцов', 'мнения самки о своем муже «Элементы» 23.03. 2009'),
#  ('размер которой',
#   'категории от степени тяжести преступления за которое лицо отбывает наказание'),
#  ('длительность нахождения в котором',
#   'расстояния в пространстве и времени до точки назначения'),
#  ('соотношение их',
#   'марки цемента фракции и влажности песка и щебня а также небольших количеств добавок пластификаторы гидрофобизаторы и т. д.'),
#  ('43 Galina Cfnc 01 35 в Америке кофе', 'покупателя'),
#  ('формат файла', 'установленного приложения'),
#  ('величина спроса на деньги', 'следующих от абсолютного уровня цен'),
#  ('количество воды', 'объема горшка'),
#  ('жизнеспособность которого', 'двух источников подписки и рекламы'),
#  ('успех брокерской компании', 'того насколько она уникальна по'),
#  ('успех команды',
#   'того как мы выдержим напряженный график «Кубка Третьяка» после тяжелейшего международного турнира в Латвии где мы недавно заняли второе место»'),
#  ('сила притяжения', 'положения корабля'),
#  ('трактовка произведения',
#   'школы или того направления которого придерживается ученый Э. Гловер'),
#  ('состояние общества', 'того как чувствует себя отдельно взятая семья'),
#  ('в «пальцевом алфавите»', 'знаков в алфавите языка'),
#  ('потребность', 'возраста массы тела от пола и энергозатрат'),
#  ('преподавание', 'уровня квалификации преподавателей'),
#  ('успешное продвижение', 'многих факторов'),
#  ('качество связи', 'полосы пропускания у соединяющихся абонентов'),
#  ('ваше благополучие', 'ваших собственных решений'),
#  ('ширина такого аксессуара', 'ширины лацканов пиджака'),
#  ('наступление которых', 'воли и сознания людей'),
#  ('состав зерна',
#   'вида и сорта растения почвенно климатических условий агротехники'),
#  ('внутреннее оборудование', 'требований заказчика'),
#  ('Остальное',
#   'автошколы и инструктора который за вождение будет требовать бабки так что в среднем около 400 лат'),
#  ('глубина лотка', 'того сколько кошек им'),
#  ('узор', 'личности мастера'),
#  ('доходность',
#   'выбранного инвестиционного инструмента отдельные ПАММ- счета'),
#  ('количество их', 'того что считать массовым вымиранием'),
#  ('достаточно интересные впечатление', 'твоего характера'),
#  ('действие',
#   'путей введения лекарственного вещества и его способности проникать через биологические барьеры'),
#  ('назначение которых', 'типа содержащегося вещества'),
#  ('процент', 'того сколько времени деньги пролежали на депозите'),
#  ('длина его на прямую', 'глубины спуска погружной части УЭЦН'),
#  ('результаты выбора языка программирования', 'того как он делался'),
#  ('расчет которого', 'такого получения'),
#  ('длительность прохождения которого',
#   'объема необходимого Вам дополнительного обследования'),
#  ('5 раб дней 540 грн.6 7 раб дней 500 грн. Стоимость всего заказа',
#   'выбранной Вами пересылки и адреса доставки'),
#  ('состояние собаки', 'скорости развития процесса'),
#  ('44ответитьссылка 0. 2', 'пары иммунитета и даже отношения'),
#  ('интернет магазина', 'качества его дизайна степени'),
#  ('уровень глюкозы в крови',
#   'работы поджелудочной железы который выделяет инсулин при приеме пищи'),
#  ('величина',
#   'двух параметров сопротивление спирали испарителя и напряжения электрического тока которое поступает на эту спираль'),
#  ('Эффект', 'класса персонажа'),
#  ('свободный рынок', 'влияния шока четыре года назад'),
#  ('продолжительность эффекта',
#   'индивидуальных особенностей человеческого организма'),
#  ('стоимость покраски',
#   'стоимости используемой краски и сечения пиломатериалов'),
#  ('количество отраженного света',
#   'поперечного сечения проекции формы пылевой частицы а следовательно пропорциональна квадрату её радиусаDavid J. Lien Optical properties of cometary dust Scientific Report'),
#  ('степень выражения в большинстве случаев',
#   'индивидуальных характеристик от несоблюдения диеты и недостаточном количестве физических нагрузок'),
#  ('сама', 'противоугонной системы автомобиля на схеме 33'),
#  ('определение', 'типа изучаемой кривой'),
#  ('их появление', 'состояния вашей иммунной системы'),
#  ('оно', 'погодных условий'),
#  ('тип и частота поддерживаемой памяти', 'установленного ЦПУ'),
#  ('доход', 'объемов трафика проходящего через'),
#  ('данное разделение', 'ее назначения'),
#  ('трудность её разгадывания',
#   'множества факторов размера головоломки количества слов одинаковой длины и с похожими буквами количества отвлекающих слов есть и такие в которых количество слов превышает то которое может вместить сетка кроссворда и т. п.'),
#  ('цена дизайна интерьера', 'множества факторов'),
#  ('Ваше благополучие', 'Ваших собственных решений'),
#  ('осаго', 'вида вашего автомобиля5'),
#  ('выигравший и размер которой', 'суммы'),
#  ('стоимость', 'Вашего места расположения'),
#  ('Содержание и методы финансового анализа хозяйствующего субъектаКачество принимаемых управленческих решений на уровне хозяйствующего субъекта',
#   'качества их аналитического обоснования'),
#  ('набор способов оплаты', 'страны и региона'),
#  ('ширина которых',
#   'габаритов транспортных средств и грузоподъемных кранов обслуживающих склад'),
#  ('размер процентной ставки и наличие комиссий', 'кредитной истории'),
#  ('характерная выразительность', 'их точного положения по бокам головы'),
#  ('размер бигуди',
#   'выбора клиента от его желания иметь крупные романтичные локоны или легкие мелкие кудряшки'),
#  ('«Настроение мужчины', 'женщины'),
#  ('состав', 'целей которые преследует пациент'),
#  ('цена', 'способа исполнения и материала'),
#  ('именно проверять а что нет полностью',
#   'организации пожелавшей провести у себя проверку'),
#  ('Способ оплаты', 'выбранного атрибута'),
#  ('цена', 'того что Вы придумаете с нашим дизайнером'),
#  ('уровень которой',
#   'комфортабельности жилья например это может быть 3,5 м куб на каждого прописанного жильца'),
#  ('рождение нормальных здоровых детей',
#   'оптимального питания родителей не только во время беременности но и до зачатия'),
#  ('положение точки росы', '5–ти факторов описанных в части выше'),
#  ('прочность трона', 'дворян'),
#  ('стабильность предприятия',
#   'обеспеченности сохранности и приумножения собственного капитала эффективности использования оборотных активов и кредитов банка'),
#  ('успех любой программы',
#   'очень многих составляющих и прежде всего от команды'),
#  ('цена', 'расстояния'),
#  ('цена',
#   'множества факторов весогабаритных параметров груза расстояния между пунктами погрузки и разгрузки и др'),
#  ('выбор его', 'вкуса и замысла застройщика'),
#  ('цена которого',
#   'различных факторов фирмы производителя объема септика стоимости работ по установке и т.д'),
#  ('статус потенциальной сверхдержавы Евросоюза', 'его «державности»'),
#  ('терапия', 'остроты процесса и характера элементов сыпи'),
#  ('выходной ток которого', 'входного напряжения'),
#  ('его сумма', 'тяжести нарушения'),
#  ('их целостность', 'наличия'),
#  ('стоимость', 'расположения курорта'),
#  ('оно', 'духовки'),
#  ('его значение',
#   'типа и размера используемого шарикового подшипника и конкретных условий работы'),
#  ('любая пенсионная система',
#   'соотношения между трудоспособными и пожилыми людьми то есть от демографической структуры населения'),
#  ('денежный доход',
#   'количества различных материальных и людских ресурсов поставляемых получателем дохода на рынок и от цен по которым эти ресурсы могут быть проданы на ресурсном рынке'),
#  ('оформление этого стенда', 'пожеланий и предпочтений клиента'),
#  ('финальное ценовое предложение',
#   'выбранной вами комплектации размера полотна и т. д'),
#  ('ставка',
#   'того на что вы используете полученные деньги в качестве первоначального взноса на вторичку ставка начинается от 15,50 %'),
#  ('доза препарата', 'степени тяжести заболевания'),
#  ('цена за м2 которой', 'формы размера цвета и вида полимерного покрытия'),
#  ('скорость доступа в Интернет', 'пропускной способности Вашего роутера'),
#  ('прирост веса и роста',
#   'многих факторов от начального роста и веса от генетической предрасположности и т.д.'),
#  ('густота теста', 'масла'),
#  ('где?', 'того -тока'),
#  ('картина и её выраженность',
#   'того где образовалась киста и на какой участок головного мозга она оказывает давление'),
#  ('вкус пирога', 'вкуса выбранного вами мармелада'),
#  ('их выраженность', 'таких психологических факторов'),
#  ('таких штор', 'многих.'),
#  ('Общество Вопрос свободы религий в Беларуси', 'политической воли властей'),
#  ('стоимость буксировки грузового транспорта',
#   'расстояния между конечными пунктами и сложности работы'),
#  ('время выполнения заказа',
#   'сложности пароля и наличия дополнительных данных о владельце страницы'),
#  ('ширина', 'способа сидения на ней'),
#  ('perlxxxx.msi x x xx', 'версии Perl'),
#  ('звёздное время', 'вращения Земли'),
#  ('обеспечение поручительство и до 1 млрд руб для всех вариантов обеспечения ставка',
#   'срока кредитования рассмотрение 4 дня'),
#  ('наличие расширения', 'величины этого взаимодействия'),
#  ('цена которой', 'объемов и сложности работ'),
#  ('теплая вода', 'внешней температуры солнца'),
#  ('фактор', 'стадии роста анагена каждого вида волос'),
#  ('и содержимое БАД', 'их производителя'),
#  ('интенсивность испарения', 'относительной влажности окружающего воздуха'),
#  ('наличие номенклатуры продукции и объемов на электронной торговой площадке ONLINECONTRACT',
#   'производственной программы производителя'),
#  ('слота',
#   'числа абонентских каналов обслуживаемых мультиплексором или коммутатором'),
#  ('точка их разделения', 'распределения нагрузки в кольце'),
#  ('количество раствора',
#   'размера стеновых материалов для обычного глиняного кирпича на 1м2 кладки расходуется около 110л раствора'),
#  ('эффект',
#   'расслабления волокон круговой мышцы радужной оболочки которая иннервируется парасимпатическими волокнами'),
#  ('жизнь', 'наших желаний и стремление к ним'),
#  ('пакет для вакуумирования рабочей трубы состоящий из промежуточного элемента для выхода газа шарового крана манометра управляемого вручную вакуумного насоса с поворотным краном подсоединенным к выходу газа посредством стального гофрированного шланга макс достижимое конечное давление в рабочей трубе',
#   'типа насоса'),
#  ('цена', 'размера техники'),
#  ('с Манчестер Юнайтед', 'одного условия Longball Gloriosнo'),
#  ('причем результат', 'того какой из потоков попадет к нему первым'),
#  ('скорость', 'которого'),
#  ('время приготовления', 'качества мяса'),
#  ('продолжительность', 'выбранной специальности'),
#  ('количество', 'числа фракций применяемых при приготовлении смеси'),
#  ('таких штор', 'многих факторов'),
#  ('цена которой', 'множества факторов'),
#  ('выбор которых',
#   'Ваших предпочтений и функционального назначения каждого типа кенгурятника'),
#  ('гипнотический эффект', 'наличия или отсутствия раппорта'),
#  ('качество урожая во многом', 'состояния растений отсутствия % hits'),
#  ('его работа', 'качества телефона'),
#  ('течение дифиллоботриоза',
#   'интенсивности инвазии и индивидуальных особенностей организма больного'),
#  ('Активность разных частей мозга человека', 'времени года'),
#  ('биодоступность которых', 'показателей рН желудочного сока'),
#  ('О2', 'региона'),
#  ('и требующийся на это объем денег', 'человеческой психологии'),
#  ('«тепловой поток',
#   'потерь тепла на наружных ограждениях которые прямо пропорциональны разности между температурой наружного воздуха Т1 и температурой Т внутри помещения площади S обогреваемого помещения коэффициента теплопотерь м2 К)»'),
#  ('«правильность»', 'точки зрения и целей стороны сражения информации'),
#  ('уровень оплаты', 'количества выполненных Вами оценок от 30 оценка'),
#  ('изготовление металлоконструкций', 'использованных сплавов металлов'),
#  ('21все',
#   'разновидностей плаща вернее складок на плаще у Георгия Победоносца'),
#  ('всецело', 'пищи'),
#  ('внешний вид', 'слаженной работы внутренних органов и систем'),
#  ('Выбор', 'специфики деятельности компании'),
#  ('ток', 'скорости изменения наводящего тока и его величины'),
#  ('их наличие или отсутствие', 'качества сборки телевизора'),
#  ('эффективность лечения урологических заболеваний в большинстве случаев',
#   'своевременного обращения к профильному врачу'),
#  ('сельское хозяйство', 'воды'),
#  ('внешность', 'наследственности'),
#  ('исход', 'характера'),
#  ('состояние человека', 'его кредитной истории доходов'),
#  ('температура воды', 'завариваемого чая'),
#  ('этот вопрос', 'слишком большого количества привходящих факторов'),
#  ('большинство участников рынка', 'общенациональной системы'),
#  ('чердака', 'выбранных материалов дизайна и размеров'),
#  ('изделия', 'плотности ткани из которой оно сшито'),
#  ('цена', 'размеров дома и сложности работ'),
#  ('намного меньше', 'стоимости и доступности местных источников энергии'),
#  ('и качество',
#   'степени профессиональной деградации психодохтуры тоже болеют ещё как'),
#  ('размер или вместительность винного шкафа',
#   'цели его покупки и традиций использования'),
#  ('качество спермы и сперматозоидов',
#   'многих факторов в том числе и от возраста'),
#  ('высота', 'выбранной покупателем образца ткани'),
#  ('Новой Почтой от 25 грнСтоимость доставки',
#   'размера груза и суммы на которую он застрахован'),
#  ('весь проект', 'ее качества'),
#  ('Реальный английский', 'уровня с которого начинаем'),
#  ('содержание', 'кодировки'),
#  ('чистота улицы', 'мэра'),
#  ('качества', 'подхода к делу для себя или побыстрей и побольше'),
#  ('величина перепада', 'модели фильтра'),
#  ('результат', 'твоей работы'),
#  ('мир на Украине', 'того кто будет предстоятелем Церкви'),
#  ('успех шахматного всеобуча', 'конкретных людей'),
#  ('выбор',
#   'многих факторов от высоты здания наличия на участке других строений высоких деревьев интенсивности гроз в вашем регионе'),
#  ('многое в решении практических вопросов',
#   'судебной и нотариальной практики»'),
#  ('длительность цикла',
#   'количества изохронных данных асинхронных данных и количества узлов опрашиваемых в каждом цикле'),
#  ('итоговая занимаемая площадь', 'фирмы производителя и коллекции'),
#  ('его значение', 'контекста удивление удовлетворение и пр.'),
#  ('Сила циклонов', 'изменения скорости движения Земли по орбите'),
#  ('Успех футбола', 'общей работы спортсменов тренеров меценатов'),
#  ('толщина фундамента', 'используемого материала стен'),
#  ('успех лечения',
#   'того насколько полно были выявлены причины и на сколько старательно Вы следуете назначению врача'),
#  ('настроение и общее состояние здоровья', 'качества сексуальной жизни'),
#  ('Корректировка стоимости', 'месторасположения объекта'),
#  ('количество', 'конкретных условий дома и участка'),
#  ('способ крепления', 'веса предметов гарнитура'),
#  ('прогноз в октябре', 'ФРС и ЕЦБ 6'),
#  ('«Единая Россия»', 'рейтинга Владимира Путина'),
#  ('стоимость', 'комплекта документов к форме'),
#  ('плотность второго порядка', 'временных аргументов через их разность'),
#  ('перевод слова', 'контекста'),
#  ('качество сигнала передачи',
#   'ряда факторов наличия препятствий на пути прохождения сигнала влажности времени суток'),
# ...
#  ('стоимость транспортировки', 'габаритов товаров и дальности расстояния'),
#  ('сила турбопаруса', 'угла атаки и расхода воздуха через перфорацию'),
#  ('которое', 'наименьшей из ёмкостей'),
#  ('тактика', 'стадии воспалительного процесса'),
#  ('5Скорость коррозии', 'характера металла2Fe в растворе NaCl'),
#  ('продолжительность жизни человека', 'двух факторов'),
#  ('количество мяса', 'того сколько вам нужно порций'),
#  ('прочитанное значение', 'настройки active'),
#  ('стоимость которого', 'характера требуемых ремонтных работ или реставрации'),
#  ('цена', 'сложности задачи и сломанного элемента'),
#  ('Структура сообщества одноклеточных водорослей', 'источника азота'),
#  ('правительство', 'армииСамое популярное0 Разоблачение от историка'),
#  ('стоимость',
#   'объема необходимых работ для восстановления ваших деревянных дверей'),
#  ('картина', 'локализации невриномы'),
#  ('концентрация раствора', 'этапа развития растений'),
#  ('качество выполненных работ',
#   'умения каждого конкретно взятого специалиста'),
#  ('десятых нашего счастья', 'здоровья'),
#  ('сумма страховой премии по которым',
#   'перечня страхуемых рисков выбранной Клиентом программы и суммы кредита'),
#  ('цена',
#   'многих факторов бренд качество продукта функции которые выполняет компрессор для аквариума и прочее'),
#  ('одна камера точнее её объём в двукамерных мехах это количество постоянно пополняющегося воздуха и его объём',
#   'подкачки'),
#  ('оплата',
#   'количества отработанных часов в месяц + ганораров при наличии дополнительно оказанных услуг для нашей организации'),
#  ('день стоимость услуг', 'самой квартиры'),
#  ('и польза от ECN', 'правильности использования AQM'),
#  ('выбор которого', 'личных предпочтений жильца'),
#  ('меньше наше общество', 'окружающей среды'),
#  ('правильная эксплуатация',
#   'настройки механизма и работы дополнительных устройств'),
#  ('степень размытия', 'расстояния до объекта'),
#  ('концентрация которого', 'уровня сахара в крови'),
#  ('стоимость трансфера',
#   'того где заказывать машину в городе прибытия или в гостинице п Домбай'),
#  ('исход каждой отдельной азартной игры', 'случайности'),
#  ('хвоста', 'объёма сырья или болота или 150грамм это правило'),
#  ('каждой точки контура', 'цветов которые отображаются в'),
#  ('это решение', 'причин которые вызвали диарею'),
#  ('их количество и дозировки', 'индивидуальных особенностей пациентки'),
#  ('точное определение',
#   'конкретного автомобиля и насколько «качественно» скручен пробег'),
#  ('время перевода', 'скорости вашего соединения'),
#  ('матрица смежности графа', 'нумерации вершин'),
#  ('комплектация', 'модели'),
#  ('время готовки', 'вида рыбы'),
#  ('ситуация с получением Нойштедтером гражданства РФ', 'футболиста'),
#  ('снасти для ловли чехони', 'сезона'),
#  ('давление', 'поверхностного натяжения и кривизны поверхности'),
#  ('наше будущее', 'чтения'),
#  ('выбор', 'ваших возможностей.” Gala705'),
#  ('группа', 'экологии вида'),
#  ('успешное преодоление которого', 'уровня воды'),
#  ('весь результат игры', 'количества выигрышей подряд'),
#  ('дроп артов', 'региона  Форума'),
#  ('которое', 'параметров кристаллической решётка и типа структуры кристалла'),
#  ('масса которой', 'свойств гипсового'),
#  ('производительность', 'различных причин в том числе и от габаритов'),
#  ('доза Микофлю', 'природы и тяжести грибковой инфекции'),
#  ('его характер', 'условия'),
#  ('*Стоимость лечения', 'степени алкогольной интоксикации'),
#  ('цена билета',
#   'того сколько свободных мест осталось и сколько времени до отправления'),
#  ('режим', 'экологии вида'),
#  ('ИнгредиентыКабачкиЧеснокСольРастительное маслоКоличество ингридиентов',
#   'Вашего вкусаРецепт икра из кабачков оочень простая как приготовить быстро и вкусно в домашних условиях Голосуй сохраняй и делись с друзьямиМненравится28 человекоценилиСохранитьрецепт15 человексохранилиПохожие рецептыОладьи из кабачковИкра из кабачков Оладушки из кабачков на йогурте с помидорами и Геркулесом'),
#  ('высота', 'выбранного образца натуральной ткани'),
#  ('доходность', 'результатов выбранного ПАММ- счета молодой сервис'),
#  ('которой', 'класса ордена'),
#  ('цена на которые', 'ряда параметров'),
#  ('каждый из которых', 'типа поверхности'),
#  ('изменение импортных и экспортных цен при этом для санкционированной страны',
#   'конкретного рынка'),
#  ('развитие ее', 'обстоятельств желания и усилий самого человека'),
#  ('качество картинки', 'качества сигнала источника который вы смотрите'),
#  ('размер которой',
#   'системы лояльности количества приобретённых туров или поезок туриста от данного офиса'),
#  ('Цвет и прозрачность коронки', 'исходного блока'),
#  ('сечения стержней', 'мощности трансформатора'),
#  ('размер НДФЛ', 'мероприятия при проведении которого дарятся подарки'),
#  ('стоимость', 'сезона'),
#  ('пункт 1', 'контента'),
#  ('число', 'выбранного тарифного плана'),
#  ('воплощение', 'самого человека его личности внутреннего мира и поступков'),
#  ('цена', 'площади'),
#  ('активность данного организма', 'активностей его клеток'),
#  ('плата от 43000 и выше', 'разряда'),
#  ('внутреннее трение', 'температуры'),
#  ('14Морда IE', 'библиотек в Виндах которые содержат значки и прочую муть'),
#  ('насморка', 'вызвавших его причин'),
#  ('работа которых', 'геопозиции'),
#  ('Расположение насадных труб', 'места камина в помещении'),
#  ('получение GeO2', 'окисленной формы германия извлечённого из руды'),
#  ('успех',
#   'многих факторов прежде всего от профессионализма наших сотрудников от качественного оборудования и от слаженной работы'),
#  ('день вылета', 'продолжительности тура'),
#  ('окончательная стоимость', 'кол-ва человек'),
#  ('количество которых', 'типаи состава оборудования а также назначения НКУ'),
#  ('способность водостоков', 'параметров ската высоты ширины и длины'),
#  ('цена', 'размера и рамки'),
#  ('зимостойкость растений', 'множества факторов'),
#  ('выбор',
#   'того каких именно целей вы хотите достичь в итоге и каким бюджетом располагаете'),
#  ('частота перекраски таких обоев',
#   'желания их владельцев. Виниловые обои превосходно моются и чистятся и они не боятся прямых солнечных лучей'),
#  ('«Все', 'самих новичков»018 4523 июня'),
#  ('способ увлажнения', 'модели прибора'),
#  ('цена которого', 'сложности работы и стоимости комплектующих'),
#  ('сохранение нашего благополучия нашей безопасности нашей работы и нашего спокойствия',
#   'их политики'),
#  ('пробиваемость', 'типа используемой ткани'),
#  ('успешность любого бизнес -парка',
#   'того насколько людям удобно работать в нем'),
#  ('масса т тела', 'его скорости'),
#  ('время', 'дрожжей и температуры'),
#  ('оптовая скидка', 'объема заказа'),
#  ('сумма', 'длины газопровода'),
#  ('второе', 'социальных и экономических факторов'),
#  ('результат', 'условий соединения на даннй момент времени'),
#  ('удобство кровати', 'удачного сочетания всех этих составляющих'),
#  ('состав которых', 'количества осадков рельефа почв'),
#  ('Выбор', 'того куда Вы планируете идти'),
#  ('Вероятность применения',
#   'степени быдловатости носителя звания и его окружения'),
#  ('плата', 'опыта кандидата'),
#  ('стоимость', 'объема работ и зоны где необходимо вводить инъекции'),
#  ('за их поза 69', 'перенапряжения'),
#  ('качество картошки фри', 'ее сорта как ее правильно выбирать'),
#  ('которое', 'стажа минимум 15 лет'),
#  ('количество опыта', 'уровня персонажа или 8 27 на 85-м уровне'),
#  ('1. приёмник спутниковый с поддержкой HD модель приемника',
#   'выбранной акции)2 смарт-карту с включенным просмотром на 31 день телеканалов пакета «Единый» или «ЕдиныйМульти» в зависимости от модели приемника'),
#  ('оператор Гамильтона', 'времени'),
#  ('успешность использования практики для познания и для проверки оценочных выводов',
#   'образования личного практического опыта следователя судей'),
#  ('которое',
#   'величины снижения давления в ТМ и установленного на ВР режима торможения'),
#  ('стоимость реконструкции и строительства недвижимости',
#   'многих индивидуальных факторов'),
#  ('%', 'вида деятельности'),
#  ('которое', 'знаков выражения x2 x1 y2-y1 z2-z1'),
#  ('слава царей', 'их милостивого отношения'),
#  ('грамотность', 'внешних факторов'),
#  ('плотность', 'временных аргументов'),
#  ('лечение', 'формы заболевания'),
#  ('оно', 'величины овощей и от индивидуальных особенностей вашей духовки'),
#  ('цена которой', 'ее свойств размера точности и т.д.'),
#  ('количество выявленных в конкретном году заболевших',
#   'количества проведенных тестирований'),
#  ('сумма', 'вашего дохода и способа его подтверждения'),
#  ('сечение', 'вида потенциала взаимодействия двух частиц'),
#  ('Количество ЛотоБаллов заработанных за каждую покупку',
#   'себестоимости каждой ставки'),
#  ('стоимость страховки', 'требований банка'),
#  ('количество и толщина которых', 'класса ордена'),
#  ('урожай', 'многих факторов'),
#  ('стоимость капитала',
#   'стоимости его составляющих обобщенно подразделяемых на два вида'),
#  ('количество', 'длины трассы'),
#  ('ее осуществление', 'развития человека и его усилий'),
#  ('разделение на инструкции и операторы', 'языка программирования'),
#  ('очень многое', 'типа ваших волос'),
#  ('«Будущее', 'тебя»'),
#  ('соглашение', 'определенных условий которые они оба принимают'),
#  ('каждый бит начального состояния',
#   'каждого бита ключа и каждого бита инициализирующего вектора'),
#  ('цена', 'сезона и представлений'),
#  ('Траектория полета легких шариков', 'ветра'),
#  ('срок', 'банка'),
#  ('изобилие таксонов добычи',
#   'действий потребителей на высших трофических уровнях'),
#  ('эффективность применения пиявки в огромной степени', 'мастерства врача'),
#  ('тяжесть',
#   'температуры окружающей среды длительности пребывания на холоде влажности воздуха'),
#  ('объем информации', 'вида подписки'),
#  ('сателлитные РНК это небольшие одноцепочечные РНК репликация и заключение в капсид которых',
#   'вспомогательного вируса с которым однако они не имеют или практически не имеют сходства последовательностей'),
#  ('часть психологических свойств', 'физиологам'),
#  ('типоразмер резины', 'комплектации или объема двигателя'),
#  ('сила эффекта мультипликатора',
#   'предельной склонности к потреблению и сбережению'),
#  ('стоимость проектирования и строительства',
#   'сложности объекта объемов работ и сроков выполнения'),
#  ('проекта', 'того насколько авторам удастся автоматизировать процесс'),
#  ('каждое из которых',
#   'каждого или почти каждого из 3 других свойств Б1 Б2 Б3'),
#  ('высокое качество', 'качества материалов'),
#  ('стоимость', 'пакета услуг'),
#  ('жизнь всей пирамиды', 'воли одной головы и та'),
#  ('карьера журналиста', 'редактора'),
#  ('судьба Вселенной', 'скрытых космических близнецов'),
#  ('срок', 'клеящего состава'),
#  ('количество',
#   'таких факторов как диаметр конкретного понтона в соответствии с приложением Н API 650'),
#  ('желание', 'той энергии которые вы вкладываете'),
#  ('вид каждого уровня в Будущем', 'действий игрока в другом времени'),
#  ('возможность участия в некоторых событиях', 'дня недели и или погоды'),
#  ('способность стекла в значительной степени', 'его химического состава'),
#  ('2', 'дозы'),
#  ('цена', 'тиража'),
#  ('давление', 'конструкции насосной установки и свойств рабочей жидкости'),
#  ('стоимость билета',
#   'различных факторов вида поезда типа вагона сезона поездки и даже даты отправления'),
#  ('зарплата', 'размера города'),
#  ('выбор материалов', 'специалистов'),
#  ('стоимость', 'сложности рисунка 1000 3000 руб'),
#  ('пенсия', 'прожиточного минимума в стране'),
#  ('стоимость которого', 'модели коробки'),
#  ('траектория полета во многом',
#   'гравитационных сил разных космических объектов'),
#  ('цена',
#   'использованного материала металлические пряжки дороже и практичнее'),
#  ('сумма возврата', 'заработной платы'),
#  ('«Настроение мужчины', 'женщины | статьи рубрики “Звезды” | Леди Mail.Ru'),
#  ('пункт', 'задачи'),
#  ('ее декорирование', 'ваших задумок'),
#  ('общее развитие человека',
#   'физического развития физическое воспитание это залог и надежная охрана здоровья'),
#  ('оно', 'многого'),
#  ('стоимость услуги для клиента',
#   'активности использования продукта количество просмотров страниц кол-во пользователей и тд'),
#  ('судьба нормандского формата', 'позиции Украины'),
#  ('коэффициент нейтронов', 'их энергии'),
#  ('количество курсов химиотерапии ABVD',
#   'стадии заболевания наличия неблагоприятных прогностических факторов и от того насколько хорошо или плохо пациент переносит этот режим химиотерапии'),
#  ('окончательный список документов',
#   'того кем Вы являетесь поставщик изготовитель отечественный импортный'),
#  ('деликтоспособность', 'возраста и вменяемости'),
#  ('результат эксперимента', 'наблюдателя этого эксперимента'),
#  ('стоимость', 'объема заказа'),
#  ('выбор цвета', 'стиля'),
#  ('коэффициент гостей', 'времени года'),
#  ('Мощность двигателя', 'его типа объема цилиндра и тактности'),
#  ('член пропорциональный 10N и время сворачивания',
#   'много меньших по порядку величины нелинейных членов связанных с поверхностными энтальпийными и энтропийными эффектами пропорциональными N2 3'),
#  ('их стоимость', 'степени автоматизации и возможностей оборудования'),
#  ('время приготовления',
#   'того проводилась ли тепловая обработка рыбы перед тем как она попала в духовку'),
#  ('Военно техническое сотрудничество между странами', 'позиции Украины'),
#  ('динамика накопления валового азота фосфора и калия надземными массами огурцов и томатов',
#   'внесения'),
#  ('еще мггое', 'ТЗ'),
#  ('0Все', 'сложности процесса'),
#  ('облик виртуальной игры', 'её аналога в реальной жизни'),
#  ('всецело',
#   'определённых целей которые вы жаждете получить от покупки тепловизора'),
#  ('Ваша безопасность',
#   'системы пожарной сигнализации датчики которой сигнализируют о малейшем задымлении от системы автоматического пожаротушения'),
#  ('решение политического кризиса на Украине', 'Яценюка | РИА Новости'),
#  ('полезность чего-либо имеющегося', 'пустоты»'),
#  ('практически каждый аспект современной жизни',
#   'целостности надежности и эффективности компьютерных сетей от личного общения с функционированием мировой экономики'),
#  ('Эффект',
#   'класса персонажа для персонажа класса Паладин значение навыка добавляется к боевому итогу combat total и наносимому урону если он использует клинковое оружие у персонажа класса Гладиатор навык добавляется к Классу Брони а также к боевому если он использует клинковое оружие тогда как персонаж класса Убийца добавляет треть навыка к уровню Атаки если действует одним или двумя кинжалами'),
#  ('выбор типа байка', 'тусовки'),
#  ('восприятие рекламного обращения потребителями во многом',
#   'внешнего состояния к примеру автобуса'),
#  ('цена которого', 'заказываемого объема и адреса доставки'),
#  ('его декорирование',
#   'тематики свадьбы желания новобрачных и даже времени года'),
#  ('Судьба сообщества', 'способности особей предвидеть чужие поступки'),
#  ('величина этого показателя', 'характера помещений разделяемых перекрытием'),
#  ('абсолютно всё',
#   'того сколько звёздочек рандом изволил дать правителю и тд и тп.'),
#  ('цена', 'срока действия'),
#  ('успех продвижения', 'использования модуля ПФ'),
#  ('«все', 'того насколько их проект разрешит задачу движения»'),
#  ('удовлетворенность отношениями',
#   'сравнения нашего партнера с другими мужчинами или женщинами которые потенциально могли бы занять их место'),
#  ('жизнь многих', 'исхода этого матча'),
#  ('цена', 'объема мусора'),
#  ('национальность', 'того места где человек проживает'),
#  ('[M Боевик Кинохит Детский Комедия Драма Ужасы Экранизация Культовое кино Романтика Военное кино Классика и другие список каналов',
#   'страны'),
#  ('успех обнаружения лодки',
#   'погодных условий и времени когда был оставлен «хвост»'),
#  ('шаг его установки', 'высоты ограждения'),
#  ('будущее проектов', 'конструктивности позиции Еврокомиссии'),
#  ('ли пропадать экран', 'модели'),
#  ('наше будущее', 'чтения и воображения.'),
#  ('девушки', 'автомобиля'),
#  ('сила психической травмы',
#   'индивидуальной значимости травмирующего события для человека степени его психологической защищенности силы духа и устойчивости к ударам судьбы'),
#  ('стоимость услуг',
#   'заказанного пакета от того какой помощью нотариуса вы воспользовались'),
#  ('5 15 %', 'региона'),
#  ('принятие решения об инвестировании', 'направления движения рынка акций'),
#  ('спрос', 'цены'),
#  ('«паразитом» и его дальнейшее выживание', 'близнеца «хозяина»'),
#  ...}

# %%
predicates.most_common()
# Out:
# [(', в', 5614),
#  ('можете с', 5366),
#  ('находится в', 5142),
#  ('стабильно получают от', 3227),
#  ('состоит из', 3222),
#  ('относится к', 2714),
#  ('зависит от', 2182),
#  ('ищем по', 2053),
#  ('включает в', 1866),
#  ('награждён орденом', 1843),
#  (', на', 1745),
#  ('находятся в', 1737),
#  ('находится на', 1705),
#  ('приводит к', 1698),
#  ('заключается в', 1589),
#  (', размещенная пользователями на eKomok является конфиденциальной', 1535),
#  ('состоят из', 1520),
#  (') находится в', 1407),
#  ('входит в', 1323),
#  ('принадлежит к', 1282),
#  ('связано с', 1169),
#  ('является частью', 1120),
#  (', с', 1119),
#  ('происходит в', 1094),
#  ('привело к', 1067),
#  ('свяжется с', 1012),
#  ('идет о', 977),
#  ('состоит в', 970),
#  ('сделаем от', 943),
#  (') в', 923),
#  ('говорит о', 912),
#  ('не скрыл их', 868),
#  ('не скрыл в', 868),
#  (', по', 824),
#  ('относятся к', 819),
#  ('попал в', 785),
#  ('принимала в', 733),
#  ('( в', 720),
#  ('поможет вам', 714),
#  ('предназначен для', 703),
#  ('участвовал в', 697),
#  ('помогут вам', 679),
#  ('работает в', 665),
#  ('будет проверен модераторомна', 662),
#  ('не имеют к', 636),
#  ('на Зайцев.нет без', 634),
#  (', при', 634),
#  ('перешёл в', 625),
#  ('работают в', 621),
#  ('связаны с', 619),
#  ('не имеют отношения', 618),
#  ('родился в', 617),
#  ('стоит на', 609),
#  ('вошла в', 606),
#  ('нет в', 604),
#  ('предназначены для', 600),
#  ('" в', 583),
#  ('вышел в', 576),
#  ('вернулся в', 570),
#  (', у', 567),
#  ('работает на', 563),
#  ('вошли в', 563),
#  ('находятся на', 562),
#  ('начинается с', 561),
#  ('находился в', 558),
#  ('отличается от', 555),
#  ('вошёл ( а ) в', 542),
#  ('подходит для', 541),
#  ('используется для', 533),
#  ('опубликована более', 530),
#  ('вошёл в', 529),
#  ('Пакет услуг', 525),
#  ('влияет на', 524),
#  ('состояла из', 519),
#  ('защищен от', 519),
#  ('" Добавлено в', 517),
#  ('попадает в', 514),
#  (', за', 511),
#  ('составляет около', 503),
#  ('привели к', 503),
#  ('используется в', 484),
#  ('нуждается в', 481),
#  ('предназначена для', 471),
#  ('работал в', 469),
#  ('пройдет в', 469),
#  ('связана с', 466),
#  ('свидетельствует о', 462),
#  (', после', 459),
#  ('получил в', 459),
#  ('помогает Вам', 457),
#  ('можете в', 456),
#  ('превращается в', 455),
#  ('приведет к', 451),
#  ('указывает на', 447),
#  ('состоялся в', 445),
#  ('используются для', 442),
#  ('погиб в', 441),
#  ('вышел на', 437),
#  ('— входит в', 437),
#  ('перейдете на', 435),
#  ('включают в', 435),
#  ('появился в', 431),
#  ('попали в', 431),
#  ('перейдете в', 426),
#  ('происходит от', 424),
#  ('произошло в', 423),
#  ('связан с', 423),
#  ('входят в', 423),
#  ('вступил в', 422),
#  ('будет размещено в', 417),
#  ('отправился в', 416),
#  ('позволит вам', 410),
#  ('появились в', 410),
#  (', к', 410),
#  ('прибыл в', 408),
#  ('дебютировал в', 402),
#  ('позволяет нам', 400),
#  ('проходит в', 400),
#  ('умер в', 399),
#  ('состоялась в', 394),
#  ('лежит в', 394),
#  ('подходят для', 390),
#  ('файлыВыберите для', 390),
#  ('вышла в', 389),
#  (', для', 387),
#  ('представлены в', 385),
#  ('совпадает с', 383),
#  ('проходил в', 379),
#  ('живет в', 378),
#  ('работает с', 376),
#  ('ведет к', 375),
#  ('Подходит для', 375),
#  ('входил в', 374),
#  ('говорят о', 374),
#  ('рассказывает о', 374),
#  ('объявил о', 373),
#  ('написан неделю', 368),
#  ('привела к', 366),
#  (', несмотря', 365),
#  ('делится на', 364),
#  ('считают полезным', 363),
#  ('приходится на', 362),
#  ('попала в', 362),
#  ('быстро разместились в', 355),
#  ('рассказал о', 355),
#  ('занимаетесь торговлей', 355),
#  ('отказался от', 354),
#  ('начал в', 353),
#  ('был образован в', 352),
#  ('легко конфигурируются при', 348),
#  ('входила в', 348),
#  ('происходит на', 348),
#  ('— в', 345),
#  ('отвечает за', 343),
#  ('вступает в', 342),
#  (', мне', 342),
#  ('имеет в', 342),
#  ('используются в', 341),
#  ('купить в', 341),
#  ('находились в', 337),
#  ('основан на', 337),
#  ('приводят к', 333),
#  ('скончался в', 331),
#  ('заявил о', 331),
#  ('находится под', 331),
#  ('живут в', 329),
#  (', входит в', 326),
#  ('защищены ВверхЗагрузка', 326),
#  ('появилась в', 324),
#  ('помогут Вам', 323),
#  ('участвует в', 322),
#  ('женился на', 320),
#  ('вошел в', 320),
#  ('находилась в', 320),
#  ('приходит в', 319),
#  ('погибли в', 319),
#  (') , в', 316),
#  ('не участвует в', 313),
#  ('пришла в', 312),
#  ('специализируется на', 311),
#  ('прошел в', 310),
#  ('является в', 309),
#  ('происходит с', 307),
#  ('-обратно В', 307),
#  ('окончил в', 306),
#  ('был переименован в', 305),
#  ('свяжется в', 305),
#  ('можете на', 305),
#  ('идеально подходят для', 305),
#  ('лежит на', 302),
#  ('содержится в', 302),
#  ('поможет Вам', 301),
#  ('Узнать больше.', 300),
#  ('отправляется в', 300),
#  (') на', 300),
#  (', из', 295),
#  ('стоит в', 294),
#  ('основана на', 292),
#  ('оказался в', 290),
#  ('вышел из', 288),
#  (', от', 287),
#  ('состоится в', 287),
#  ('провёл в', 284),
#  ('защищён от', 281),
#  ('идет на', 280),
#  ('предложениеПакет услуг', 279),
#  ('поступил в', 278),
#  ('пришли к', 278),
#  ('приглашает на', 277),
#  ('жили в', 275),
#  ('идет в', 273),
#  ('свяжутся с', 273),
#  ('прошла в', 272),
#  ('влияют на', 271),
#  ('состоял из', 271),
#  ('свяжемся с', 269),
#  ('идёт о', 269),
#  ('предлагает для', 269),
#  ('можете по', 268),
#  ('прошли в', 267),
#  ('переехала в', 267),
#  ('готовится к', 266),
#  ('узнаем о', 266),
#  ('проводится в', 264),
#  ('не несет ответственности', 264),
#  ('относитесь к', 264),
#  ('осуществляется в', 264),
#  ('работают на', 264),
#  (', во', 263),
#  ('пришла к', 263),
#  ('жил в', 260),
#  ('" на', 259),
#  ('соответствуют к', 259),
#  ('началась в', 258),
#  ('принимал в', 258),
#  ('предлагает в', 254),
#  ('стал в', 253),
#  ('делятся на', 252),
#  ('пришли в', 252),
#  ('выходит на', 251),
#  ('вышли на', 249),
#  ('нуждаются в', 249),
#  ('переименован в', 248),
#  ('располагается в', 248),
#  ('переходит в', 248),
#  ('приведена на', 247),
#  ('работают с', 246),
#  ('вышла замуж за', 245),
#  ('вышла на', 244),
#  ('обратился к', 244),
#  ('не дал результатов', 243),
#  ('попадают в', 242),
#  ('участвовали в', 242),
#  ('возвращается в', 241),
#  ('участвовала в', 240),
#  ('появится в', 240),
#  ('свидетельствуют о', 240),
#  ('пришел в', 239),
#  ('оказались в', 236),
#  ('зависят от', 235),
#  ('встречается в', 235),
#  ('имеют в', 233),
#  ('еще не подписались на', 233),
#  ('играл в', 231),
#  ('; в', 229),
#  ('упоминается в', 228),
#  ('приехал в', 227),
#  ('живёт в', 225),
#  ('встретился с', 224),
#  ('прошёл в', 224),
#  ('переехал в', 223),
#  ('начинается от', 222),
#  ('включены в', 222),
#  ('позволит Вам', 222),
#  ('поможет в', 222),
#  ('вышли в', 222),
#  ('направлена на', 221),
#  (') с', 221),
#  ('родилась в', 219),
#  ('доходит до', 219),
#  ('сводится к', 218),
#  ('обеспечивают в', 217),
#  ('проходит через', 216),
#  ('остался в', 216),
#  ('происходят в', 216),
#  ('предлагает вам', 214),
#  ('находит в', 214),
#  ('пришел к', 213),
#  ('уходит в', 213),
#  ('превратилась в', 213),
#  ('отличаются от', 213),
#  ('хранится в', 213),
#  ('указаны в', 212),
#  ('перешел в', 212),
#  ('( на', 212),
#  ('участвуют в', 211),
#  ('указывают на', 211),
#  ('находился на', 211),
#  (', до', 211),
#  ('проходили в', 210),
#  ('проявляется в', 208),
#  ('вступили в', 208),
#  ('найдете в', 208),
#  ('смотрит на', 207),
#  ('появляется в', 206),
#  ('перешли в', 206),
#  ('соглашаетесь с', 205),
#  ('ИсполнителиЖанрыСборникиРадиоФорумДобавить трекМобильное приложениеАудиокнигиРасскажи о',
#   205),
#  ('объединены в', 204),
#  ('был преобразован в', 204),
#  ('работает по', 204),
#  ('познакомился с', 204),
#  ('взял в', 203),
#  ('получили в', 203),
#  ('превратился в', 202),
#  ('позволяет им', 202),
#  ('играет в', 202),
#  ('направлены на', 202),
#  ('выступает в', 201),
#  ('получила в', 201),
#  ('используют для', 200),
#  ('- в', 200),
#  ('выходит из', 199),
#  ('был построен в', 198),
#  ('покажем вам', 198),
#  ('присоединился к', 198),
#  ('дает в', 198),
#  ('говорим о', 197),
#  ('учился в', 196),
#  ('сидит на', 196),
#  ('применяется для', 195),
#  ('применяется в', 195),
#  ('началось в', 195),
#  ('смотрите в', 194),
#  ('находитесь в', 193),
#  ('подходит к', 191),
#  ('объявила о', 191),
#  ('является для', 190),
#  ('часто путешествуете , для', 189),
#  ('состоялось в', 189),
#  ('образовано 20 декабря 2004 года в', 188),
#  ('основано на', 188),
#  ('сочетает в', 188),
#  ('сообщил о', 188),
#  ('идут на', 187),
#  ('начинается в', 186),
#  ('свяжутся в', 186),
#  (', под', 185),
#  ('служит для', 185),
#  (', без', 184),
#  ('оказалась в', 183),
#  ('представлена в', 183),
#  ('доберетесь до', 183),
#  ('основаны на', 183),
#  ('приходит к', 182),
#  ('предлагает Вам', 182),
#  ('не распространяется на', 182),
#  ('служил в', 182),
#  ('рассчитан на', 181),
#  ('используют в', 181),
#  ('нашли в', 181),
#  ('выходят на', 180),
#  ('выступал в', 180),
#  ('идеально подходит для', 180),
#  ('остается в', 178),
#  ('идет об', 178),
#  ('появился на', 178),
#  ('встречается с', 177),
#  ('идут в', 176),
#  ('хранятся в', 176),
#  ('проходит по', 176),
#  ('находятся под', 176),
#  ('защищает от', 175),
#  ('осуществляется по', 175),
#  ('принимается врачом', 175),
#  ('встречаются в', 174),
#  ('производится в', 174),
#  ('обратился с', 174),
#  ('ищем для', 174),
#  ('являются собственностью', 173),
#  ('оказывается в', 173),
#  ('сталкивается с', 173),
#  ('быстро размещаются в', 172),
#  ('была основана в', 172),
#  ('предлагает с', 171),
#  ('отказалась от', 171),
#  ('подал в', 170),
#  ('содержит в', 170),
#  ('произошел в', 170),
#  ('выйдет в', 170),
#  ('приступил к', 170),
#  ('подберет для', 170),
#  ('отправились в', 169),
#  ('следит за', 169),
#  ('основывается на', 168),
#  ('остались в', 167),
#  ('перешла в', 167),
#  ('проходят в', 167),
#  ('был создан в', 166),
#  ('вышел ( а ) из', 166),
#  ('превращаются в', 166),
#  ('приехали в', 165),
#  ('сидит в', 165),
#  ('предлагаем вам', 165),
#  ('вышла из', 165),
#  ('вступила в', 164),
#  ('стал для', 164),
#  ('знакомится с', 164),
#  ('готовятся к', 164),
#  ('провел в', 163),
#  ('предназначено для', 163),
#  ('разработаны специально для', 162),
#  ('работал на', 162),
#  ('заключалась в', 162),
#  ('начинаются с', 162),
#  ('был в', 162),
#  ('окажет на', 161),
#  ('будет зависеть от', 161),
#  ('компенсируют через', 160),
#  ('возник в', 160),
#  ('требует от', 160),
#  ('произошла в', 160),
#  ('вызывает у', 160),
#  ('используется как видео', 160),
#  ('Отели в', 160),
#  ('проверяет данным', 159),
#  (', находится в', 159),
#  ('Отели рядом с', 159),
#  ('живу в', 159),
#  ('прибыли в', 159),
#  ('был опубликован автором', 159),
#  ('предпочитают путешественники', 159),
#  ('стремится к', 158),
#  ('трахается с', 158),
#  ('подбираются по', 158),
#  ('сочтут возможным', 158),
#  ('пришёл в', 157),
#  ('пришёл к', 157),
#  ('восходит к', 157),
#  ('столкнулся с', 156),
#  ('было связано с', 156),
#  ('не зависит от', 156),
#  ('был основан в', 156),
#  ('- слушать музыку онлайн на Зайцев.нет без', 155),
#  ('столкнулись с', 155),
#  ('произошли в', 155),
#  ('пришла на', 155),
#  ('находилось на', 155),
#  ('содержатся в', 154),
#  ('получил от', 153),
#  ('отказались от', 153),
#  ('расскажет о', 152),
#  ('выступил с', 152),
#  ('останется в', 152),
#  ('умер от', 151),
#  ('вошло в', 151),
#  ('свяжемся в', 150),
#  ('приходят в', 150),
#  ('происходило в', 150),
#  ('отправляется на', 150),
#  ('сталкиваются с', 150),
#  ('приводятся в', 150),
#  ('обеспечивают при', 149),
#  ('выходит в', 149),
#  ('отправляются в', 149),
#  ('представлены на', 149),
#  ('отыщет среди', 149),
#  ('зарабатывает на', 149),
#  ('сообщили о', 148),
#  ('находится у', 148),
#  (', благодаря', 148),
#  ('случилось с', 148),
#  ('распространяется на', 148),
#  ('начались в', 147),
#  ('рассчитаны на', 147),
#  ('проживает в', 147),
#  ('сыграл в', 147),
#  ('получают в', 146),
#  ('шла о', 146),
#  ('Нет комментариев', 146),
#  ('напали на', 145),
#  ('мечтает о', 145),
#  ('составляет в', 144),
#  ('взял на', 144),
#  ('отказывается от', 143),
#  ('остались без', 143),
#  ('проводятся в', 143),
#  ('дает нам', 143),
#  ('вышли из', 143),
#  ('направлен на', 143),
#  ('обращается к', 143),
#  ('создан для', 143),
#  ('приступили к', 142),
#  ('традиционно названы лунами', 142),
#  (', о', 142),
#  ('привел к', 142),
#  ('являются в', 141),
#  ('появилось в', 141),
#  ('рассчитана на', 141),
#  ('присутствует в', 141),
#  ('приведены в', 141),
#  ('пройдут в', 141),
#  ('выйдет на', 140),
#  ('верит в', 140),
#  ('ответят на', 140),
#  ('работала в', 140),
#  ('разворачивается в', 140),
#  ('оснащены удобствами', 140),
#  ('действует на', 139),
#  ('станет для', 139),
#  ('передана в', 139),
#  ('подойдет для', 139),
#  ('попали на', 138),
#  ('играют в', 138),
#  (', кроме', 138),
#  ('приводит в', 138),
#  ('– в', 138),
#  ('даст вам', 138),
#  ('представлен в', 138),
#  ('вернулись в', 137),
#  ('найдете без', 137),
#  ('ведёт к', 137),
#  ('выступал за', 137),
#  ('состояла в', 136),
#  ('была создана в', 136),
#  ('стоят на', 135),
#  ('началась с', 135),
#  ('сочетается с', 135),
#  ('идёт на', 135),
#  ('смотрят на', 135),
#  ('приезжает в', 135),
#  ('бы в', 135),
#  ('пошли на', 134),
#  ('живем в', 134),
#  ('Автоматически создан при', 134),
#  ('была построена в', 134),
#  ('занял в', 134),
#  ('перешли на', 134),
#  ('были преобразованы в', 133),
#  ('бы на', 133),
#  ('не входит в', 133),
#  ('заботится о', 133),
#  ('едет в', 132),
#  ('бы с', 132),
#  ('применяются в', 132),
#  ('находится по', 132),
#  ('появляются в', 132),
#  ('вернулся на', 132),
#  (', со', 132),
#  ('осуществляется на', 131),
#  ('выпадает в', 131),
#  ('поступает в', 130),
#  ('выражается в', 130),
#  ('позволяет ему', 130),
#  ('была опубликована в', 130),
#  ('— на', 130),
#  ('был открыт в', 130),
#  ('© 2015 МИА «Россия сегодня»Сетевое издание «РИА Новости» зарегистрировано в',
#   130),
#  ('уехал в', 130),
#  ('превратились в', 129),
#  ('идет по', 129),
#  ('работает над', 129),
#  ('обратился в', 129),
#  ('Нет в', 129),
#  ('нет на', 129),
#  ('превращает в', 129),
#  ('выступил в', 129),
#  ('вернулась в', 128),
#  ('приходит на', 128),
#  ('заявила о', 128),
#  ('входили в', 128),
#  (': в', 128),
#  ('адрес защищен от', 127),
#  ('жила в', 127),
#  ('погрузитесь в', 127),
#  ('позволяют нам', 126),
#  ('не имеет права', 126),
#  ('позволят вам', 126),
#  ('упал на', 126),
#  ('осталась в', 126),
#  ('рассказала о', 125),
#  ('Масштабируется до', 125),
#  ('включена в', 125),
#  ('отправилась в', 125),
#  ('помогут в', 125),
#  (', ничего', 125),
#  ('выполнены в', 125),
#  ('выглядит для', 125),
#  ('играет на', 124),
#  ('была включена в', 124),
#  ('заявили о', 124),
#  ('получает в', 124),
#  ('выиграл в', 123),
#  ('совершил в', 123),
#  ('произошло с', 123),
#  ('начнется в', 123),
#  ('| Нет комментариев', 123),
#  ('работали в', 122),
#  ('дает пользователям', 122),
#  ('жалуются на', 122),
#  ('изготовлены из', 122),
#  ('приведёт к', 122),
#  ('говорил о', 122),
#  ('выполнен в', 122),
#  ('измеряют с', 122),
#  ('существует в', 122),
#  ('написал в', 121),
#  ('страдает от', 121),
#  ('появилась на', 121),
#  ('умерла в', 121),
#  (', говорит о', 121),
#  ('отвечают за', 120),
#  ('применяются для', 120),
#  ('опирается на', 120),
#  ('найдете на', 120),
#  ('был передан в', 120),
#  ('работал с', 120),
#  ('отправился на', 119),
#  ('возникает в', 119),
#  ('были опубликованы в', 119),
#  (', через', 119),
#  ('оценивается в', 119),
#  ('подберет в', 118),
#  ('доберетесь за', 118),
#  ('см. в', 118),
#  ('была переименована в', 118),
#  ('появились на', 118),
#  ('заработал на', 118),
#  ('видеосигналаЭти простые в применении усилители компании Analog Devices специально оптимизированы для',
#   118),
#  ('обладают разрешением', 118),
#  ('увидел в', 118),
#  ('≥ 12 В( Параметрический поиск) Усилители с', 118),
#  ('изготавливаются из', 117),
#  ('. в', 117),
#  ('оставил в', 117),
#  (') содержит с', 117),
#  ('обвинил в', 117),
#  ('видит в', 117),
#  ('повествует о', 117),
#  ('подошел к', 117),
#  ('побывал в', 117),
#  ('сообщает о', 116),
#  (') по', 116),
#  ('проникает в', 116),
#  ('собраны в', 116),
#  ('был принят в', 116),
#  ('подошла к', 116),
#  ('базируется на', 116),
#  ('изоляторыЛинейные изоляторыВ лице линейных изоляторов разработчики источников питания получают методам',
#   116),
#  ('произошло на', 116),
#  ('используется при', 116),
#  ('не требуется для', 115),
#  ('вступит в', 115),
#  ('была передана в', 115),
#  ('был выпущен в', 115),
#  ('направлено на', 115),
#  ('находились на', 115),
#  ('в интернет магазине', 115),
#  ('ложится на', 115),
#  ('поступила в', 114),
#  ('не подходит для', 114),
#  ('является причиной', 114),
#  ('были в', 114),
#  ('привёл к', 114),
#  ('происходит при', 114),
#  ('играли в', 114),
#  ('пришли на', 114),
#  ('не стоит на', 114),
#  ('был отправлен в', 114),
#  ('закончил в', 113),
#  ('получает от', 113),
#  ('возникла в', 113),
#  ('позволяет в', 113),
#  ('провели в', 113),
#  ('знаем о', 113),
#  ('стоит за', 113),
#  ('остаются в', 113),
#  ('находилось в', 113),
#  ('ищем у', 113),
#  ('перезвоним в', 113),
#  ('не имели семей', 113),
#  ('являетесь правообладателем', 113),
#  ('пойдет на', 113),
#  ('обратились к', 113),
#  ('подозревается в', 113),
#  ('узнали о', 112),
#  ('дошли до', 112),
#  ('превратится в', 112),
#  ('сможете в', 112),
#  ('состоялись в', 112),
#  ('знает о', 112),
#  ('переходит на', 112),
#  ('находимся в', 112),
#  ('предлагает гостям.', 111),
#  ('работаем с', 111),
#  ('заходит о', 111),
#  ('выведена из', 111),
#  ('несет в', 111),
#  ('был награждён орденом', 111),
#  ('напал на', 111),
#  ('располагается на', 111),
#  ('лежат в', 111),
#  ('берет на', 110),
#  ('влечет за', 110),
#  ('подошли к', 110),
#  ('использует в', 110),
#  ('был произведён в', 110),
#  ('отправил в', 109),
#  ('настаивает на', 109),
#  ('помогает в', 109),
#  ('забронировал на', 109),
#  ('победил в', 109),
#  ('проходила в', 109),
#  ('стоят в', 109),
#  ('находитесь на', 109),
#  ('ведут к', 109),
#  ('познакомилась с', 108),
#  ('выполнена в', 108),
#  ('подберет из', 108),
#  ('будет в', 108),
#  ('уходит на', 108),
#  ('производится на', 108),
#  ('заключаются в', 107),
#  ('ответил на', 107),
#  ('строится на', 107),
#  ('верят в', 107),
#  ('занимает около', 107),
#  ('приехала в', 107),
#  ('продаются в', 106),
#  ('вырос на', 106),
#  ('установлен в', 106),
#  ('впадает в', 106),
#  ('снялась в', 106),
#  ('ушёл в', 106),
#  ('берет в', 106),
#  ('происходит по', 105),
#  ('смотрю на', 105),
#  (', вам', 105),
#  ('началось с', 105),
#  ('идёт в', 105),
#  ('пошла на', 105),
#  ('включен в', 105),
#  ('искали авиабилеты', 104),
#  ('попал под', 104),
#  ('проводились в', 104),
#  ('обвинили в', 104),
#  ('вернулся к', 104),
#  ('ответит на', 104),
#  ('открылся в', 104),
#  ('отправляются на', 104),
#  ('требуется для', 104),
#  ('ждет в', 104),
#  ('сообщила о', 103),
#  ('служат для', 103),
#  ('относят к', 103),
#  ('провела в', 103),
#  ('действует в', 103),
#  ('является на', 103),
#  ('существуют в', 102),
#  ('преобразован в', 102),
#  ('пошли в', 102),
#  ('отказал в', 102),
#  ('продается в', 102),
#  ('сделаны из', 102),
#  ('приглашает в', 102),
#  ('выступили в', 101),
#  ('определяется по', 101),
#  ('написано в', 101),
#  ('начался в', 101),
#  ('осуществляется с', 101),
#  ('объявили о', 101),
#  ('оказался на', 101),
#  ('обладают для', 101),
#  ('видел в', 101),
#  ('стоял на', 100),
#  ('перезвоним Вам', 100),
#  ('проводит в', 100),
#  ('является собственностью', 100),
#  ('напрямую зависит от', 100),
#  ('влюбляется в', 100),
#  ('погибли при', 100),
#  ('попал на', 100),
#  ('является автором', 99),
#  ('знают о', 99),
#  ('состояло из', 99),
#  ('дебютировал за', 99),
#  ('ушел в', 99),
#  ('играл за', 99),
#  ('был убит в', 99),
#  ('построен на', 99),
#  ('приближается к', 99),
#  ('держит в', 99),
#  ('приговорил к', 99),
#  ('выйдет из', 98),
#  ('" с', 98),
#  ('упал в', 98),
#  ('отвечает на', 98),
#  ('имеется в', 98),
#  ('занимает в', 98),
#  ('присоединилась к', 98),
#  ('говорит об', 98),
#  ('принимали в', 98),
#  ('; см . Список', 98),
#  ('выходят в', 98),
#  ('пришел на', 98),
#  ('рассказали о', 98),
#  ('принимаете на', 97),
#  ('оказываются в', 97),
#  ('говорили о', 97),
#  ('делается на', 97),
#  ('позволило ему', 97),
#  ('устанавливается в', 97),
#  ('думает о', 97),
#  ('была выпущена в', 97),
#  ('скончался от', 97),
#  ('пострадали в', 97),
#  ('возникают в', 97),
#  ('снялся в', 97),
#  ('выступает за', 97),
#  ('смотрите на', 96),
#  ('проходят по', 96),
#  ('были переданы в', 96),
#  ('поступили в', 96),
#  ('может в', 96),
#  ('врезался в', 96),
#  ('Добавить в', 96),
#  ('выросла на', 96),
#  ('нашла в', 96),
#  ('ушла в', 95),
#  ('делается в', 95),
#  ('обнаружили в', 95),
#  ('попали по', 95),
#  ('играл на', 95),
#  ('принимаете в', 95),
#  ('переименована в', 95),
#  ('возникают при', 95),
#  ('переходит к', 95),
#  ('живете в', 95),
#  ('получила от', 95),
#  ('являются частью', 95),
#  (') Просмотреть альбом', 95),
#  ('произошло от', 95),
#  ('появятся в', 95),
#  ('пошел в', 95),
#  ('находилась на', 95),
#  (', обеспечивают в', 95),
#  ('использовались в', 95),
#  ('создана для', 94),
#  ('борется с', 94),
#  ('войдет в', 94),
#  ('присутствуют в', 94),
#  ('вступают в', 94),
#  ('выполнены из', 94),
#  ('придется по', 94),
#  ('пошел на', 94),
#  ('представляет из', 94),
#  ('узнал о', 93),
#  ('был назначен на', 93),
#  ('поступил на', 93),
#  ('сотрудничает с', 93),
#  ('работают по', 93),
#  ('поможем вам', 93),
#  ('дошла до', 93),
#  ('( В', 93),
#  ('перешёл на', 93),
#  ('являются для', 93),
#  ('нападает на', 93),
#  ('перешли к', 93),
#  ('не влияет на', 93),
#  ('возникает при', 92),
#  ('перешла на', 92),
#  ('приведут к', 92),
#  ('принадлежит услугам', 92),
#  ('откажется от', 92),
#  ('< разработчикам', 92),
#  ('располагаются в', 92),
#  ('использовался в', 92),
#  ('бежал в', 92),
#  ('- на', 92),
#  ('были связаны с', 92),
#  ('обеспечивает в', 92),
#  ('Закрыть Закрыть Добавлено в', 92),
#  ('переехали в', 92),
#  ('подошёл к', 91),
#  ('находится с', 91),
#  ('хватает на', 91),
#  ('не нуждается в', 91),
#  ('появится на', 91),
#  ('приведены по', 91),
#  ('дано в', 91),
#  ('применяется при', 91),
#  ('оборудован пандусами', 91),
#  ('забил в', 91),
#  ('составляла на', 91),
#  ('работаю в', 91),
#  (', состоит из', 91),
#  ('взяли в', 91),
#  ('получите в', 90),
#  ('проводился в', 90),
#  ('не имеет значения', 90),
#  ('живет на', 90),
#  ('представляете в', 90),
#  ('находится возле', 90),
#  ('обладают комбинацией', 90),
#  ('искали в', 90),
#  ('прошло в', 90),
#  ('поступит в', 90),
#  ('идет к', 90),
#  ('предлагаем Вам', 90),
#  ('построена на', 90),
#  ('связывают с', 90),
#  ('перебрался в', 89),
#  ('вышло в', 89),
#  ('выбирают преобразователи', 89),
#  ('Открыть в', 89),
#  ('проходит на', 89),
#  ('является результатом', 89),
#  ('обвиняется в', 89),
#  ('приходят к', 89),
#  ('возвращается к', 89),
#  ('относились к', 89),
#  ('являетесь владельцем', 89),
#  (', обеспечивают с', 89),
#  ('видеосигналаПростые в применении усилители компании Analog Devices специально оптимизированы для',
#   89),
#  ('занимается производством', 89),
#  ('падает на', 88),
#  ('работал над', 88),
#  ('ищете фразы', 88),
#  (') , на', 88),
#  ('присоединились к', 88),
#  ('пошла в', 88),
#  ('останется на', 88),
#  ('стремятся к', 88),
#  ('находят в', 88),
#  ('принял в', 88),
#  ('можете у', 88),
#  ('не представляется возможным', 88),
#  ('встречаются на', 88),
#  (', протекает в', 88),
#  ('пришло в', 87),
#  ('® доминирует на', 87),
#  ('имели в', 87),
#  ('перешел на', 87),
#  ('бывает в', 87),
#  ('обойдется в', 87),
#  ('переходят в', 87),
#  ('работает без', 87),
#  ('выполнена из', 87),
#  ('живут на', 87),
#  ('имеют с', 87),
#  ('уходят в', 87),
#  ('® доминирует благодаря', 87),
#  ('прибыл на', 87),
#  ('подразделяются на', 86),
#  ('Отели со', 86),
#  ('построен в', 86),
#  ('прибыла в', 86),
#  ('является основой', 86),
#  ('содержат в', 86),
#  ('используются при', 86),
#  ('предлагает гостям', 86),
#  ('стала для', 86),
#  ('выходит за', 86),
#  ('выполняются в', 86),
#  ('имеет на', 85),
#  ('предложил ей', 85),
#  ('делает возможным', 85),
#  ('разделена между', 85),
#  ('зашли на', 85),
#  ('проводится с', 85),
#  ('основан в', 85),
#  ('принимала во', 85),
#  ('лежат на', 85),
#  ('взяла в', 85),
#  ('откроется в', 85),
#  ('отправились на', 85),
#  ('выступают в', 85),
#  ('смотрел на', 85),
#  ('отвечают на', 85),
#  ('устанавливается на', 85),
#  ('заходит в', 85),
#  ('выступил на', 85),
#  ('состояли из', 84),
#  ('обращаются к', 84),
#  ('собрались в', 84),
#  ('проводят в', 84),
#  ('разрешено в', 84),
#  ('выпускается в', 84),
#  ('построена в', 84),
#  ('делает в', 84),
#  ('изготавливается из', 84),
#  (', нам', 84),
#  ('кроется в', 84),
#  ('сохраняется в', 84),
#  ('была в', 84),
#  (', находятся в', 84),
#  ('начал с', 84),
#  ('не относится к', 84),
#  ('избавит от', 83),
#  ('предоставляются партнерами для', 83),
#  ...]

# %%
preds = defaultdict(Counter)
sub_obj = defaultdict(Counter)
c = Counter()
for line in open('predicates_pattern.txt'):
    subj, predicate, *objs = line.split('\t')
    preds[predicate].update([subj])
    c.update([predicate])
    sub_obj[predicate].update([(subj, tuple(objs))])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-438-0251aebbbd8b> in <module>()
#       5     subj, predicate, *objs = line.split('\t')
#       6     preds[predicate].update([subj])
# ----> 7     c.update([predicate])
#       8     sub_obj[predicate].update([(subj, tuple(objs))])
#
# /usr/lib/python3.5/collections/__init__.py in update(*args, **kwds)
#     607         iterable = args[0] if args else None
#     608         if iterable is not None:
# --> 609             if isinstance(iterable, Mapping):
#     610                 if self:
#     611                     self_get = self.get
#
# /usr/lib/python3.5/abc.py in __instancecheck__(cls, instance)
#     180         # Inline the cache checking
#     181         subclass = instance.__class__
# --> 182         if subclass in cls._abc_cache:
#     183             return True
#     184         subtype = type(instance)
#
# KeyboardInterrupt:

# %%
predicate
# Out:
# 'и_PART_advmod дано_VERB_parataxis_CORE'

# %%
def verb_post(key, lookup):
    cnt = sub_obj[key].most_common()
    w_post = Counter()
    seqs_post = []
    df = defaultdict(set)
    for t, c in cnt:
        for obj in t[1]:
            tokens = obj.split()
            w_post[tokens[0].split('_')[0]] += c
            pos = ' '.join([token.split('_')[2] for token in tokens])
            seqs_post.append(pos)
            df[pos].add(' '.join([token.split('_')[0] for token in tokens]))
    return w_post.most_common(), seqs_post, df

# %%
w, seqs, d = verb_post('предлагает_VERB_root_CORE', sub_obj)

# %%
sub_obj['является'].most_common()
# Out:
# [(('информация', ('конфиденциальной\n',)), 4871),
#  (('блокировка', ('в таком случае', 'полной\n')), 614),
#  (('лицензия', ('на него', 'свободной\n')), 450),
#  (('отель', ('частью сети отелей\n',)), 268),
#  (('рейсовСравнить',
#    ('собственностью компании BravoNext SA с головным офисом по адресу',
#     'цены\n')),
#   248),
#  (('солнечно лунная теория', ('точной наукой\n',)), 185),
#  (('© 2006 2016Bravoavia',
#    ('зарегистрированной торговой маркой ® Услуги предоставляемые на сайте предложены Группой компаний lastminute.com group и её партнерами\n',)),
#   136),
#  (('использовать ваучерBravo КомпенсацияiPhone и Android приложенияПАРТНЕРСТВОРекламаАкции и новостиДанный веб-сайт',
#    ('собственностью компании BravoNext SA с головным офисом по адресу Vicolo de’ Calvi 2 6830 Chiasso CH регистрационный номер компании CHE 115.704.228 ИНН CHE 115.704.228\n',)),
#   99),
#  (('сбор',
#    ('дополнительной платой', 'за использование нашей службы бронирования\n')),
#   97),
#  (('Vicolo de’ Calvi 2 6830 Chiasso CH регистрационный номер компании CHE 115.704.228 ИНН CHE 115.704.228',
#    ('собственностью компании BravoNext SA с головным офисом по адресу\n',)),
#   76),
#  (('использовать ваучерiPhone и Android приложенияПАРТНЕРСТВОРекламаАкции и новостиДанный веб-сайт',
#    ('собственностью компании BravoNext SA с головным офисом по адресу\n',)),
#   72),
#  (('обязательное указание на реальность полового акта посредством эякуляции которая может быть направлена в лицо рот вагину анус или просто на тело актрисы',
#    ('особенности\n',)),
#   67),
#  (('представление полового акта и половых органов в отличии от распространённого мнения',
#    ('изобретением современности и презренного капитализма\n',)),
#   67),
#  (('отель', ('частью сети отелей Hilton\n',)), 66),
#  (('Данная суперобложка', ('пиратской\n',)), 62),
#  (('использовать ваучерBravo КомпенсацияiPhone и Android приложенияПАРТНЕРСТВОРекламаАкции и новостиДанный веб-сайт',
#    ('собственностью компании BravoNext SA с головным офисом по адресу\n',)),
#   53),
#  (('отель', ('частью сети отелей Marriott Hotels\n',)), 46),
#  (('данная информация', ('пособием по самолечению\n',)), 46),
#  (('отель', ('частью сети отелей Best\n',)), 45),
#  (('© 2006 2016Bravoavia', ('зарегистрированной торговой маркой ®\n',)), 42),
#  (('католицизм', ('направлением христианства в стране\n',)), 42),
#  (('цветок', ('живой скульптурой\n',)), 41),
#  (('Данный веб-сайт',
#    ('собственностью компании BravoNext SA с головным офисом по адресу\n',)),
#   35),
#  (('информация', ('публичной офертой\n',)), 31),
#  (('виртуальный хостинг', ('самым доступным видом хостинга\n',)), 28),
#  (('Этот отель', ('частью сети отелей\n',)), 27),
#  (('отель', ('частью сети отелей Days\n',)), 27),
#  (('виртуальный хостинг', ('самым популярным видом хостинга\n',)), 26),
#  (('большое число платных приложений и игр на Айфон Айпад или Айпод',
#    ('недостатком данного бренда\n',)),
#   25),
#  (('классический хостинг', ('самым доступным видом хостинга\n',)), 25),
#  (('хостинг сайтов', ('самым популярным видом хостинга\n',)), 25),
#  (('страница', ('публичной офертой\n',)), 24),
#  (('Вся музыка на данном сайте',
#    ('законной собственностью её создателей',
#     'на сайте она представленная для ознакомительных целей\n')),
#   22),
#  (('отель', ('частью сети отелей LM.\n',)), 21),
#  (('отель', ('частью сети отелей SkiHorizon.\n',)), 21),
#  (('сотрудничество', ('долговременным и надежным\n',)), 20),
#  (('хостинг',
#    ('более подходящим для проектов не нуждающихся в высокой производительности\n',)),
#   20),
#  (('Этот отель', ('частью сети отелей SkiHorizon\n',)), 20),
#  (('хостинг',
#    ('более подходящим для проектов не требующих высокой производительности\n',)),
#   18),
#  (('Вада плюс программа очищения организма«Программа 2 Коло-Вада Плюс»',
#    ('программой очищения организма которая может использоваться как дополнение к диетам и голоданию\n',)),
#   18),
#  (('отель', ('частью сети отелей Best Western\n',)), 18),
#  (('Указанная цена', ('публичной офертой\n',)), 17),
#  (('это', ('проблемой\n',)), 17),
#  (('классический хостинг', ('самым популярным видом хостинга\n',)), 17),
#  (('что',
#    ('необходимым условием и залогом успешного социально экономического развития территории\n',)),
#   17),
#  (('Сайт',
#    ('исключительно информационным и не является публичной офертой определяемой положением статьи 437 2 гражданского кодекса РФ',
#     'нам\n')),
#   16),
#  (('отель', ('частью сети отелей IBIS\n',)), 16),
#  (('большая эффективность в работе именно с твердыми материалами',
#    ('однако при этом перфораторы практически бесполезны для сверления аккуратных отверстий в древесине металле пластике..',
#     'преимуществом перфораторов перед ударными дрелями\n')),
#   15),
#  (('Содержание этого поля', ('приватным\n',)), 15),
#  (('отель', ('частью сети отелей Comfort\n',)), 15),
#  (('отель', ('частью сети отелей Holiday Inn Hotels\n',)), 15),
#  (('мощность двигателя', ('в перфораторах\n',)), 15),
#  (('предложение', ('публичной офертой\n',)), 15),
#  (('сама динамика выздоровлений', ('лучшим доказательством которой\n',)), 15),
#  (('отель', ('частью сети отелей Holiday Inn Express.\n',)), 15),
#  (('протестантизм', ('направлением христианства в стране\n',)), 15),
#  (('что', ('крупным размером\n',)), 14),
#  (('вес', ('существенной проблемой\n',)), 14),
#  (('Гражданин РФ',
#    ('преимуществом Чем занимается грузчик в магазине «Пятерочка»',
#     'соискателя\n')),
#   14),
#  (('которое',
#    ('оператором бизнес центра Nordstar Tower где арендует помещения «Роснефть»\n',)),
#   14),
#  (('что', ('отличным поводом\n',)), 14),
#  (('трансляции', ('итоговой\n',)), 14),
#  (('это', ('в свою очередь', 'причиной многих опасных заболеваний\n')), 13),
#  (('отель', ('частью сети отелей Campanile.\n',)), 13),
#  (('отель', ('частью сети отелей GTA.\n',)), 13),
#  (('что', ('рекордом\n',)), 13),
#  (('китайская мускусная мазь от геморроя',
#    ('высокоэффективным средством которое помогает всем\n',)),
#   13),
#  (('отель', ('частью сети отелей Ramada.\n',)), 13),
#  (('файлы cookie', ('Карта сайта', 'частным веб-сайтом\n')), 13),
#  (('он', ('таковым\n',)), 13),
#  (('предложение', ('офертой\n',)), 13),
#  (('этот отель', ('идеальным\n',)), 13),
#  (('отель', ('частью сети отелей YX.В этом отеле\n',)), 13),
#  (('отель', ('частью сети отелей Logis\n',)), 13),
#  (('который',
#    ('инновационной технологической разработкой немецкой компании Gramme-Revit GmbH\n',)),
#   13),
#  (('что', ('несомненным плюсом\n',)), 12),
#  (('отель', ('частью сети отелей SM.\n',)), 12),
#  (('рекламаБаннерная реклама', ('самым привычным видом web рекламы\n',)), 12),
#  (('проект', ('некоммерческим\n',)), 12),
#  (('рекламаБаннерная реклама',
#    ('самым привычным видом электронной рекламы\n',)),
#   12),
#  (('что', ('очень важным условием корректного поиска\n',)), 12),
#  (('отель', ('частью сети отелей OBZ.\n',)), 11),
#  (('копирование и использование материалов и фотографий без письменного разрешения администрации сайта',
#    ('незаконным\n',)),
#   11),
#  (('мощность', ('для выбора бетономешалки', 'одним ВАЖНЫМ параметром\n')), 11),
#  (('отель', ('частью сети отелей Logis International\n',)), 11),
#  (('рекламаБаннерная реклама', ('самым привычным видом интернет рекламы\n',)),
#   11),
#  (('страница', ('постоянным адресом киноленты\n',)), 11),
#  (('он', ('кем\n',)), 11),
#  (('комната', ('общей\n',)), 10),
#  (('отель', ('YX. Скрыть', 'частью сети отелей\n')), 10),
#  (('что', ('нарушением\n',)), 10),
#  (('которое',
#    ('300 тысяч рублей компенсации с Первого канала за использование песни рок-музыканта в программе Голос',
#     'обладателем авторских прав на произведения Виктора Цоя в иске о взыскании\n')),
#   10),
#  (('Оперативная информация о ходе матча в онлайн трансляции', ('итоговой\n',)),
#   10),
#  (('Данный документ', ('переводом\n',)), 10),
#  (('отель', ('частью сети отелей Holiday Inn Express\n',)), 9),
#  (('ваш брокер', ('вашим налоговым агентом', 'торговле на фондовой бирже\n')),
#   9),
#  (('что', ('лучшим результатом в отборах для страны\n',)), 9),
#  (('шланг', ('плотному расположению синтетических волокон\n',)), 9),
#  (('отель', ('частью сети отелей UZ.Любителей\n',)), 9),
#  (('отель', ('частью сети отелей NH\n',)), 9),
#  (('это', ('обязательным условием\n',)), 9),
#  (('он', ('чем\n',)), 9),
#  (('решение которого', ('окончательным\n',)), 9),
#  (('он', ('не токсичным\n',)), 9),
#  (('который', ('футболистом\n',)), 9),
#  (('отель', ('частью сети отелей Premiere Classe Hotels.\n',)), 9),
#  (('стоимость и особенности условий провоза багажа',
#    ('моментом', 'при бронировании билетов\n')),
#   9),
#  (('публикация',
#    ('собственностью ИАА Центр гуманитарных технологий и охраняется в соответствии с законодательством Российской Федерации об авторском праве\n',)),
#   9),
#  (('отказанная судом во взыскании сумма предъявленных к вам исковых требований',
#    ('том случае', 'экономической выгодой\n')),
#   9),
#  (('железный четырехколесный конь', ('исключением\n',)), 9),
#  (('автор', ('полновластным хозяином своих персонажей\n',)), 9),
#  (('сторона флага', ('зеркальным отображением его лицевой стороны»\n',)), 9),
#  (('что', ('нормой\n',)), 8),
#  (('что', ('дополнительной защитой от пыли грязи влаги и повреждений\n',)), 8),
#  (('автореВадим', ('владельцем этого блога\n',)), 8),
#  (('«Вступление клуба из Китая в КХЛ',
#    ('хорошим шагом для развития лиги» 5 20 12 Тренер юниорской сборной России «Сергачев сможет закрепиться в НХЛ через год» 2 48 НХЛ\n',)),
#   8),
#  (('информация', ('ознакомительной\n',)), 8),
#  (('КИЕВЭНЕРГО', ('исполнителем услуг ГВС\n',)), 8),
#  (('бронирование и полная оплата путевки в Турцию',
#    ('еще в апреле', 'условием для получения такой скидки\n')),
#   8),
#  (('отель', ('частью сети отелей IP.\n',)), 8),
#  (('которая',
#    ('нежелательной',
#     'по личному мнению Администратора сообщества модераторов сообщества или Администрации сайта\n')),
#   8),
#  (('Данный сайт', ('официальным сайтом премии Дебют Все права защищены ®\n',)),
#   8),
#  (('и объединение отводков и семей',
#    ('в зиму', 'глупостью', 'хоть до закормки сиропом хоть после\n')),
#   8),
#  (('что', ('плюсом\n',)), 8),
#  (('расположение гостиницы в центре', ('вариантом\n',)), 8),
#  (('отель', ('частью сети отелей Kyriad Hotel\n',)), 8),
#  (('башня Италия', ('самым высоким зданием в Сан-Паулу\n',)), 8),
#  (('православие', ('направлением христианства в стране\n',)), 8),
#  (('канцлер Германии госпожа А. Меркель', ('главным виновным\n',)), 8),
#  (('Этот отель', ('частью сети отелей SkiHorizon.\n',)), 8),
#  (('отель', ('частью сети отелей Hampshire\n',)), 7),
#  (('это', ('правдой\n',)), 7),
#  (('сторона флага', ('зеркальным отображением его лицевой стороны\n',)), 7),
#  (('энергия удара Скорость вращенияЭтот показатель',
#    ('для работ с бетоном и кирпичом очень важным показателем\n',)),
#   7),
#  (('Совет РСФСР', ('высшим органом государственной власти РСФСР\n',)), 7),
#  (('отель', ('частью сети отелей UZ\n',)), 7),
#  (('инструментаЭтот показатель', ('столь важным при точечной работе\n',)), 7),
#  (('он', ('членом которого\n',)), 7),
#  (('АФК «Система»',
#    ('законом США об инвестиционных компаниях от 1940 года',
#     'инвестиционной компанией\n')),
#   7),
#  (('отель',
#    ('8.Практическая информация К услугам гостей отеля бесплатная парковка',
#     'частью сети отелей Super\n')),
#   7),
#  (('часть', ('разборной\n',)), 7),
#  (('отель', ('частью сети отелей Super 8.В\n',)), 7),
#  (('онлайн бронирования Agoda.com для бронирования отеля',
#    ('быстрым и легким\n',)),
#   7),
#  (('отель', ('частью сети отелей Ramada\n',)), 7),
#  (('что',
#    ('лидером в области охраны окружающей среды и обладателем премии Greenovation за текущий год как один из лучших проектов по «зеленой» экономике в Хорватии\n',)),
#   7),
#  (('он', ('воспитанником которого\n',)), 7),
#  (('сайт', ('публичной офертой\n',)), 7),
#  (('это', ('обязательным для эффективной работы\n',)), 7),
#  (('Добро пожаловатьПрограммное обеспечение', ('большой\n',)), 7),
#  (('отель', ('частью сети отелей IBIS HOTELS\n',)), 7),
#  (('это', ('обязательным\n',)), 7),
#  (('отель', ('частью сети отелей MERCURE\n',)), 7),
#  (('отель', ('частью сети отелей SkiHorizon\n',)), 7),
#  (('дорожки и широкие газоны засаженные красочными представителями флоры',
#    ('родиной одного из главных выставочных садов в мире садов Бутчартов',
#     'родом\n')),
#   7),
#  (('отель', ('SM. Скрыть', 'частью сети отелей\n')), 7),
#  (('отель', ('частью сети отелей NH Hoteles\n',)), 7),
#  (('он', ('которым\n',)), 7),
#  (('ресурс', ('публичной офертой\n',)), 7),
#  (('информация на сайте', ('публичной офертой\n',)), 7),
#  (('ударная дрель от компании INTERTOOL',
#    ('«доступная цена отличное качество»', 'образцом сочетания\n')),
#   7),
#  (('наличие реверса', ('функцииОбязательной функцией\n',)), 7),
#  (('он', ('им\n',)), 6),
#  (('отель', ('частью сети отелей Super\n',)), 6),
#  (('отель',
#    ('частью сети отелей Super 8.В',
#     'этом отеле к услугам гостей для гостей в инвалидных креслах\n')),
#   6),
#  (('отель',
#    ('8.Примечание К услугам гостей отеля бесплатная парковка',
#     'частью сети отелей Super\n')),
#   6),
#  (('отель', ('частью сети отелей Logis de France.\n',)), 6),
#  (('отель',
#    ('частью сети отелей Hilton Hotels.К услугам гостей отеля высокоскоростной Интернет\n',)),
#   6),
#  (('отель', ('частью сети отелей ON\n',)), 6),
#  (('лысина',
#    ('для некоторых мужчин',
#     'при общении с противоположным полом',
#     'серьезным препятствием',
#     'того\n')),
#   6),
#  (('словосочетание к несчастью', ('частью речи\n',)), 6),
#  (('побережье Флориды в США', ('вершинами которого\n',)), 6),
#  (('что', ('причиной\n',)), 6),
#  (('отель', ('частью сети отелей Howard Johnson\n',)), 6),
#  (('календарный квартал',
#    ('базовым налоговым отчетным периодом', 'у которых\n')),
#   6),
#  (('что', ('лесбиянкой\n',)), 6),
#  (('Этот учебник', ('моей собственностью\n',)), 6),
#  (('это', ('большой проблемой\n',)), 6),
#  (('остров Хонсю',
#    ('них', 'самым большим по площади и наиболее населенным\n')),
#   6),
#  (('отель',
#    ('частью сети отелей YX.К услугам гостей отеля высокоскоростной Интернет\n',)),
#   6),
#  (('2015 Данный ресурс', ('облачным хранилищем полезных данных\n',)), 6),
#  (('класс', ('определенный пользователем', 'производным от std\n')), 6),
#  (('копия Windows', ('подлинной\n',)), 6),
#  (('театр вмещающий 20 000 зрителей',
#    ('основной достопримечательностью которого\n',)),
#   6),
#  (('2 статьи 437 ГК РФ', ('в соответствии с пунктом', 'публичной офертой\n')),
#   6),
#  (('поле', ('обязательным\n',)), 6),
#  (('отель', ('частью сети отелей Motel6\n',)), 6),
#  (('бесплатноАптека', ('участником программы Оранж Кард\n',)), 6),
#  (('и качество изготовления рукава', ('отличительным фактором\n',)), 6),
#  (('Ла-Рошель', ('главной коммуной', 'из них\n')), 6),
#  (('клиентовОбщие вопросыОплата и финансовые вопросыТехнические вопросыИнформация о cookiesПЛАНИРОВАНИЕ ПОЕЗДКИКак бронировать авиабилетыКак использовать ваучерiPhone и Android приложенияПАРТНЕРСТВОРекламаАкции и новостиДанный веб-сайт',
#    ('собственностью компании BravoNext SA с головным офисом по адресу Vicolo de’ Calvi 2 6830 Chiasso CH регистрационный номер компании CHE 115.704.228 ИНН CHE 115.704.228\n',)),
#   6),
#  (('он', ('гражданином которого\n',)), 6),
#  (('он', ('членом которой\n',)), 6),
#  (('что', ('рекордом клуба\n',)), 6),
#  (('Дэвид Уолл',
#    ('исследователем Института Восточной Азии в Кэмбриджском университете и ассоциированным членом Chatham House лондонский Королевский институт международных отношений прим. пер. censored англосаксы\n',)),
#   6),
#  (('I степень', ('степенью ордена\n',)), 6),
#  (('Уведомление о проведении закупки', ('публичной офертой Заказчика\n',)), 6),
#  (('данный маршрут', ('популярным у пассажиров\n',)), 6),
#  (('процедура закупки', ('конкурсом\n',)), 6),
#  (('дрелиУдарная дрель',
#    ('самым распространенным и популярным инструментом не только среди домашних мастеров но и профессионалов\n',)),
#   6),
#  (('беседка', ('своеобразной фишкой ландшафтного дизайна дачного участка\n',)),
#   6),
#  (('веб-сайт',
#    ('собственностью компании Bravonext SA с головным офисом по адресу\n',)),
#   6),
#  (('что', ('важнейшей частью любовных отношений\n',)), 6),
#  (('Монастырский чай', ('панацеей от всех болезней\n',)), 6),
#  (('руководство', ('свободным программным обеспечением\n',)), 5),
#  (('он', ('сегодняшний день\n',)), 5),
#  (('Тулуза', ('главной коммуной', 'из них\n')), 5),
#  (('оно', ('таковым\n',)), 5),
#  (('характер', ('ни при каких условиях', 'публичной офертой\n')), 5),
#  (('что', ('лучшим доказательством эффективности\n',)), 5),
#  (('отель',
#    ('HI. В этом отеле к услугам гостей поле для гольфа неподалеку.',
#     'частью сети отелей\n')),
#   5),
#  (('отель', ('частью сети отелей Tulip\n',)), 5),
#  (('хостинг',
#    ('более подходящим для проектов которые не нуждаются в высокой производительности\n',)),
#   5),
#  (('Этот отель', ('частью сети отелей Logis International\n',)), 5),
#  (('имущество каждого из супругов', ('его собственностью\n',)), 5),
#  (('красный', ('очень светлый оттенком\n',)), 5),
#  (('это', ('нарушением\n',)), 5),
#  (('отель', ('частью сети отелей T2\n',)), 5),
#  (('такое путешествие', ('самым недорогим.\n',)), 5),
#  (('отель', ('частью сети отелей Inter -hotel.\n',)), 5),
#  (('Цифровая', ('публичной офертой\n',)), 5),
#  (('это', ('необходимым\n',)), 5),
#  (('рукоятка', ('неподвижной\n',)), 5),
#  (('он', ('отцом\n',)), 5),
#  (('крем', ('тональным средством\n',)), 5),
#  (('участок ЗСД', ('наиболее технически сложным\n',)), 5),
#  (('которая', ('актрисой\n',)), 5),
#  (('отель', ('частью сети отелей Radisson\n',)), 5),
#  (('кто', ('продавцом бинарных опционов\n',)), 5),
#  (('он', ('популярным ингредиентом для алкогольных коктейлей\n',)), 5),
#  (('отель', ('частью сети отелей IQ\n',)), 5),
#  (('что', ('основной причиной возникновения остеохондроза\n',)), 5),
#  (('Сергей Пашин приведение статуса председателей АС в соответствие со статусом председателей СОИ',
#    ('логичным шагом\n',)),
#   5),
#  (('налогоплательщик', ('налоговым резидентом Российской Федерации\n',)), 5),
#  (('что',
#    ('поводом для многочисленных «гэгов» когда его фамилия почти произносится но этому всегда что-нибудь мешает\n',)),
#   5),
#  (('что', ('ошибкой\n',)), 5),
#  (('отель',
#    ('частью сети отелей T2.К услугам гостей отеля высокоскоростной Интернет\n',)),
#   5),
#  (('отель', ('частью сети отелей Americas Best Value Inn.\n',)), 5),
#  (('представленная на сайте информация', ('публичной офертой\n',)), 5),
#  (('которое', ('памятником архитектуры\n',)), 5),
#  (('предмет', ('PvP наградой\n',)), 5),
#  (('что', ('изобретателем смартфона iPhone\n',)), 5),
#  (('президент России Владимир Путин', ('лидером которого\n',)), 5),
#  (('«Деятельность прочих общественных организаций не включенных в другие группировки»',
#    ('основным видом деятельности\n',)),
#   5),
#  (('Онлайн Любовь',
#    ('по сравнению с другими сайтами знакомств',
#     'то что два человека общаясь на сайте знакомств Онлайн Любовь находят точки соприкосновения в умственном и духовном плане задолго до того как между ними возникает физическая связь\n')),
#   5),
#  (('которая', ('ещё и физиотерапевтом', 'при всей своей красоте\n')), 5),
#  (('отель', ('частью сети отелей IR\n',)), 5),
#  (('это', ('причиной\n',)), 5),
#  (('кто',
#    ('спонсором этих так называемых повстанцев и тем которые стоят за спиной этих спонсоров\n',)),
#   5),
#  (('страна', ('родоначальницей астрономии\n',)), 5),
#  (('наличие незначительной родовой травмы опухоли на голове новорожденного',
#    ('одной особенностью новорожденного ребенка\n',)),
#   5),
#  (('то исполнение служебных обязанностей', ('служебной необходимостью\n',)),
#   5),
#  (('этот рецепт', ('для меня', 'совершенно неожиданным\n')), 5),
#  (('новоприобретённая территория',
#    ('слишком большой для эффективного управления\n',)),
#   5),
#  (('кто', ('убийцей\n',)), 5),
#  (('она', ('деканом\n',)), 5),
#  (('она', ('кем\n',)), 5),
#  (('отель', ('частью сети отелей Howard\n',)), 5),
#  (('она', ('кем', 'на самом деле\n')), 5),
#  (('которая',
#    ('ведущей глобальной исследовательской компанией с множеством патентов на новые и важные технологии\n',)),
#   5),
#  (('которая', ('в свою очередь\n',)), 5),
#  (('веб-сайт', ('более популярным', 'тем\n')), 5),
#  (('что',
#    ('изобретателем iPhone13 48 29 06 2016 Житель американского штата Флорида Томас Росс Thomas Ross обратился с иском в суд утверждая что является изобретателем смартфона iPhone и планшета iPad требуя от производителя устройств компании Apple компенсацию в размере 10 миллиардов долларов и выплаты отчислений от их продаж сообщает издание New York Daily News\n',)),
#   5),
#  (('Информация', ('на сайте', 'публичной офертой\n')), 5),
#  (('исполнительное производствоИсполнительное решение суда',
#    ('исполнительной службой',
#     'последней стадией по выполнению решений суда\n')),
#   5),
#  (('оператор', ('симметричным\n',)), 5),
#  (('отель', ('частью сети отелей Marriott Hotels Resorts\n',)), 5),
#  (('Орлеан',
#    ('Женская НБА', 'фаворитом на проведение Матча всех звезд 2017 8 10 12\n')),
#   5),
#  (('кожаный сарафан с планками на груди и белой рубашкой',
#    ('достаточно модным', 'на сегодняшний день\n')),
#   5),
#  (('обеспечение максимально широкой линейки ассортимента товаров по охране труда',
#    ('магазина', 'приоритетной задачей\n')),
#   5),
#  (('старший брат Мурило «Ниндзя» Руа',
#    ('известным бойцом смешанного стиля\n',)),
#   5),
#  (('наша позиция', ('последовательной\n',)), 5),
#  (('информационный ресурс', ('публичной офертой\n',)), 5),
#  (('отель', ('частью сети отелей Campanile\n',)), 5),
#  (('область',
#    ('«112» системы 112',
#     'пилотным регионом России по внедрению системы обеспечения вызова экстренных оперативных служб по единому номеру\n')),
#   4),
#  (('владелец транспортного средства', ('должником\n',)), 4),
#  (('Новиков', ('в органы предварительного расследования\n',)), 4),
#  (('то что делают шииты демонстрируя уныние и горе что скорее всего по большему счету является притворством тасонну’ и показухой рийа’',
#    ('правильным\n',)),
#   4),
#  (('температура процессора',
#    ('максимальной для ноутбука на процессоре i7\n',)),
#   4),
#  (('первый AUG кодон в зависимости от нуклеотидного контекста вокруг AUG',
#    ('сайтом трансляции\n',)),
#   4),
#  (('арабская нефтяная компания Abu Dhabi National Oil Company',
#    ('месторождении\n',)),
#   4),
#  (('низкое качество сборки',
#    ('причиной повреждения пакетов лопаток из аустенитной стали\n',)),
#   4),
#  (('«заботы» советского государства об инвалидах в СССР',
#    ('красочной иллюстрацией\n',)),
#   4),
#  (('которая', ('на самом деле\n',)), 4),
#  (('лицензионное соглашение с пиратским пользователем',
#    ('юридическим соглашением между пиратским пользователем физическим или юридическим лицом и автором программного продукта\n',)),
#   4),
#  (('величина нагрева вала после нескольких минут работы на максимальных оборотах',
#    ('критерием\n',)),
#   4),
#  (('ребенок', ('собственником\n',)), 4),
#  (('данное предложение', ('публичной офертой\n',)), 4),
#  (('зеленый', ('очень светлый оттенком\n',)), 4),
#  (('Айрес', ('наиболее затратной частью путешествия\n',)), 4),
#  (('отель', ('частью сети отелей mD Hotel Kooperation.\n',)), 4),
#  (('которая', ('еще и дополнением к предыдущей главе\n',)), 4),
#  (('она', ('неотъемлемой частью красоты\n',)), 4),
#  (('т.е.', ('лечебным средством\n',)), 4),
#  (('отель', ('частью сети отелей BW.К услугам гостей отеля бассейн.\n',)), 4),
#  (('одним наиболее популярных сервисов', ('казино\n',)), 4),
#  (('ель', ('Китае', 'источником древесины для ряда промышленностей\n')), 4),
#  (('оно', ('чем\n',)), 4),
#  (('что', ('самым длинным периодом роста с мая прошлого года\n',)), 4),
#  (('отель',
#    ('RF. В этом отеле к услугам гостей поле для гольфа неподалеку',
#     'частью сети отелей\n')),
#   4),
#  (('центральный павильон представленный огромной гостиной открытой планировки каждая зона которой будь это столовая или зона отдыха достаточно просторны чтобы в них комфортно разместились большие компании людей для общения и отдыха',
#    ('достопримечательностью виллы\n',)),
#   4),
#  (('опера',
#    ('экранизацией оперы «Тоска» Джакомо Пуччини написанной по сюжету одноимённой драмы французского писателя Викторьена Сарду\n',)),
#   4),
#  (('что', ('корнем проблемы\n',)), 4),
#  (('должник',
#    ('лицом которое пользуется транспортным средством в связи с инвалидностью\n',)),
#   4),
#  (('предложенная ему работа', ('для него подходящей\n',)), 4),
#  (('та цена которая указана на ценнике изделия в магазине',
#    ('достоверной\n',)),
#   4),
#  (('благотворительная помощь', ('вашей потребностью\n',)), 4),
#  (('правовое государство', ('главной целью\n',)), 4),
#  (('розовый', ('оттенком\n',)), 4),
#  (('пресс-релиз', ('предложением о продаже ценных бумаг в США\n',)), 4),
#  (('это', ('свидетельством того что грядет оно обещание\n',)), 4),
#  (('размещение ссылок',
#    ('нарушением авторских прав', 'текущему законодательству\n')),
#   4),
#  (('отель',
#    ('WV. В этом отеле есть высокоскоростной Интернет',
#     'частью сети отелей\n')),
#   4),
#  (('которая', ('ингибитором коррозии\n',)), 4),
#  (('Испания',
#    ('страной с высокой долей транспортных перевозок за пределы ЕС\n',)),
#   4),
#  (('ценовое предложение которого', ('наименьшим\n',)), 4),
#  (('отель', ('частью сети отелей Hampshire Classic Hotels.\n',)), 4),
#  (('работа кишечника', ('залогом здоровья всего организма\n',)), 4),
#  (('который', ('причиной\n',)), 4),
#  (('которая',
#    ('частью диффузной эндокринной системы синоним АПУД-система\n',)),
#   4),
#  (('предложенный подход явления', ('травой\n',)), 4),
#  (('автомобильный гидравлический подкатной домкрат', ('алюминиевым\n',)), 4),
#  (('бутик в городе Сингапур', ('официальным дистрибьютором часов Rolex\n',)),
#   4),
#  (('что', ('свидетельством оригинальности надежности и качества\n',)), 4),
#  (('она', ('только дополнением к тысячам и тысячам таких же судеб\n',)), 4),
#  (('что', ('национальным рекордом\n',)), 4),
#  (('он', ('участником которых\n',)), 4),
#  (('прямая открытая для поисковых систем гиперссылка в первом абзаце на цитируемую статью или новость',
#    ('новостных и интернет изданий обязательной\n',)),
#   4),
#  (('отель', ('частью сети отелей Quality\n',)), 4),
#  (('что', ('полной чепухой\n',)), 4),
#  (('что', ('правдой\n',)), 4),
#  (('апрель', ('образом\n',)), 4),
#  (('газовым револьвером.', ('по российским законам\n',)), 4),
#  (('пуриновый нуклеотид в позиции 3', ('его единственной характеристикой\n',)),
#   4),
#  (('что', ('нашей целью\n',)), 4),
#  (('вокалист лидер группы', ('автором большинства текстов и музыки\n',)), 4),
#  (('Барфи', ('притчей во языцех\n',)), 4),
#  (('месторождение', ('китайская морская нефтяная компания CNOOC\n',)), 4),
#  (('отель', ('частью сети отелей Ski\n',)), 4),
#  (('размещение ПРО', ('России30.05', 'ответом на агрессивные действия\n')), 4),
#  (('список', ('полным\n',)), 4),
#  (('Этот отель', ('частью сети отелей ON\n',)), 4),
#  (('магазин расположенный в Санкт-Петербурге',
#    ('надежным элементом рынка охраны труда и техники безопасности\n',)),
#   4),
#  (('этот фильм',
#    ('Сто лет одиночества', 'экранизацией романа Габриэля Маркеса\n')),
#   4),
#  (('частота ОРВИ',
#    ('8 раз в год',
#     'для детей дошкольного и младшего школьного возраста посещающих детские учреждения',
#     'нормальным показателем\n')),
#   4),
#  (('флот', ('для страны', 'ненужной обузой\n')), 4),
#  (('то что количество получаемых ингредиентов задается в процентах от количества исходной номенклатуры',
#    ('особенностью этой операции\n',)),
#   4),
#  (('которое', ('участником Конвенции\n',)), 4),
#  (('Правообладателем которых', ('ЗАО «Лаборатория Касперского»\n',)), 4),
#  (('отель', ('частью сети отелей T2.Вы\n',)), 4),
#  (('что',
#    ('хорошим показателем для блока снабженного активной коррекцией коэффициента мощности\n',)),
#   4),
#  (('отель', ('TA. Скрыть', 'частью сети отелей\n')), 4),
#  (('отель',
#    ('T2.Практическая информация К услугам гостей отеля бесплатная парковка',
#     'частью сети отелей\n')),
#   4),
#  (('ассамблея Совета Европы',
#    ('старейшим в Европе международным парламентским институтом\n',)),
#   4),
#  (('это', ('гарантийным случаем\n',)), 4),
#  (('это',
#    ('важным событием и итогом многолетнего сотрудничества двух стран имеющего всеобъемлющий стратегический характер\n',)),
#   4),
#  (('«Пастранс реклама»', ('сегодняшний день\n',)), 4),
#  (('Sign up for Twitter to follow Фотограф', ('на свадьбу @fottograff\n',)),
#   4),
#  (('Этот отель', ('частью сети отелей Best\n',)), 4),
#  (('которая',
#    ('ожидаемой будущей альтернативной стоимостью денег иногда текущей или реальной ставкой процента\n',)),
#   4),
#  (('провал всей профилактической работы в сфере противодействия религиозному экстремизму',
#    ('результатом\n',)),
#   4),
#  (('PilotF1 Специально для nfs-mostwanted.do.am Материал представленный на сайте',
#    ('собственностью сайта\n',)),
#   4),
#  (('державного виконавцяИсполнительное решение суда',
#    ('исполнительной службой',
#     'последней стадией по выполнению решений суда\n')),
#   4),
#  (('что', ('искомым расстоянием какой отрезок\n',)), 4),
#  (('технологическая надежность ОТН СМИТ которую регистрируют в процессе инженерной квалиметрической оценки и мониторинга производственной деятельности',
#    ('важной объективной характеристикой качества реорганизации\n',)),
#   4),
#  (('поле длины', ('8-битным полем\n',)), 4),
#  (('оно', ('гражданином которой\n',)), 4),
#  (('он', ('участником которой\n',)), 4),
#  (('обратное соответствие', ('функцией\n',)), 4),
#  (('2015 Spravochnikov.ru База данных сайта и всех его поддоменов',
#    ('интеллектуальной собственностью\n',)),
#   4),
#  (('Баннерная рекламаБаннерная реклама',
#    ('самым привычным видом электронной рекламы\n',)),
#   4),
#  (('постоянное использование флейты Йеном Андерсоном',
#    ('самым известным примером\n',)),
#   4),
#  (('отель', ('n.a. Этот', 'частью сети отелей IBIS\n')), 4),
#  (('демократия', ('главной целью', 'числе\n')), 4),
#  (('технология Гитлер вел свою циничную резню эффективно используя усовершенствованную современную индустрию» и задала несколько риторических вопросов таких как «Зло может быть могучей силой соблазнительной идеей но разве оно сильнее чем гениальность талант созидание мужество или благородство',
#    ('отличием между ними\n',)),
#   4),
#  (('шкаф-трансформер',
#    ('наше время очень распространенным вариантом да и самым популярным среди жителей квартир\n',)),
#   4),
#  (('отель', ('частью сети отелей Hilton Hotels\n',)), 4),
#  (('который', ('бесплатным\n',)), 4),
#  (('похудение', ('важным чем', 'психическое здоровье\n')), 4),
#  (('она', ('чем\n',)), 4),
#  (('Крым', ('частью России\n',)), 4),
#  (('сахар',
#    ('настолько же вредным для здоровья продуктом как алкоголь или табак\n',)),
#   4),
#  (('рейтинг', ('интегральным продуктом\n',)), 4),
#  (('жизнь', ('составляющей частью легенды Княжества\n',)), 4),
#  (('предложение', ('публичной офертой по смыслу Гражданского Кодекса РФ\n',)),
#   4),
#  (('президент «Роснефти» Игорь Сечин',
#    ('самым высокооплачиваемым топ-менеджером России\n',)),
#   4),
#  (('отель',
#    ('BW. В этом отеле есть высокоскоростной Интернет',
#     'частью сети отелей\n')),
#   4),
#  (('его длина и материал изготовления',
#    ('особенностью Т-образного воротка INTERTOOL\n',)),
#   4),
#  (('вторичный же', ('резервным\n',)), 4),
#  (('цены наличие товара и другое', ('публичной офертой\n',)), 4),
#  (('оно', ('предметом ипотеки\n',)), 4),
#  (('отель',
#    ('частью сети отелей Days Inn.К услугам гостей отеля высокоскоростной Интернет\n',)),
#   4),
#  (('концовка', ('главным недостатком сериала\n',)), 4),
#  (('дополнительная вентиляция',
#    ('не маловажной ее задачей в жаркую погоду\n',)),
#   4),
#  (('выпуск журнала', ('источником новостей в мире вязания крючком\n',)), 4),
#  (('число', ('простым\n',)), 4),
#  (('физлицо которое на июль 2014 года занимало пост гендиректора ЗАО Кваренги холл',
#    ('базе данных Спарк собственником ОАО Премьер инвест\n',)),
#   4),
#  (('карловарская вода качественный спирт природный сахар и специфически слегка горчащая смесь из приблизительно 32 трав и корешков',
#    ('составляющей его исключительного вкуса\n',)),
#   4),
#  (('ваше правительство Азарова', ('правительством\n',)), 4),
#  (('ссылка на первоисточник', ('условием перепечатки и ретрансляции\n',)), 4),
#  (('хостинг сайтов', ('самым доступным видом хостинга\n',)), 4),
#  (('видео', ('частью следующих коллекций\n',)), 4),
#  (('2014Данный сайт', ('российским сегментом сети Интернет\n',)), 4),
#  (('адвокатаИсполнительное решение суда исполнительной службой',
#    ('последней стадией по выполнению решений суда\n',)),
#   4),
#  (('отель',
#    ('YX.В этом отеле к услугам гостей для гостей в инвалидных креслах',
#     'частью сети отелей\n')),
#   4),
#  (('что',
#    ('ныне продолжительностью среднего синодического месяца в еврейском календаре\n',)),
#   4),
#  (('который', ('символом города\n',)), 4),
#  (('автор авторы полезной модели сведения о его месте жительства месте пребывания',
#    ('заявителем заявителями\n',)),
#   4),
#  (('пресс-релиз',
#    ('предложением о продаже ценных бумаг в Российской Федерации\n',)),
#   4),
#  (('она', ('из которых', 'младшей\n')), 4),
#  (('он', ('вредоносным', 'чем же\n')), 4),
#  (('адвокатИсполнительное решение суда исполнительной службой',
#    ('последней стадией по выполнению решений суда\n',)),
#   4),
#  (('который',
#    ('«Aplaus» внимательный обслуживающий персонал предл.', 'частью отеля\n')),
#   4),
#  (('отель', ('частью сети отелей Inter -hotel\n',)), 4),
#  (('этот отель', ('прекрасным\n',)), 4),
#  (('жрец Лиздейка по легенде сын Наримунта', ('родоначальником\n',)), 4),
#  (('парк', ('волевым толстяком\n',)), 4),
#  (('искусство', ('чудесным способом для\n',)), 4),
#  (('достаточно большое потребление сжатого воздуха 230 300 литров минуту',
#    ('недостатком пневматических краскопультов системы HVLP\n',)),
#   4),
#  (('мотив привидений', ('неотъемлемой частью детских мультфильмов\n',)), 4),
#  (('этого специального «шарфового» плетения',
#    ('то что ткань тянется только в диагональном направлении\n',)),
#   4),
#  (('поспешность заказчика который начинает выполнять строительство сетей',
#    ('распространённым просчётом',
#     'сразу после того как от проектировщиков получена схема внешнего электроснабжения без получения согласований имеющегося проекта\n')),
#   4),
#  (('отель', ('частью сети отелей IQ.В этом отеле\n',)), 4),
#  (('Мадрид', ('географическим центром страны\n',)), 4),
#  (('разрез спереди пазушка украшенный вышивкой',
#    ('особенностью мужской украинской рубахи\n',)),
#   4),
#  (('тариф', ('стоимостью всего периода пребывания\n',)), 4),
#  (('налогоплательщик', ('гражданином которой\n',)), 4),
#  (('вставка ластовица в области промежности выполненная из сетки',
#    ('большой но не малозначимой особенностью этих летних брюк\n',)),
#   4),
#  (('Кержаков',
#    ('прекрасным примером профессионализма для футболистов Цюриха\n',)),
#   4),
#  (('территория к северу от Ленинграда', ('запретной зоной»\n',)), 4),
#  (('которое',
#    ('обладателем авторских прав на произведения Виктора Цоя в иске о взыскании\n',)),
#   4),
#  (('требование с гражданина РФ прописки в Москве',
#    ('нарушением Статьи 45 Конституции РФ\n',)),
#   4),
#  (('решение суда исполнительной службой',
#    ('последней стадией по выполнению решений суда\n',)),
#   4),
#  (('самая дорогая', ('ремонтом на сто\n',)), 4),
#  (('вся информация',
#    ('на нем', 'публичной офертой определяемой положениями Статьи 437 2\n')),
#   4),
#  (('он',
#    ('собственником жилого помещения или нет и для регистрации несовершеннолетнего ребёнка\n',)),
#   4),
#  (('отель', ('частью сети отелей WV\n',)), 4),
#  (('перевод', ('официальным\n',)), 4),
#  (('«ангелом» Victoria’s Secret', ('2015 года\n',)), 4),
#  (('наличие собственного устройства', ('рекомендацией\n',)), 4),
#  (('предприятие',
#    ('генеральным дистрибютором торговой марки Старий друже\n',)),
#   4),
#  (('отель', ('частью сети отелей YX\n',)), 4),
#  (('он', ('резидентом которого\n',)), 4),
#  (('вариант названия «орангута́нг»',
#    ('равнозначным', 'разговорном русском языке\n')),
#   4),
#  (('которая',
#    ('в этом году',
#     'председателем в Организации стран экспортеров нефти ОПЕК\n')),
#   4),
#  (('что', ('настоящим королём\n',)), 4),
#  (('шкура животного', ('основой при котором\n',)), 4),
#  (('что',
#    ('хорошим допущением для мгновенного потока в средней тропосфере умеренных широт\n',)),
#   4),
#  (('он', ('такой уж жестокой\n',)), 4),
#  (("On'", ('объектом эко-дизайна\n',)), 4),
#  (('кто', ('им\n',)), 4),
#  (('отправитель', ('клиентом банка получателя\n',)), 4),
#  (('его проведение в реальном времени',
#    ('кроме того полученные изображения не нуждаются в специальной обработке\n',)),
#   4),
#  (('что', ('нарушением врачебной тайны\n',)), 4),
#  (('которая', ('гидроизоляцией но не пароизоляцией\n',)), 4),
#  (('данный инструмент', ('самым ликвидным\n',)), 4),
#  (('отель', ('частью сети отелей YX.К услугам гостей отеля бассейн.\n',)), 4),
#  (('возможность регулировки скорости вращения',
#    ('преимуществом данной модели\n',)),
#   4),
#  (('что', ('довольно надежным признаком овуляции\n',)), 4),
#  (('Opticum 3000L', ('клоном чего\n',)), 4),
#  (('это', ('заблуждением\n',)), 4),
#  (('сохранение тепла и /или отвод влаги с поверхности тела',
#    ('основным назначением которого\n',)),
#   4),
#  (('он', ('лидером которой\n',)), 4),
#  (('отель',
#    ('сауна', 'частью сети отелей Radisson Blu.К услугам гостей отеля\n')),
#   4),
#  (('2011 года', ('момент выхода ролика', 'последней версией\n')), 4),
#  (('который',
#    ('по совместительству', 'художественным руководителем Театра.doc\n')),
#   4),
#  (('что', ('существенным недостатком\n',)), 4),
#  (('то что ведьмы до сих пор живут среди нас',
#    ('самым удивительным из них\n',)),
#   4),
#  (('информация им предоставленная', ('при предоставлении информации\n',)), 4),
#  (('молоко',
#    ('единственным продуктом который необходим новорожденному малышу\n',)),
#   4),
#  (('кто', ('чемпионом Голландии\n',)), 4),
#  (('он', ('кем', 'на самом деле\n')), 4),
#  (('чай на сегодняшний день',
#    ('лучшим сертифицированным средством для очистки организма от Паразитов\n',)),
#   4),
#  (('сказка',
#    ('для нас', 'протяжении всей жизни', 'самой близкой и мудрой историей\n')),
#   4),
#  (('поедание человеческого мозга', ('причиной возникновения болезни\n',)), 4),
#  (('ординар иначе одиночная ставка',
#    ('простым видом ставок который предполагает большую вероятность победы\n',)),
#   4),
#  (('вид',
#    ('эндемиком Анголы World Checklist of Selected Plant Families Royal Botanic Gardens Kew Angola Endemic Vascular Plant Genera Checklist\n',)),
#   4),
#  (('любая биссектриса', ('каком треугольнике', 'медианой и высотой\n')), 4),
#  (('Анастасия Петрова', ('на данный момент\n',)), 4),
#  (('лицо получившее от Банка право на пользование картой и образец подписи которого',
#    ('Условиями использования банковских карт Держателем карты\n',)),
#   4),
#  (('которая', ('главной мыслью произведения своими словами\n',)), 4),
#  (('компания Canonical', ('разработчиком и спонсором\n',)), 3),
#  (('Карл Маннгейм показавший социально историческую обусловленность мышления в работе Идеология и утопия',
#    ('основоположником социологии знания\n',)),
#   3),
#  (('он', ('наиболее понятными для начинающих игроков\n',)), 3),
#  (('что',
#    ('в стране где поклоняются золотому тельцу', 'очень редким исключением\n')),
#   3),
#  (('отель', ('частью сети отелей Scandic.\n',)), 3),
#  (('вторичный же', ('второстепенным\n',)), 3),
#  (('такое изображение', ('основным объектом использования\n',)), 3),
#  (('бренд «Дон»',
#    ('Дона» и «100 лучших товаров России»',
#     'многократным победителем конкурса «Лучшие товары\n')),
#   3),
#  (('по исполнительному производствуИсполнительное решение суда',
#    ('исполнительной службой',
#     'последней стадией по выполнению решений суда\n')),
#   3),
#  (('глюкоза', ('мономером которых\n',)), 3),
#  (('ларингоспазм в большинстве случаев',
#    ('жизни', 'следствием бронхита и сильного удушливого кашля\n')),
#   3),
#  (('отель', ('частью сети отелей Husa\n',)), 3),
#  (('что', ('магом\n',)), 3),
#  (('проект ВШКА WEB-отделение', ('аналогом очного обучения\n',)), 3),
#  (('размер винрейта', ('хорошим\n',)), 3),
#  (('он', ('туристической достопримечательностью\n',)), 3),
#  (('Правление',
#    ('коллегиальным исполнительным органом и подотчетно общему собранию собранию уполномоченных Правление избирается общим собранием собранием уполномоченных из числа членов кооператива сроком на три года\n',)),
#   3),
#  (('расположенный', ('идеальной отправной точкой для экскурсий в Медан\n',)),
#   3),
#  (('кара', ('результатом любви\n',)), 3),
#  (('он', ('основным\n',)), 3),
#  (('который', ('вымершим\n',)), 3),
#  (('которая',
#    ('дочерью популярного певца 1990-х Билли Рэя Сайруса который также был звездой сериала\n',)),
#   3),
#  (('что', ('важным\n',)), 3),
#  (('что', ('высокопоставленным членом нового общества\n',)), 3),
#  (('сочетание лесостепных ландшафтов окультуренных человеком с боровыми ландшафтами давно потерявшими свою первозданность',
#    ('характерной особенностью природы окрестностей села\n',)),
#   3),
#  (('вид',
#    ('эндемиком Танзании Tanzania Endemic Vascular Plant Genera Checklist\n',)),
#   3),
#  (('ГК «Ланмар»',
#    ('крупным реализатором резинотехнической продукции в Южном Федеральном Округе\n',)),
#   3),
#  (('сталь 65г с закалкой 50ед', ('холодным оружием\n',)), 3),
#  (('Аргон', ('не единственным благородным или инертным газом\n',)), 3),
#  (('официальный сайт АО «Эксперт РА» www.raexpert.ru',
#    ('источником отражающим актуальное состояние рейтинговой оценки\n',)),
#   3),
#  (('побелка верхней части стен мелом с одновременной окраской нижней части стен панелей масляной краской',
#    ('распространенной отделкой стен и в частных домах и в квартирах\n',)),
#   3),
#  (('Какое утверждение', ('неверным\n',)), 3),
#  (('Министр иностранных дел', ('по должности', 'того\n')), 3),
#  (('Форекс', ('весьма успешной и горячо любимой трейдерами\n',)), 3),
#  (('«упрощённой» модели 5C',
#    ('продвинутой версией предшествующей пятой модели\n',)),
#   3),
#  (('также станция метро', ('хорошим 7 мин ходьбы\n',)), 3),
#  (('момент', ('нашей целью\n',)), 3),
#  (('партнерство «Саморегулируемая организация «Краснодарские строители» сокращенное наименование НП «СРО «Краснодарские строители»',
#    ('капитальный ремонт созданной для содействия ее членам в осуществлении деятельности направленной на достижение целей предусмотренных Уставом',
#     'некоммерческой организацией основанной на членстве субъектов предпринимательской деятельности юридических лиц и индивидуальных предпринимателей осуществляющих строительство реконструкцию\n')),
#   3),
#  (('кривая', ('геодезической\n',)), 3),
#  (('«Шат- сандарбхи» в котором изложены основные положения богословия гаудия вайшнавизма',
#    ('автором труда\n',)),
#   3),
#  (('повышенный выход готовой продукции без ухудшения вкусовых качеств и более плотная и качественная набивка батонов',
#    ('преимуществом использования вакуума\n',)),
#   3),
#  (('статья', ('заготовкой\n',)), 3),
#  (('масса баллонов',
#    ('номинальной',
#     'при изготовлении баллонов под углекислоту с ограничением по массе\n')),
#   3),
#  (('контракт',
#    ('полным и выражения соглашение Целые между отелями и Sercotel пользователя\n',)),
#   3),
#  (('полипропилен', ('антикоррозийным покрытием', 'того\n')), 3),
#  (('Бог единый в трёх лицах',
#    ('бестелесным невидимым духом Ин 4 24 живым Иер\n',)),
#   3),
#  (('которое', ('началом истории спасения\n',)), 3),
#  (('Хартия Земли признанная ЮНЕСКО полностью отождествляющая содержание Хартии со своими принципами и целями',
#    ('по данным вопросам', 'ярким международным документом\n')),
#   3),
#  (('армированная лента',
#    ('новым антикоррозионным материалом который не загрязняет\n',)),
#   3),
#  (('продукт',
#    ('противоопухолевым антибактериальным обеззараживающим средством\n',)),
#   3),
#  (('она', ('дочерью известного врача Эллис Грей\n',)), 3),
#  (('информация размещенная на сайте Werkman.ru', ('публичной офертой\n',)), 3),
#  (('которая', ('ничем иным как регулировкой чувствительности приемника\n',)),
#   3),
#  (('чатуранга появившаяся в Индии не позднее V —VI веков',
#    ('корнем которой\n',)),
#   3),
#  (('сбор четырёх компонентов из сбежавших существ',
#    ('основным заданием которой\n',)),
#   3),
#  (('отель',
#    ('частью сети отелей YX.К услугам гостей отеля высокоскоростной Интернет.\n',)),
#   3),
#  (('это', ('недостатком', 'по европейским нормам\n')), 3),
#  (('Нарушение сна Причины и факторы риска ночного апноэ',
#    ('Фактической причиной появления обструктивного ночного апноэ\n',)),
#   3),
#  (('что', ('большим преимуществом\n',)), 3),
#  (('отель',
#    ('открытый бассейн.', 'частью сети отелей MX.К услугам гостей отеля\n')),
#   3),
#  (('чем толщина прогреваемого слоя что обычно характерно для СВЧ энергоподвода',
#    ('глубине проникновения меньшей', 'однородным\n')),
#   3),
#  (('похудение', ('какой серьезной задачей\n',)), 3),
#  (('она', ('общепризнанной великой державой\n',)), 3),
#  (('тот факт что транспортная компания намного эффективней своего клиента во всем что касается транспорта',
#    ('в пользу корпоративного транспортного обслуживания',
#     'важным аргументом\n')),
#   3),
#  (('что', ('несомненным преимуществом этого вида постройки\n',)), 3),
#  (('отель', ('n.a. Этот', 'частью сети отелей\n')), 3),
#  (('агентство LIGURIARU',
#    ('официальным представителем итальянских агентств недвижимости и строительных компаний на российском рынке\n',)),
#   3),
#  (('он',
#    ('единственным музыкантом чья игра на гармонике заслужила такой высокой оценки\n',)),
#   3),
#  (('работа автоматики основанная на ходе ствола вперед', ('особенностью\n',)),
#   3),
#  (('собрание', ('правомочным\n',)), 3),
#  (('группа «Приват» И.',
#    ('акционером компании «Аэросвит» владеющей контрольным пакетом акций «Донбассаэро»\n',)),
#   3),
#  (('отель', ('частью сети отелей Intercontinental Hotels\n',)), 3),
#  (('именно он',
#    ('основной причиной образования и роста разного рода раковых клеток\n',)),
#   3),
#  (('именно колотая брусчатка', ('прародительницей остальных видов\n',)), 3),
#  (('экстендер Пенимастер',
#    ('на данный момент',
#     'самым современным и технически совершенным прибором в мире с помощью которого можно увеличить пенис в условиях дома или исправить его форму\n')),
#   3),
#  (('это', ('данном случае', 'еще и большим конкурентным преимуществом\n')), 3),
#  (('это', ('показателем\n',)), 3),
#  (('посадка картофеля',
#    ('приходом весны одним из основных заданий многих жителей Украины\n',)),
#   3),
#  (('прямой начальник', ('его непосредственным начальником\n',)), 3),
#  (('информация Цигун',
#    ('традиционной китайской системой самооздоровления\n',)),
#   3),
#  (('он', ('в которых', 'либо исполнителем либо руководителем\n')), 3),
#  (('информация на сайте', ('объектом авторских прав\n',)), 3),
#  (('отель', ('частью сети отелей UZ.Вы\n',)), 3),
#  (('МКСК МКСГ МКСЛ МСК МСС МКГСС и МТС', ('единицей времени\n',)), 3),
#  (('что',
#    ('наивысшим достижением за всю историю профессионального Counter-Strike\n',)),
#   3),
#  (('Бавария»', ('официальным импортером BMW MINI ALPINA и BMW Motorrad\n',)),
#   3),
#  (('Этот отель',
#    ('тренажерный зал.', 'услугам гостей отеля', 'частью сети отелей\n')),
#   3),
#  (('школьник который присоединяется к специализированному факультативному исполнительному отделению англ',
#    ('3 главным героем', 'Persona\n')),
#   3),
#  (('отель', ('частью сети отелей Golden Tulip Hotels.\n',)), 3),
#  (('действующий президент страны', ('магистром ордена\n',)), 3),
#  (('покупка которых', ('НЕ первостепенной\n',)), 3),
#  (('Силва',
#    ('восьмым Генеральным директором со дня основания Организации в Квебеке Канаде 16 октября 1945 г\n',)),
#   3),
#  (('открытое и публичное обсуждение планируемых действий правительства и принятие решений с учетом мнения общественности',
#    ('ключевым фактором эффективности механизмов решения экологических проблем страны\n',)),
#   3),
#  (('предоставление возможности аудио визуального контакта с оператором непосредственно с киоска',
#    ('основной особенностью которого\n',)),
#   3),
#  (('немецкий язык', ('языком общения на территории Германии\n',)), 3),
#  (('какой она',
#    ('на самом деле жестокой и беспощадной как с одной стороны так и с другой\n',)),
#   3),
#  (('я б. озвученный в фильмах Фрэнком Озом',
#    ('вымышленным персонажем придуманным компанией Lucasfilm\n',)),
#   3),
#  (('то что произошло', ('всех', 'шоком\n')), 3),
#  (('арбуз', ('самой большой ягодой в мире\n',)), 3),
#  (('Белый»',
#    ('Кесльевски первый «Три цвета Синий» а третий «Три цвета Красный»',
#     'вторым в трилогии Кшиштофа\n')),
#   3),
#  (('старинная артиллерийская башня Святого Игнасия построенная в XIV XV веках',
#    ('одной достопримечательностью Бетюна\n',)),
#   3),
#  (('наказание', ('платой за грехи\n',)), 3),
#  (('zexx КИА Пиканто', ('конкурентом Пежо 2008\n',)), 3),
#  (('стоимость 12 000 рублей', ('минусом\n',)), 3),
#  (('монастырский чай от диабета',
#    ('сравнительно новым продуктом на рынке\n',)),
#   3),
#  (('словосочетание к несчастью', ('какой частью речи\n',)), 3),
#  (('что', ('большим плюсом\n',)), 3),
# ...
#  (('система', ('голономной\n',)), 3),
#  (('что', ('благом\n',)), 3),
#  (('индивидуализм в лице например Ницше восходящий к левой стороне гегелевской школы в особенности к Максу Штирнеру',
#    ('представителем номинализма настоящего времени\n',)),
#   3),
#  (('что', ('причинами косолапости\n',)), 3),
#  (('телевизионное изображение',
#    ('массивом отдельных точек который однако воспринимается как единая сцена\n',)),
#   3),
#  (('болезненное ощущение у ребёнка', ('уже совершенно очевидным\n',)), 3),
#  (('магическая Долина Фей', ('домом\n',)), 3),
#  (('истина', ('объективным отношением языка и мира\n',)), 3),
#  (('постоянное изменение трудовой функции работника',
#    ('в соответствии со статьей 72. 1 Трудового кодекса РФ',
#     'переводом на другую работу\n')),
#   3),
#  (('одним из разделов молекулярной биологии', ('сути\n',)), 3),
#  (('природный газ', ('самым экономичным видом топлива', 'сегодняшний день\n')),
#   3),
#  (('кто', ('его плательщиком\n',)), 3),
#  (('размер члена', ('важным показателем', 'любого мужчины\n')), 3),
#  (('оплата WebMoney разных товаров и услуг', ('сегодняшний день\n',)), 3),
#  (('близость', ('естественной потребностью человека\n',)), 3),
#  (('что', ('большой редкостью\n',)), 3),
#  (('лента «Храбрая сердцем»',
#    ('Пиксар и Дисней вышедшим на экраны в 2012 году',
#     'совместным творением студий\n')),
#   3),
#  (('настоящий греческий салат с сыром фета приготовленный с учетом всех тонкостей рецептуры',
#    ('блюдом', 'просто невероятного вкуса и аромата\n')),
#   3),
#  (('Марли', ('самым известным исполнителем в стиле регги\n',)), 3),
#  (('процесс PvE', ('единственным способом развития «прокачки»\n',)), 3),
#  (('скандал вокруг голой героини в душе',
#    ('искусственно раздутым для поддержания популярности игры\n',)),
#   3),
#  (('наличие спонтанной активности отдельных волокон мышцы повышение амплитуды ЭМГ сигнала',
#    ('признаками\n',)),
#   3),
#  (('Австралия',
#    ('островом материком согласно другой что первые поселенцы чтобы добраться до него были вынуждены плыть морем\n',)),
#   3),
#  (('Любовь Зайцева', ('руководителем\n',)), 3),
#  (('«Энергостандарт»',
#    ('поставщиком асинхронных трехфазных электродвигателей с короткозамкнутым ротором общепромышленного назначения с привязкой мощности к габаритным размерам по ГОСТ 28330 РС 3031 71 марки АМ АМН промышленных насосных агрегатов трехвинтовые шестеренные сетевые и питательные насосы промышленных вентиляторов и другого электротехнического оборудования\n',)),
#   3),
#  (('Рособрнадзор при перепечатке и копировании материалов сайта ссылка на Рособрнадзор',
#    ('обязательной\n',)),
#   3),
#  (('данного поля', ('приватным\n',)), 3),
#  (('компания', ('сегодняшний день\n',)), 3),
#  (('«ЛаВин',
#    ('лучшим данкером со времен прайма Винса Картера» 28 15 42 НБА\n',)),
#   3),
#  (('Графики Палитры и RGB/CMYK/HSL ПреобразованиеEncycolorpedia',
#    ('| Расширенные цвета', 'темный оттенком голубой', 'цвета\n')),
#   3),
#  (('это имущество', ('предметом залога\n',)), 3),
#  (('классический стиль', ('чертой дизайнерской коллекции Kerasan Retro\n',)),
#   3),
#  (('2016 «Летидор»',
#    ('частью компании Rambler&Co117105 Москва Варшавское ш. 9 стр\n',)),
#   3),
#  (('чай', ('знаком уважения\n',)), 3),
#  (('наличие плода развивающегося из завязи цветка',
#    ('особенностью этого отдела\n',)),
#   3),
#  (('которая', ('обязательной\n',)), 3),
#  (('профилактика',
#    ('и при любом заболевании наилучшим средством лечения варикозного расширения вен\n',)),
#   3),
#  (('Зевса»',
#    ('другая книга писательницы Воронковой «В глуби веков» в которой раскрывается вся бурная противоречивая наполненная многими важными событиями жизнь македонского полководца',
#     'продолжением «Сына\n')),
#   3),
#  (('Российская Федерация л',
#    ('в отношении товаров',
#     'в графе 11 номер таможенной декларации',
#     'страной происхождения которых\n')),
#   3),
#  (('развитие социальных связей', ('обязательным\n',)), 3),
#  (('консервативность', ('грузом все века\n',)), 3),
#  (('Новый год',
#    ('всем мире', 'самым любимым и поистине народным праздником\n')),
#   3),
#  (('их подготовительный этап подготовка реставрационного объекта под покраску',
#    ('фактором который влияет на конечное качество работ\n',)),
#   3),
#  (('Множественная эндокринная неоплазия типа IIb',
#    ('самым серьёзным вариантом синдрома МЭН\n',)),
#   3),
#  (('FAQ', ('официальной техподдержкой устройств компании Amazon\n',)), 3),
#  (('река Белдур',
#    ('по другую сторону которой лежат Орсаль и Тралия',
#     'южной его границей\n')),
#   3),
#  (('историографический аспект',
#    ('изучении средневековой истории Русского Севера', 'наиболее.\n')),
#   3),
#  (('Расселл Болдинг Rassell Balding',
#    ('в ведении холдинга Sydney Airport Corporation Limited SACL',
#     'генеральным директором\n')),
#   3),
#  (('CSS3Соотносящиеся Цвета', ('светлый оттенком голубой\n',)), 3),
#  (('Шевроле Ланос',
#    ('с пробегом в Запорожье в то же время', 'своеобразной авантюрой\n')),
#   3),
#  (('надежность которую обеспечивает непревзойденное японское качество',
#    ('особенностью всех моделей часов orient\n',)),
#   3),
#  (('обстоятельство что повышенная влажность среды в девяноста случаях из ста приводит к образованию на элементах конструкций грибка или плесени которые в свою очередь способствуют полной её порче',
#    ('для кого', 'секретом\n')),
#   3),
#  (('проведение одной командой нескольких игр в день',
#    ('к тому же',
#     'обычной практикой',
#     'при ярком солнце или при дожде и сильном ветре\n')),
#   3),
#  (('что', ('самым большим значением для обзорных журналов по иммунологии\n',)),
#   3),
#  (('она', ('обеспечением по автокредиту\n',)), 3),
#  (('труд человека', ('на земле\n',)), 3),
#  (('то что их не стоит перекармливать',
#    ('главным в кормлении аквариумных рыбок\n',)),
#   3),
#  (('бывший студент ее отца Джон Кардинал', ('настоящим виновником\n',)), 3),
#  (('получение контроля над профсоюзами» без этого победа революции невозможна',
#    ('«приоритетной задачей для коммунистических партий\n',)),
#   3),
#  (('отель',
#    ('открытый бассейн.', 'частью сети отелей GTA.К услугам гостей отеля\n')),
#   3),
#  (('возможность обслуживания клиентов во всех районах города',
#    ('главным конкурентным преимуществом перед другими пиццериями\n',)),
#   3),
#  (('размещение металлургии и промышленности вооружения западнее Урала',
#    ('другим слабым местом советской военной экономики\n',)),
#   3),
#  (('продавец', ('владельцем автомобиля\n',)), 3),
#  (('Нормандия 2009» и участницей конкурса «Мисс Вселенная 2010» на котором вошла в Top15 заняв в итоге 13-е место',
#    ('победительницей конкурса «Мисс\n',)),
#   3),
#  (('рецепт крема', ('основным\n',)), 3),
#  (('камера с тройным автофокусом.', ('главной особенностью которого\n',)), 3),
#  (('зимняя парка мужская', ('отличным решением для российских холодов\n',)),
#   3),
#  (('Дэйв',
#    ('Lightning» со второго альбома Ride the Lightning',
#     'соавтором песен «The Call of Ktulu» и «Ride the',
#     'этого\n')),
#   3),
#  (('что', ('отличным результатом\n',)), 3),
#  (('грех', ('катастрофой по\n',)), 3),
#  (('история планеты', ('тайной для мало-мальски образованного человека\n',)),
#   3),
#  (('URL', ('абсолютным или относительным\n',)), 3),
#  (('отель',
#    ('LI. В этом отеле к услугам гостей мини кухня', 'частью сети отелей\n')),
#   3),
#  (('сокращение объема употребляемой пищи и как следствие равномерное снижение веса',
#    ('целью которых\n',)),
#   3),
#  (('штат Виктория', ('самым высоким по поверхности крыши\n',)), 3),
#  (('она',
#    ('джаз гитаристом', 'музыкальным бизнесом', 'на сегодняшний день\n')),
#   3),
#  (('который', ('в отличие от сульфата бария', 'рентгенонегативным\n')), 3),
#  (('Михаил Швыдкой',
#    ('94,9 миллиона рублей', 'художественным руководителем которого\n')),
#   3),
#  (('он', ('автором которых\n',)), 3),
#  (('она', ('Королевой Викторией\n',)), 3),
#  (('аэропорт Токио Ханеда IATA: HND', ('международным\n',)), 3),
#  (('информация представленная на вебсайте Бюро Консульских Отношений Государственного Департамента США и вебсайтах Дипломатических Миссий США',
#    ('окончательной\n',)),
#   3),
#  (('зеленый', ('светлый оттенком\n',)), 3),
#  (('помещение',
#    ('объектом недвижимости подлежащим государственной кадастровой оценке\n',)),
#   3),
#  (('внутригородской железнодорожный транспорт',
#    ('важнейшим элементом транспортной системы современного города одним из основных инструментов поддержания мобильности населения и высоких стандартов жизни\n',)),
#   3),
#  (('который', ('переносчиком вируса Зика\n',)), 3),
#  (('процедура',
#    ('болезненной хоть и проводится порой без какого-либо дополнительного обезболивания\n',)),
#   3),
#  (('защита людей', ('главной целью\n',)), 3),
#  (('и «Каприччио на отъезд любимого брата» И.', ('сочинением\n',)), 3),
#  (('шифрование данных которое применяется в тех случаях когда необходимо защитить передаваемую информацию от доступа несанкционированными получателями',
#    ('функцией выполняемой на уровне представлений\n',)),
#   3),
#  (('Земля', ('эксклюзивным поставщиком Натурал Калма в Россию\n',)), 3),
#  (('отель', ('частью сети отелей Danske Kroer Hoteller\n',)), 3),
#  (('его защита от пилы и влаги',
#    ('для производства строительных материалов',
#     'необходимым критерием для светильников\n')),
#   3),
#  (('энергетическая система РБ производство транспорт и потребление электрической и тепловой энергии',
#    ('частью энергетической системы России\n',)),
#   3),
#  (('щее время город',
#    ('настоя',
#     'центром изучения прикладной или т.н. практической археологии\n')),
#   3),
#  (('программа',
#    ('уникальным не имеющим аналогов образовательным продуктом совмещающим в себе как теоретическую подготовку слушателей\n',)),
#   3),
#  (('он', ('в вымышленной спортивной игре блицбол', 'знаменитым форвардом\n')),
#   3),
#  (('документ', ('не официальным переводом исходной английской версии\n',)), 3),
#  (('ногтей”',
#    ('разработка генеалогического древа своей фамилии',
#     'средством порождения чувства патриотизма с “младых\n')),
#   3),
#  (('главная «дипломатическая» награда Испании',
#    ('Канцлером', 'великим магистром этого ордена', 'король Испании\n')),
#   3),
#  (('Какая температура процессора',
#    ('года назад', 'максимальной для ноутбука на процессоре i7\n')),
#   3),
#  (('народ первая предупредительная и предупредительная и последняя будут требовать от власти выполнения обещаний это уже смешно..',
#    ('Долой лживую власть', 'единственным источником власти\n')),
#   3),
#  (('отличие отрицания от вытеснения заключающееся в том что информация подверженная вытеснению сначала была осознана и только потом вытеснена а информация подвергнутая отрицанию в сознание вообще не попадает',
#    ('моментом\n',)),
#   3),
#  (('город Ньютон', ('центром\n',)), 3),
#  (('кто', ('преступником\n',)), 3),
#  (('что', ('колдуньей\n',)), 3),
#  (('MongoDB', ('по которым\n',)), 3),
#  (('он',
#    ('автором более 30 синглов вошедших в Top 10 списка Hot Country Songs журнала Billboard из которых 20 возглавляли этот чарт.\n',)),
#   3),
#  (('клеменцевоковыльная степь с доминированием редкого вида ковыля Клеменца Stipa klemenzii и участием ковыля Крылова Stipa krylovii',
#    ('сообществом степей\n',)),
#   3),
#  (('выдуманная автором смерть американского конгрессмена Энтони Даймонда',
#    ('в результате дорожно транспортного происшествия\n',)),
#   3),
#  (('он',
#    ('истинно научным журналом',
#     'то что содержание журнала является строгим с научной точки зрения и отражает последние достижения физики\n')),
#   3),
#  (('дед',
#    ('французским актёром и председателем французской кинокомпании Pathé.В 2005 году\n',)),
#   3),
#  (('через сайт', ('предварительным\n',)), 3),
#  (('«Средство передачи сообщения',
#    ('сообщением» что было впоследствии предметом многих дискуссий\n',)),
#   3),
#  (('ссылка на источник',
#    ('обязательным условием перепечатки или ретрансляции\n',)),
#   3),
#  (('Церковь', ('единственным провайдером бога', 'на земле\n')), 3),
#  (('доля мигрантов в структуре населения', ('особ.\n',)), 3),
#  (('обзор',
#    ('демонстрацией перспектив фармацевтической индустрии открывающихся в новой для России области гомеопатии\n',)),
#   3),
#  (('рынок',
#    ('основным развлечением для многих туристов которые не посещают отвязные гоанские вечеринки',
#     'субботу\n')),
#   3),
#  (('то что', ('плюсом\n',)), 3),
#  (('код', ('ещё раз', 'корректным\n')), 3),
#  (('поломка компрессора', ('существенным недостатком', 'у холодильника\n')),
#   3),
#  (('ускорение', ('для всех направлений', 'единым\n')), 3),
#  (('Jan Wielemaker', ('создателем и основным разработчиком\n',)), 3),
#  (('оно', ('вымышленным специально для данной композиции\n',)), 3),
#  (('РФ. Строй-М Светлей',
#    ('публичной офертой определяемой статьей 437 ГК\n',)),
#   3),
#  (('Квинсленд',
#    ('на данный момент', 'самым высоким зданием в Австралии со шпилем\n')),
#   3),
#  (('это', ('недостатком метода\n',)), 3),
#  (('его интерфейс',
#    ('на самом деле',
#     'текстовым или COW Character Oriented Window окна ориентированные на знаки\n')),
#   3),
#  (('Мани Банка', ('направлениями деятельности ДжиИ\n',)), 3),
#  (('заседание проводимое не реже 1 раза в месяц школьную газету',
#    ('организационной формой деятельности Совета старшеклассников',
#     'работу информационного творческого объединения\n')),
#   3),
#  (('увеличение члена при помощи экстендера',
#    ('единственным способом используемым в официальной медицине для увеличения и исправления формы полового члена',
#     'нехирургическим путем\n')),
#   3),
#  (('бесплатная доставка и высокое качество монтажа',
#    ('одним голосом в пользу того чтобы купить кухню под заказ на сайте kuxni-lux.ru\n',)),
#   3),
#  (('Савва Бродский', ('таковым художником\n',)), 3),
#  (('Википедия»', ('про «Чем\n',)), 3),
#  (('эта церковь',
#    ('самым старым действующим христианским храмом в Африке\n',)),
#   3),
#  (('что', ('денежным эквивалентом имущества которое у него было\n',)), 3),
#  (('Бог', ('дверной ручкой столом флагштоком или лампочкой\n',)), 3),
#  (('спряжение глаголов', ('главной трудностью испанской грамматики\n',)), 3),
#  (('магазин расположенный в Ульяновске',
#    ('надежным элементом рынка охраны труда и техники безопасности\n',)),
#   3),
#  (('палаццо построенное ещё в 17 веке обладателем красной шапочки кардиналом Камилло Боргезе',
#    ('излюбленным местом прогулок жителей и гостей Рима\n',)),
#   3),
#  (('враг с меткой', ('целью\n',)), 3),
#  (('она', ('астероидом\n',)), 3),
#  (('Мани Банка', ('задачей ДжиИ\n',)), 3),
#  (('он сам', ('соучастником\n',)), 3),
#  (('молоко', ('более вредным для здоровья человека чем курение сигарет\n',)),
#   3),
#  (('«Оборудование тара и упаковка для пищевой промышленности»',
#    ('отраслью деятельности компании\n',)),
#   3),
#  (('и внутридермальный пигментный невус папилломатозный невус и еще некоторое количество невусов которые лично определить всегда очень трудно',
#    ('меланомонеопасным\n',)),
#   3),
#  (('она',
#    ('наименее открытой и привлекательной как для импорта так и для экспорта\n',)),
#   3),
#  (('четыре брата младший из которых Оламайд Фэйсон',
#    ('Дональда Фэйсона', 'участником американской R&B группы\n')),
#   3),
#  (('жаропрочность',
#    ('характеристикой определяющей работоспособность стали\n',)),
#   3),
#  (('Штейнзальц',
#    ('автором более 60 книг и сотен статей на различные темы включая Талмуд Еврейскую мистику Еврейскую философию социологию и философию',
#     'целом\n')),
#   3),
#  (('эта колыбельная',
#    ('4 лет с 1982 по 1986 год',
#     'заставкой телепередачи с одноимённым названием',
#     'по нынешнее время\n')),
#   3),
#  (('Авто»',
#    ('на рынке г.Одессы и юга Украины', 'официальным дилером Mazda\n')),
#   3),
#  (('отель', ('частью сети отелей Mercure\n',)), 3),
#  (('что', ('рекордом для Балкан и всей прилегающей территории\n',)), 3),
#  (('панда', ('символом Всемирного фонда дикой природы WWF\n',)), 3),
#  (('эта проблема', ('образом', 'постоянной для вас\n')), 3),
#  (('«Волга»',
#    ('ОАО “Заволжский моторный завод” который поставляет следующие модификации двигателей ЗМЗ 402 ЗМЗ 405 ЗМЗ 406 ЗМЗ 409',
#     'поставщиком силовых агрегатов двигателе ДВС для автомобилей семейства\n')),
#   3),
#  (('что', ('настолько мощным и умным и Вы\n',)), 3),
#  (('защита коконов с яйцами', ('некоторых видов', 'целью объединения\n')), 3),
#  (('левая', ('античной', 'из двух полукруглых башен\n')), 3),
#  (('крыжма', ('атрибутом обряда крещения\n',)), 3),
#  ...]

# %%
d['amod obj']
# Out:
# {'бесплатную услугу',
#  'большие номера',
#  'большой выбор',
#  'взаимовыгодное сотрудничество',
#  'дизайнерские номера',
#  'инжиниринговые услуги',
#  'канадские дома',
#  'некурящие номера',
#  'оригинальные детали',
#  'просторные номера',
#  'различные номера',
#  'смежные номера',
#  'специализированные видеокодеки',
#  'такие уд',
#  'такие удобст',
#  'такие удобства',
#  'такие фотоуслуги',
#  'цветные смесители',
#  'экскурсионное бюро.',
#  'элегантные номера'}

# %%
Counter(seqs).most_common()
# Out:
# [('amod obl', 160),
#  ('amod obj', 147),
#  ('obl', 63),
#  ('obj', 40),
#  ('case obl', 10),
#  ('amod obj nmod', 7),
#  ('case amod obl', 4),
#  ('obl nmod', 3),
#  ('obj case nummod', 3),
#  ('amod obj nmod cc conj nmod', 3),
#  ('amod obj amod nmod', 3),
#  ('amod amod obj', 3),
#  ('obl case', 2),
#  ('amod obj nmod cc conj amod obj case nummod cc conj amod obl amod conj nmod cc amod conj nmod',
#   2),
#  ('obj nmod', 2),
#  ('amod obj cc conj', 2),
#  ('amod obj case nmod', 2),
#  ('case obl nmod amod nmod', 2),
#  ('advmod amod obj', 2),
#  ('amod obj nmod nmod cc conj', 2),
#  ('obj nmod case nmod', 2),
#  ('nummod obl', 2),
#  ('obj cc conj', 2),
#  ('amod obj cc conj nsubj cc parataxis nsubj acl:relcl xcomp case flat:foreign flat:foreign case obl nsubj aux conj obj cc advmod',
#   2),
#  ('amod obl amod cc conj nmod', 2),
#  ('amod obj nmod case amod nmod', 2),
#  ('obj nmod amod nmod', 2),
#  ('obj nmod case nmod nmod cc case advmod conj cc conj', 1),
#  ('obj case nmod case amod nmod advmod parataxis cc conj nmod cc conj', 1),
#  ('amod obj case nmod appos', 1),
#  ('amod obj flat:foreign flat:foreign flat:foreign', 1),
#  ('obj case nmod amod nmod', 1),
#  ('amod obj amod nmod cc conj case nmod case nmod case nmod cc conj', 1),
#  ('obj amod nmod case nmod cc amod conj case amod nmod cc case amod conj', 1),
#  ('amod obj case nmod conj case amod nmod conj case amod nmod conj case nmod',
#   1),
#  ('amod obl amod conj cc amod conj', 1),
#  ('amod obj amod obl nmod amod cc conj conj conj', 1),
#  ('obl nmod amod conj appos case nmod case nmod conj conj conj conj conj conj conj parataxis conj conj cc conj',
#   1),
#  ('obj advmod dep obj case nmod nmod case nmod nmod nmod conj obj amod nmod case nmod nmod amod nmod conj amod obl case obl amod nmod conj obj amod nmod case obl acl:relcl nsubj case amod nmod cc conj obj',
#   1),
#  ('amod obj nmod case nmod cc conj case amod parataxis cc amod conj case amod nmod',
#   1),
#  ('obj conj', 1),
#  ('nummod:gov amod obl cc advmod amod conj case amod nmod case amod amod nmod',
#   1),
#  ('amod obj case nmod nmod', 1),
#  ('amod obj cc amod amod conj case amod nmod', 1),
#  ('amod obl nmod case conj nmod case nmod nmod case nmod', 1),
#  ('obj nmod case amod nmod', 1),
#  ('amod obj nmod case fixed amod nmod cc conj nmod', 1),
#  ('obj case amod nmod case nummod amod nmod', 1),
#  ('obj case nmod nmod', 1),
#  ('amod obj case nmod appos flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign',
#   1),
#  ('obj conj conj conj', 1),
#  ('obj flat:foreign flat:foreign nummod', 1),
#  ('amod obl case conj case nmod', 1),
#  ('amod obj nummod flat:foreign', 1),
#  ('advmod amod amod obj cc conj case amod amod nmod', 1),
#  ('amod amod obj cc advmod case conj case nmod amod nmod cc amod conj', 1),
#  ('obj case nmod cc advmod', 1),
#  ('amod obl amod nmod', 1),
#  ('obj nummod case parataxis cc nummod conj appos case nmod nsubj acl:relcl xcomp case obl obj nmod cc nsubj nsubj advmod acl:relcl obj case amod obl cc advmod advmod conj obl nmod',
#   1),
#  ('case obl case amod nmod cc case amod conj', 1),
#  ('obl case nmod', 1),
#  ('amod obj amod nmod cc conj amod nmod', 1),
#  ('amod obj nmod cc conj case nmod amod nmod', 1),
#  ('amod amod obj conj', 1),
#  ('obj cc conj nmod', 1),
#  ('amod obj amod nmod nmod amod conj cc conj nmod', 1),
#  ('case obl amod nmod', 1),
#  ('nummod obl nmod', 1),
#  ('obj case nmod amod nmod amod nmod case amod nmod cc case advmod case nmod advmod fixed case nmod case nmod',
#   1),
#  ('amod obj nmod nummod nummod nmod amod nmod nmod flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign cc conj',
#   1),
#  ('case obl case nmod amod obj nmod acl case obl nummod case nummod parataxis nmod cc conj case nummod parataxis nmod',
#   1),
#  ('obj dep obl', 1),
#  ('case amod obl parataxis nmod case nummod nmod', 1),
#  ('obj cc conj nmod conj amod conj', 1),
#  ('amod obj case obl nsubj acl:relcl amod obj', 1),
#  ('amod obl nmod case amod amod nmod', 1),
#  ('case nummod obl case amod amod nmod nmod', 1),
#  ('amod obj case amod nmod', 1),
#  ('amod obj cc advmod amod nsubj parataxis obl nmod nmod obl', 1),
#  ('obj case amod nmod', 1),
#  ('advmod case amod obl cc conj', 1),
#  ('obj nmod cc conj', 1),
#  ('amod obj amod conj conj nmod nmod case nmod flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign',
#   1),
#  ('amod obj appos', 1),
#  ('obj amod nmod flat:foreign', 1),
#  ('amod obj nmod case nmod acl:relcl cop nsubj case amod conj conj nmod', 1),
#  ('case amod obl case amod nmod cc amod conj case amod nmod case nmod conj conj cc amod conj',
#   1),
#  ('obj obj acl:relcl nsubj advmod', 1),
#  ('amod obj amod amod nmod', 1),
#  ('obj cc conj case amod nmod', 1),
#  ('obj nmod nummod case nmod nmod', 1),
#  ('obj amod nmod case amod nmod case amod nmod', 1),
#  ('amod obj nmod case amod nmod cc advmod amod conj cc conj', 1),
#  ('case obl case nmod case nmod', 1),
#  ('amod obj amod nmod case nmod', 1),
#  ('case obl case nmod nmod amod nmod flat:foreign', 1),
#  ('case nummod:gov obl', 1),
#  ('amod obj case nmod cc amod conj', 1),
#  ('obj cc amod conj amod case amod obl amod amod amod amod obj amod case amod cc conj obl',
#   1),
#  ('case amod obl nmod cc case conj nmod case amod amod nmod', 1),
#  ('amod amod obj amod nmod case nmod amod obj', 1),
#  ('obj amod nmod amod nmod nmod', 1),
#  ('case nummod obl case nummod nmod amod case nmod', 1),
#  ('amod obj nmod case nmod amod nmod', 1),
#  ('obj case nmod nmod cc amod conj case amod nmod', 1),
#  ('amod obj nmod amod nmod amod conj amod obj advmod case amod obl', 1),
#  ('obj nmod nmod nmod nmod amod nmod', 1),
#  ('amod obj amod amod nmod appos', 1),
#  ('case amod obl nmod', 1),
#  ('amod obj amod nmod case amod advmod advmod amod nsubj obl advmod aux acl:relcl obl cc conj',
#   1),
#  ('amod amod obj amod nmod conj amod nmod nmod', 1),
#  ('amod obj parataxis nmod case nmod cc advmod conj nmod conj nmod conj nmod',
#   1),
#  ('obj cc obj conj parataxis', 1),
#  ('obl case nmod case nmod', 1),
#  ('amod obj nummod nmod', 1),
#  ('obj nmod cc case conj', 1),
#  ('amod obj amod nmod amod amod amod obj case obl conj conj', 1),
#  ('amod amod obj nmod cc conj nmod', 1),
#  ('case amod obl cc amod conj nmod', 1),
#  ('obl nmod case nmod nmod', 1),
#  ('amod amod obj amod parataxis appos nmod amod obj nmod nmod conj case amod nmod nmod nmod cc amod conj nmod amod nmod',
#   1),
#  ('case obl cc conj case nmod cc conj', 1),
#  ('amod case nmod obj cc conj case nmod cc conj', 1),
#  ('obj nmod nummod case nmod acl:relcl amod nsubj flat:foreign', 1),
#  ('amod obj appos nummod nummod parataxis nummod nummod amod obj case nmod case nmod',
#   1),
#  ('advmod amod amod cc conj obl', 1),
#  ('obj parataxis cc conj nummod nmod cc conj', 1),
#  ('amod obj amod nmod case nmod cc conj', 1),
#  ('advmod amod cc conj obl nmod parataxis case nmod nmod parataxis case nmod mark fixed case parataxis amod nmod',
#   1),
#  ('amod obj amod nmod cc conj', 1),
#  ('obj amod nmod case nmod case amod nmod amod amod parataxis conj conj cc conj parataxis dep obl',
#   1),
#  ('amod obl parataxis cc nmod conj conj', 1),
#  ('obj nmod nummod nmod', 1),
#  ('obj nmod flat:foreign case amod nmod parataxis nmod case nummod nmod cc conj',
#   1),
#  ('obj amod cc conj amod nmod case nmod case amod amod cc conj nmod', 1),
#  ('advmod amod amod obj', 1),
#  ('amod obj amod amod obl:agent flat:foreign conj', 1),
#  ('amod cc conj amod obl', 1),
#  ('amod obj amod nmod parataxis amod nmod nmod nmod amod parataxis cc amod conj',
#   1),
#  ('amod obj cc amod conj amod nmod amod nmod', 1),
#  ('obj amod nmod conj nmod conj nummod', 1),
#  ('amod amod obj cc amod conj case amod nmod case nmod', 1),
#  ('case obl case amod nmod nmod amod nmod', 1),
#  ('amod amod obl case obl nsubj acl:relcl case obl case obl amod nmod', 1),
#  ('obl case fixed nmod conj parataxis amod conj cc conj', 1),
#  ('amod obj nmod amod nmod', 1),
#  ('advmod obj case fixed fixed nummod nmod cc advmod conj advmod amod amod obj advmod case obl nsubj conj amod obl amod nmod advmod amod conj amod nmod case amod nmod',
#   1),
#  ('amod obj amod nmod amod amod conj cc amod conj case amod nmod cc conj amod nmod',
#   1),
#  ('obj case nmod amod cc conj nmod amod nmod amod conj parataxis amod cc conj',
#   1),
#  ('amod obj case nmod cc advmod case conj', 1),
#  ('amod obl conj', 1),
#  ('amod amod obj case nmod amod nmod flat:foreign', 1),
#  ('obj amod amod amod nmod case amod cc conj nmod cc amod conj case nmod flat:foreign nummod',
#   1),
#  ('obj case amod nmod amod nmod nmod case nmod amod amod nmod', 1),
#  ('amod obj nmod acl', 1),
#  ('obl amod nmod nmod nmod case nmod nmod', 1),
#  ('case fixed amod conj conj cc conj obl', 1),
#  ('obj case amod cc conj nmod nsubj nmod aux:pass advmod parataxis case nummod:gov obl',
#   1),
#  ('amod obj cc conj nmod case nmod case amod nmod nmod', 1),
#  ('amod obj cc advmod nummod parataxis conj case nmod appos conj conj', 1),
#  ('amod obl nmod amod conj cc case nmod advmod amod conj', 1),
#  ('obl amod appos amod amod conj nmod case nmod', 1),
#  ('obj case obl nsubj acl:relcl amod obj case nmod appos', 1),
#  ('obj case nmod nmod flat:foreign cc flat:foreign', 1),
#  ('amod advmod amod amod obj', 1),
#  ('amod amod obj amod amod nmod case nmod nmod nsubj case amod case nmod nmod appos',
#   1),
#  ('amod obj nmod case amod nmod cc conj parataxis conj cc conj', 1),
#  ('amod amod case nmod obj amod nmod case nmod case nummod case nummod nmod nmod dep amod obj case amod obl case obl nummod nmod conj obl',
#   1),
#  ('obj case nmod cc conj amod nmod', 1),
#  ('amod obj nsubj acl:relcl xcomp advmod amod amod obl', 1),
#  ('amod obj case nmod amod nmod', 1),
#  ('amod obl amod conj conj conj cc conj appos case nmod acl:relcl nsubj cc conj amod amod obj case amod nmod case amod nmod nmod nmod nmod flat:foreign flat:foreign',
#   1),
#  ('amod amod case nmod obj nmod amod appos amod dep amod obj case obl conj conj',
#   1),
#  ('obj amod nmod', 1),
#  ('amod obl cc conj case nmod', 1),
#  ('obl flat:name flat:name amod amod flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign flat:foreign nmod',
#   1),
#  ('obl case amod obl parataxis nsubj obj advmod amod amod parataxis cc conj conj amod amod obj cc conj parataxis nmod amod amod obj conj conj nmod amod cc conj case obl amod nmod',
#   1),
#  ('obj amod conj conj case nmod', 1),
#  ('amod obj cc conj case obl amod nsubj acl:relcl xcomp amod obj case advmod advmod amod nmod',
#   1),
#  ('obj appos', 1),
#  ('obj amod nmod nsubj acl:relcl obl amod nmod cc amod conj case nmod amod obl nmod',
#   1),
#  ('obj case nmod', 1),
#  ('obl appos advmod nsubj acl:relcl xcomp amod obl case amod obl', 1),
#  ('amod obl nmod case amod nmod mark nsubj advcl xcomp amod amod obl', 1),
#  ('obj nmod amod nmod nsubj acl:relcl xcomp obj cc conj obj amod nmod', 1),
#  ('amod obj amod nmod nmod nmod case nmod', 1),
#  ('amod obj cc conj nmod', 1),
#  ('amod obj nmod case nmod amod amod nmod case amod advmod amod conj nmod', 1),
#  ('amod obj amod conj conj nmod case amod nmod parataxis nmod amod nmod', 1),
#  ('amod obj cc advmod nmod conj conj nmod cc conj amod', 1),
#  ('amod amod obj nmod nmod nsubj nmod cop advmod acl:relcl', 1),
#  ('obj case nmod parataxis parataxis amod nmod nmod', 1),
#  ('obj case amod nmod nmod nmod case parataxis case nmod', 1),
#  ('nummod:gov obl', 1),
#  ('amod amod obj case nmod amod amod nmod cc conj', 1),
#  ('obj amod amod nmod case nmod amod nmod cc conj nmod', 1),
#  ('amod obj case nmod nmod amod nmod', 1),
#  ('obj amod nmod conj case amod nmod', 1),
#  ('case advmod amod obl', 1),
#  ('obj amod nmod case amod nmod case nmod', 1),
#  ('obj case amod nmod amod nmod', 1),
#  ('case obl nmod nmod case', 1),
#  ('amod conj cc conj obj case nmod amod nmod amod amod appos conj parataxis case nmod nmod cc conj amod nmod',
#   1),
#  ('amod cc conj obj', 1),
#  ('amod cc conj obl amod amod nmod flat:foreign case amod amod nmod', 1),
#  ('advmod advmod amod obl nsubj advmod acl:relcl amod amod obj advmod amod advmod obl nmod nmod case nmod',
#   1),
#  ('obj nmod case nmod cc amod conj', 1),
#  ('amod obj case nummod case nummod nmod appos mark nmod cc amod conj case nmod amod nmod cc conj nmod cc conj cc conj amod nmod',
#   1),
#  ('advmod advmod obl cc amod case nmod case nmod cc advmod advmod amod conj cc conj',
#   1),
#  ('obl appos', 1),
#  ('amod obl flat:name', 1),
#  ('case obl amod case nummod amod obl cc nummod conj nmod case nmod amod nmod',
#   1),
#  ('amod amod obj nmod', 1),
#  ('case advmod amod obl nmod amod case obl amod nmod amod conj amod conj', 1),
#  ('case obl amod case obl', 1),
#  ('obj case nmod amod nmod case nmod', 1),
#  ('amod amod obl cc advmod conj advmod nmod', 1),
#  ('amod amod obj nmod appos case nmod', 1),
#  ('obj nmod nmod case nmod case amod amod amod nmod', 1),
#  ('advmod amod obl nmod case nmod amod nmod case nmod nmod case nmod case nmod',
#   1),
#  ('case nummod obl', 1)]

# %%
c.most_common(100)
# Out:
# [('является', 141080),
#  ('нет', 93128),
#  ('может', 73867),
#  ('имеет', 70084),
#  ('можете', 69585),
#  ('стал', 57634),
#  ('находится', 55386),
#  ('являются', 46268),
#  ('предлагает', 40765),
#  ('нравится', 39737),
#  ('стоит', 38130),
#  ('получил', 35728),
#  ('имеют', 35570),
#  ('могут', 33677),
#  ('посмотрите', 32962),
#  ('составляет', 31540),
#  ('стала', 30845),
#  ('работает', 29751),
#  ('найдете', 26897),
#  ('происходит', 24595),
#  ('стали', 24544),
#  ('следует', 21883),
#  ('становится', 20577),
#  ('идет', 20360),
#  ('удалось', 20183),
#  ('делает', 20075),
#  ('используется', 20071),
#  ('состоит', 20069),
#  ('получают', 19788),
#  ('помогаем', 19785),
#  ('придется', 19720),
#  ('находятся', 19619),
#  ('входит', 19043),
#  ('зависит', 18194),
#  ('представляет', 17987),
#  ('относится', 17930),
#  ('предлагают', 17814),
#  ('стало', 16920),
#  ('дает', 16576),
#  ('говорит', 16547),
#  ('станет', 16491),
#  ('получила', 16294),
#  ('сможете', 16263),
#  ('получили', 15929),
#  ('включает', 15445),
#  ('проходит', 15006),
#  ('требуется', 14615),
#  ('работал', 14460),
#  ('сказал', 14349),
#  ('работают', 14345),
#  ('приходится', 14283),
#  ('принял', 14070),
#  ('представлены', 14039),
#  ('имеются', 13872),
#  ('начал', 13613),
#  ('вышел', 13596),
#  ('имеется', 13522),
#  ('используются', 13482),
#  ('существует', 13450),
#  ('ищем', 13250),
#  ('начинается', 13083),
#  ('содержит', 13008),
#  ('сделал', 12866),
#  ('получает', 12783),
#  ('позволяет', 12465),
#  ('подходит', 12116),
#  ('требует', 12051),
#  ('появился', 11894),
#  ('появились', 11882),
#  ('появилась', 11879),
#  ('делают', 11838),
#  ('знает', 11820),
#  ('поможет', 11790),
#  ('появляется', 11581),
#  ('входят', 11463),
#  ('занимает', 11364),
#  ('принадлежит', 11309),
#  ('заявил', 11239),
#  ('считается', 11118),
#  ('относятся', 11045),
#  ('отличается', 11016),
#  ('включают', 11007),
#  ('вышла', 10926),
#  ('нашли', 10875),
#  ('пришлось', 10867),
#  ('приводит', 10840),
#  ('обеспечивает', 10797),
#  ('проверялась', 10750),
#  ('обладает', 10692),
#  ('произошло', 10655),
#  ('требуют', 10647),
#  ('ссылается', 10599),
#  ('называется', 10543),
#  ('написал', 10535),
#  ('представлена', 10269),
#  ('работали', 10238),
#  ('осуществляется', 10153),
#  ('использовали', 10128),
#  ('остается', 10122),
#  ('занимается', 10110)]

# %%
[x[0] for x in preds['родился'].most_common() if x[0].istitle() and len(x[0]) > 3]
# Out:
# ['Мейер Залик',
#  'Гвоздев',
#  'Одегбами',
#  'Джу Хёк',
#  'Раманаускас',
#  'Яков Тургенев',
#  'Гермоген Титович',
#  'Стотт',
#  'Пузович',
#  'А. Анисимов',
#  'Ольмедо',
#  'Восточная Фризия .',
#  'Добрый',
#  'Терещенко',
#  'Флориан Федорович',
#  'Аксельссон',
#  'Шмарово',
#  'Марьянович',
#  'Бочаров',
#  'Раймонд Сапорта',
#  'Лисица',
#  'Аристон',
#  'Еникеев',
#  'Алексанян',
#  'Йованович',
#  'Фернандес',
#  'Фольман',
#  'Бастианини',
#  'Прайс',
#  'Икинс',
#  'Квайе',
#  'Чарльз Крамп',
#  "Л'Акуила ,",
#  'Сантистебан-Ксикес',
#  'Мандро',
#  '( 1866По',
#  'Иенеми',
#  'Ильин',
#  'Секонди- Такоради .',
#  'Миркович',
#  'Людвиг Гшоссманн',
#  'И. А.',
#  'Винья Стеллути',
#  'Мохамед',
#  'Джереми ,',
#  'Зайцев',
#  'Джурич',
#  'Авраам Цви Идельсон',
#  'Волдемар Валдманис —',
#  'Аллахвердиев',
#  'Мартин Савала Ломбарди',
#  'Лазарь Гейгер',
#  'Конти',
#  'Канада',
#  'Марк Алданов',
#  'Архипп',
#  'Украина .',
#  'Сальминен',
#  'Раймундо Сапорта',
#  'Шень',
#  '( Драйсон',
#  'Аризанов',
#  'Кеннеди',
#  'Обадов',
#  'Милка Сингх',
#  'Сироджиддин Джалолиддиновича',
#  'Аристион',
#  'Бадхеведорп , Северная Голландия .',
#  'Вильена',
#  'Рыгдылон',
#  'Саут-Йоркшир .',
#  'Донку',
#  'Хапусенеб',
#  'Тульвинг',
#  'Джон Хэмингуэй',
#  'Голубарь']

# %%
[x for x in sub_obj['родился'].most_common() if x[0][0].istitle()]
# Out:
# [(('Одегбами', ('в нигерийском городе Ибадан .\n',)), 1),
#  (('Людвиг Гшоссманн',
#    ('Согласно «Общему лексикону художников всех времен и народов» ( Allgemeines Künstlerlexikon : Die bildenden Künstler aller Zeiten und Völker ) Günter Meißner : Allgemeines Künstlerlexikon : Die bildenden Künstler aller Zeiten und Völker',
#     'в Мюнхене .\n')),
#   1),
#  (('Флориан Федорович', ('Флориан Федорович\n',)), 1),
#  (('Раймундо Сапорта', ('в 1926 году', 'в Париже ,\n')), 1),
#  (('Саут-Йоркшир .', ('Гарри Магуайр', 'в Шеффилде ,\n')), 1),
#  (('Милка Сингх', ('Согласно записям в Пакистане\n',)), 1),
#  (('Аристион', ('Согласно этой книге', 'в семье язычников .', 'во II веке\n')),
#   1),
#  (('Аризанов', ('в селе Иловица ( община Босилово ) .\n',)), 1),
#  (('Раймонд Сапорта', ('в Стамбуле .', 'согласно которому\n')), 1),
#  (('Чарльз Крамп', ('Хью', 'в Рочестере ,\n')), 1),
#  (('Архипп', ('в городе Иераполе ,', 'во Фригии ,\n')), 1),
#  (('А. Анисимов',
#    ('Л.',
#     'в селе Ракитное ( сейчас — Гнаровское ) , Вольнянский район , Запорожская область ) в рабочей семье .\n')),
#   1),
#  (('Восточная Фризия .', ('в 1505 году', 'в графстве\n')), 1),
#  (('Сок', ('в Южной Кореи', 'в городе Кванджу .\n')), 1),
#  (('Зайцев',
#    ('Иона Мордков ( Мордкович )',
#     'в 1828 году ,',
#     'в Богуславе Каневского уезда .\n')),
#   1),
#  (("Л'Акуила ,", ('в городе', 'в регионе Абруццо в центральной Италии .\n')),
#   1),
#  (('Квайе', ('в ганском городе Тема .\n',)), 1),
#  (('Йованович', ('в городе Томс-Ривер штата Нью-Джерси ,\n',)), 1),
#  (('( Драйсон', ('на один глаз ,', 'слепым\n')), 1),
#  (('Бочаров', ('в станице Ессентукской Терской области .\n',)), 1),
#  (('Раманаускас', ('Эдвинас', 'в городе Шяуляй Литовской ССР .\n')), 1),
#  (('Мартин Савала Ломбарди', ('в Такне ( регион Такна , Перу ) .\n',)), 1),
#  (('Сантистебан-Ксикес', ('Энрике', 'в Мансанильо .\n')), 1),
#  (('Шень',
#    ('в 1036 году', 'в области Тайюань ( современная провинция Шаньси ) .\n')),
#   1),
#  (('Терещенко',
#    ('в 1883 году', 'в Васильковском уезде Киевской губернии .\n')),
#   1),
#  (('Хаг', ('в городе Хайленд , Иллинойс .\n',)), 1),
#  (('Яков Тургенев', ('в XVII веке .\n',)), 1),
#  (('Рыгдылон',
#    ('в семье учителя в улусе Кусота ( современный Хилокский район Забайкальского края ) .\n',)),
#   1),
#  (('Авраам Цви Идельсон', ('В селе\n',)), 1),
#  (('Алексанян', ('в Арарате .\n',)), 1),
#  (('Фернандес', ('В 2015 году', 'у Саймона и его девушки Эльвиры\n')), 1),
#  (('( 1866По', ('другим данным', 'около 1860 года . ,\n')), 1),
#  (('Вильена',
#    ('Энрике де', 'в 1384 году', 'в Торральба де Куэнка', 'в семье\n')),
#   1),
#  (('Хапусенеб', ('в правление фараона Аменхотепа I .\n',)), 1),
#  (('Мандро',
#    ('Международный конгресс современной архитектуры ( CIAM ) .',
#     'После этого\n')),
#   1),
#  (('Лазарь Гейгер', ('в семье реформаторов\n',)), 1),
#  (('Кеннеди', ('Охене', 'в ганском городе Аккра .\n')), 1),
#  (('Бадхеведорп , Северная Голландия .', ('в нидерландском городе\n',)), 1),
#  (('Лисица',
#    ('в селе Ламинци- Брезици близ Градишки в семье партизанского офицера и домохозяйки .\n',)),
#   1),
#  (('Донку', ('в южнокорейской столице Сеуле', 'в 1988 году .\n')), 1),
#  (('Мейер Залик',
#    ('в семье немецкого иммигранта Энтони Залика и жительницы Пенсильвании\n',)),
#   1),
#  (('Шмарово',
#    ('в деревне',
#     'в селе Кольцово Ферзиковского района Калужской губернии ) .\n')),
#   1),
#  (('Фольман', ('в Хайфе', 'в 1962 году .\n')), 1),
#  (('Марк Алданов', ('у них\n',)), 1),
#  (('Еникеев', ('в деревне\n',)), 1),
#  (('Гвоздев',
#    ('в семье диакона Шатеневской Николаевской церкви Никольского уезда ( Вологодская губерния ) .\n',)),
#   1),
#  (('Пузович',
#    ('в городе Крагуеваце административного региона Шумадия Югославии .\n',)),
#   1),
#  (('Аллахвердиев', ('Ильхам', 'в 1962 году', 'в городе Агдам .\n')), 1),
#  (('Конти', ('в конце 1920-х .', 'на Сицилии\n')), 1),
#  (('Голубарь',
#    ('в городке Корсунь Киевской губернии ( ныне — город Корсунь-Шевченковский Черкасской области )',
#     'в бедной крестьянской семье .\n')),
#   1),
#  (('Добрый', ('Абрам Уриевич ( Юрьевич )', 'в 1867 году', 'в Киеве .\n')), 1),
#  (('Ильин',
#    ('Кондой Аларского аймака ( Балаганского уезда )',
#     'в 1891 году',
#     'в улус\n')),
#   1),
#  (('Джон Хэмингуэй', ('в Торонто\n',)), 1),
#  (('Чен', ('в культуре отличной от той , в которой он живёт сейчас ,\n',)), 1),
#  (('Джереми ,', ('В октябре 2009 года', 'у Эрики и Роджера\n')), 1),
#  (('Тульвинг', ('в Эстонии ( город Петсери ;\n',)), 1),
#  (('Джу Хёк', ('Нам\n',)), 1),
#  (('Обадов',
#    ('12 июля 1948 года городе Земун ( ныне один из районов Белграда ) , Югославия .\n',)),
#   1),
#  (('Сальминен', ('в финском городе Хельсинки .\n',)), 1),
#  (('Винья Стеллути', ('в римском квартале', 'в зажиточной ,\n')), 1),
#  (('Миркович', ('в Приштине ,\n',)), 1),
#  (('Мохамед', ('в Кот-д’Ивуаре\n',)), 1),
#  (('Канада', ('в Эдмонтоне , Альберта ,\n',)), 1),
#  (('Сироджиддин Джалолиддиновича', ('Мухамедов\n',)), 1),
#  (('Стотт', ('в Манчестере .\n',)), 1),
#  (('Аристон', ('в Пелле ,\n',)), 1),
#  (('И. А.', ('В здании', 'в Московской', 'в 1812 году', 'на перекрестке\n')),
#   1),
#  (('Гермоген Титович',
#    ('был активным участником Первой русской революции .\n',)),
#   1),
#  (('Икинс', ('через пять лет после изобретения\n',)), 1),
#  (('Волдемар Валдманис —',
#    ('в будущем', 'известный советский сценограф и график .\n')),
#   1),
#  (('Джурич', ('в Тузле ,\n',)), 1),
#  (('Бастианини', ('в котором\n',)), 1),
#  (('Ольмедо',
#    ('в 1936 году',
#     'в перуанском городе Арекипа в семье теннисного тренера .\n')),
#   1),
#  (('Аксельссон', ('Туре', 'в Хельсинки .\n')), 1),
#  (('Украина .', ('в городе Хмельницком ,\n',)), 1),
#  (('Иенеми', ('в нигерийском городе Порт-Харкорт .\n',)), 1),
#  (('Секонди- Такоради .', ('в ганском городе\n',)), 1),
#  (('Прайс', ('в 60-х .\n',)), 1),
#  (('Марьянович', ('в рабочей семье в г. Днепропетровске .\n',)), 1)]

# %%
import requests

# %%
yarn = requests.get('http://russianword.net/yarn.xml')

# %%
f = open('yarn.xml', 'wb')
f.write(yarn.content)
f.close()
